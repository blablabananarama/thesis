# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


# make folders specific for certain data
folder_name = ''
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(RAW_EXTERNAL, folder_name)):
        os.makedirs(join(RAW_EXTERNAL, folder_name))

    if not exists(join(INTERMEDIATE, folder_name)):
        os.makedirs(join(INTERMEDIATE, folder_name))

    if not exists(join(FINAL, folder_name)):
        os.makedirs(join(FINAL, folder_name))


print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %% [markdown]
# 1. Abundance [mmol/cell] = Abundance [mmol/gDW] * ( cell volume [fL/cell] * cell density [g/fL] * dry content [gDW/g] )
# 2. Abundance [molecules/cell] = Abundance [mmol/cell] * Na [molecules/mol] * 1000 [mmol/mol]

# %%
import pandas as pd
import re
# import data 
data = pd.read_csv(f"{INTERMEDIATE}/proteomics_concentrations.csv", index_col=0)



# get cell volumes
cell_volumes = pd.read_csv(f"{RAW_INTERNAL}/proteomics/growth_conditions.csv", index_col=0)
cell_volumes = cell_volumes["Single cell volume [fl]1"]
# remove the first two rows of LB
cell_volumes = cell_volumes.loc[~cell_volumes.index.duplicated(keep='first')]
# rename the number 3 in there
cell_volumes = cell_volumes.rename({'Osmotic-stress glucose3':'Osmotic-stress glucose_uncertainty'}, axis='index')
rename_dict = {i:re.sub(r'\W+', '', i).lower() for i in cell_volumes.index}
cell_volumes = cell_volumes.rename(rename_dict, axis='index')


# Finally, convert to mmol/gDW:
water_content = 0.3
cell_density = 1.105e-12



# Iterate through the dataset and multiply by the corresponding cell volume, to get mmol/fL:
for (col_name, d) in data.iteritems():
    chemo_name = col_name.replace("_uncertainty", "").replace("_mean", "")
    try:
        data[col_name] = data[col_name] * cell_volumes.loc[chemo_name]#["cell_volume"]
    except:
        print(chemo_name)
        
        
data = data * cell_density * water_content
        

# convert into counts
data = data * 6.022e+23 / 1000
data
# Out:
# osmoticstressglucose
# osmoticstressglucose
#                    glucose       lb  glycerolaa  acetate  fumarate  \
# Uniprot Accession
# P0A8T7              2779.0   7164.0      4503.0   2180.0    2444.0
# P0A8V2              3957.0   8888.0      5199.0   2661.0    3199.0
# P36683              7596.0  16600.0     17548.0  22844.0   19491.0
# P15254              2456.0    821.0      2339.0   1438.0    2071.0
# P09831              2859.0    604.0       652.0   1363.0    1281.0
# ...                    ...      ...         ...      ...       ...
# P36667                 3.0     26.0         NaN      2.0      10.0
# P0AC78                 1.0      0.0         0.0      4.0       3.0
# P76164               171.0      2.0         5.0     53.0      23.0
# P38506                 3.0      6.0         4.0      2.0       3.0
# Q46810                44.0     18.0         NaN     13.0      15.0
#
#                    glucosamine  glycerol  pyruvate  chemostatµ05  \
# Uniprot Accession
# P0A8T7                  3316.0    2845.0    2730.0        4780.0
# P0A8V2                  3999.0    3749.0    3714.0        5245.0
# P36683                 13753.0   10792.0   16395.0       15733.0
# P15254                  1959.0    2068.0    2708.0        2285.0
# P09831                  1977.0    2204.0    1691.0        2321.0
# ...                        ...       ...       ...           ...
# P36667                     7.0       3.0       4.0           3.0
# P0AC78                     2.0       4.0       6.0           9.0
# P76164                    41.0      49.0      56.0          45.0
# P38506                     2.0       2.0       3.0           2.0
# Q46810                    10.0      10.0       8.0          18.0
#
#                    chemostatµ035  ...  stationaryphase1day_uncertainty  \
# Uniprot Accession                 ...
# P0A8T7                    3900.0  ...                         117.2860
# P0A8V2                    4388.0  ...                         343.0518
# P36683                   20261.0  ...                          36.6669
# P15254                    1730.0  ...                          43.3218
# P09831                    1959.0  ...                          40.1120
# ...                          ...  ...                              ...
# P36667                       1.0  ...                              NaN
# P0AC78                       4.0  ...                           0.0000
# P76164                      22.0  ...                           0.0000
# P38506                       2.0  ...                           0.0000
# Q46810                      41.0  ...                              NaN
#
#                    stationaryphase3days_uncertainty  \
# Uniprot Accession
# P0A8T7                                     230.3656
# P0A8V2                                     248.9786
# P36683                                      75.9024
# P15254                                      29.5470
# P09831                                       7.2834
# ...                                             ...
# P36667                                          NaN
# P0AC78                                       0.0000
# P76164                                      10.7809
# P38506                                       0.0000
# Q46810                                          NaN
#
#                    osmoticstressglucose_uncertainty  42cglucose_uncertainty  \
# Uniprot Accession
# P0A8T7                                     470.0568                552.3210
# P0A8V2                                     568.7992                517.4073
# P36683                                     467.2900                463.3794
# P15254                                     170.9446                214.5130
# P09831                                     236.9394                518.0481
# ...                                             ...                     ...
# P36667                                          NaN                     NaN
# P0AC78                                       0.0000                  0.0000
# P76164                                      15.4707                 71.9055
# P38506                                       0.0000                  0.0000
# Q46810                                          NaN                     NaN
#
#                    ph6glucose_uncertainty  xylose_uncertainty  \
# Uniprot Accession
# P0A8T7                           205.0146            227.7264
# P0A8V2                           239.0976            189.4599
# P36683                           207.8103           1458.6066
# P15254                            30.4024            135.6148
# P09831                           213.4832            500.4480
# ...                                   ...                 ...
# P36667                                NaN                 NaN
# P0AC78                             0.0000              0.0000
# P76164                            14.3737              5.0820
# P38506                             0.7951              0.0000
# Q46810                                NaN                 NaN
#
#                    mannose_uncertainty  galactose_uncertainty  \
# Uniprot Accession
# P0A8T7                        549.2615               516.4046
# P0A8V2                        559.7193               556.9500
# P36683                        521.9372               266.5125
# P15254                         21.5208               120.7330
# P09831                        368.1909               312.5928
# ...                                ...                    ...
# P36667                             NaN                    NaN
# P0AC78                          0.0000                 0.0000
# P76164                          2.2428                 7.2192
# P38506                          0.0000                 0.0000
# Q46810                             NaN                    NaN
#
#                    succinate_uncertainty  fructose_uncertainty
# Uniprot Accession
# P0A8T7                          454.6780              419.6293
# P0A8V2                          524.2800              409.4013
# P36683                          822.9287              285.4150
# P15254                           56.6248              149.1720
# P09831                          166.0157              343.7478
# ...                                  ...                   ...
# P36667                               NaN                   NaN
# P0AC78                            0.0000                0.0000
# P76164                            2.3332               12.9584
# P38506                            0.0000                0.0000
# Q46810                               NaN                   NaN
#
# [2359 rows x 44 columns]

# %%
original_data = pd.read_csv(f"{RAW_INTERNAL}/proteomics/protein_values.csv", index_col=0)
original_data
# Out:
#                                                          Description  Gene  \
# Uniprot Accession
# P0A8T7             DNA-directed RNA polymerase subunit beta' OS=E...  rpoC
# P0A8V2             DNA-directed RNA polymerase subunit beta OS=Es...  rpoB
# P36683             Aconitate hydratase 2 OS=Escherichia coli (str...  acnB
# P15254             Phosphoribosylformylglycinamidine synthase OS=...  purL
# P09831             Glutamate synthase [NADPH] large chain OS=Esch...  gltB
# ...                                                              ...   ...
# P36667             dTDP-Rha:alpha-D-GlcNAc-pyrophosphate polypren...  wbbL
# P0AC78             Undecaprenyl-phosphate alpha-N-acetylglucosami...  wecA
# P76164             Uncharacterized protein ydfW in Qin prophage r...  ydfW
# P38506             Protein Xni OS=Escherichia coli (strain K12) G...  ygdG
# Q46810             Uncharacterized protein ygfJ OS=Escherichia co...  ygfJ
#
#                    Peptides.used.for.quantitation  Confidence.score  \
# Uniprot Accession
# P0A8T7                                         91           6045.53
# P0A8V2                                         89           5061.29
# P36683                                         67           4505.67
# P15254                                         65           4277.71
# P09831                                         64           4111.74
# ...                                           ...               ...
# P36667                                          1             87.30
# P0AC78                                          1             37.97
# P76164                                          1             39.51
# P38506                                          1             30.22
# Q46810                                          1             87.64
#
#                    Molecular weight (Da)  Dataset  Glucose     LB  \
# Uniprot Accession
# P0A8T7                      155045.00800        2     2779   7164
# P0A8V2                      150520.27580        2     3957   8888
# P36683                       93420.94570        2     7596  16600
# P15254                      141295.89840        2     2456    821
# P09831                      163176.31530        2     2859    604
# ...                                  ...      ...      ...    ...
# P36667                       31022.76240        1        3     26
# P0AC78                       40912.09384        2        1      0
# P76164                        8702.81560        2      171      2
# P38506                       28130.36423        2        3      6
# Q46810                       21481.91354        1       44     18
#
#                    Glycerol + AA  Acetate  ...  Mannose.2  Galactose .2  \
# Uniprot Accession                          ...
# P0A8T7                    4503.0     2180  ...      16.15         22.87
# P0A8V2                    5199.0     2661  ...      13.51         19.75
# P36683                   17548.0    22844  ...       3.16          2.07
# P15254                    2339.0     1438  ...       1.22          7.69
# P09831                     652.0     1363  ...      17.71         22.36
# ...                          ...      ...  ...        ...           ...
# P36667                       NaN        2  ...        NaN           NaN
# P0AC78                       0.0        4  ...       0.20          0.51
# P76164                       5.0       53  ...       3.56         30.08
# P38506                       4.0        2  ...     159.16        109.74
# Q46810                       NaN       13  ...        NaN           NaN
#
#                    Succinate.2  Fructose.2  Gene.1  Bnumber  \
# Uniprot Accession
# P0A8T7                   16.45        9.29    rpoC    b3988
# P0A8V2                   13.60        7.77    rpoB    b3987
# P36683                    4.21        3.25    acnB    b0118
# P15254                    2.96        6.20    purL    b2557
# P09831                   10.69        8.91    gltB    b3212
# ...                        ...         ...     ...      ...
# P36667                     NaN         NaN    wbbL      NaN
# P0AC78                    0.64        0.51    wecA      NaN
# P76164                   12.28       14.56    ydfW      NaN
# P38506                    1.20      131.15    ygdG      NaN
# Q46810                     NaN         NaN    ygfJ      NaN
#
#                    Annotated functional COG groups (letter)  \
# Uniprot Accession
# P0A8T7                                                    K
# P0A8V2                                                    K
# P36683                                                    C
# P15254                                                    F
# P09831                                                    E
# ...                                                     ...
# P36667                                                    -
# P0AC78                                                    -
# P76164                                                    -
# P38506                                                    -
# Q46810                                                    -
#
#                    Annotated functional COG group (description)  \
# Uniprot Accession
# P0A8T7                                            Transcription
# P0A8V2                                            Transcription
# P36683                         Energy production and conversion
# P15254                      Nucleotide transport and metabolism
# P09831                      Amino acid transport and metabolism
# ...                                                         ...
# P36667                                                      NaN
# P0AC78                                                      NaN
# P76164                                                      NaN
# P38506                                                      NaN
# Q46810                                                      NaN
#
#                        Annotated functional COG class  Unnamed: 78
# Uniprot Accession
# P0A8T7             INFORMATION STORAGE AND PROCESSING          NaN
# P0A8V2             INFORMATION STORAGE AND PROCESSING          NaN
# P36683                                     METABOLISM          NaN
# P15254                                     METABOLISM          NaN
# P09831                                     METABOLISM          NaN
# ...                                               ...          ...
# P36667                                            NaN          NaN
# P0AC78                                            NaN          NaN
# P76164                                            NaN          NaN
# P38506                                            NaN          NaN
# Q46810                                            NaN          NaN
#
# [2359 rows x 78 columns]
