# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


# make folders specific for certain data
folder_name = ''
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(RAW_EXTERNAL, folder_name)):
        os.makedirs(join(RAW_EXTERNAL, folder_name))

    if not exists(join(INTERMEDIATE, folder_name)):
        os.makedirs(join(INTERMEDIATE, folder_name))

    if not exists(join(FINAL, folder_name)):
        os.makedirs(join(FINAL, folder_name))


print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %%
import cobra
import os
import pandas as pd
import cameo
import wget
import ssl
from scipy.stats import pearsonr


#E. coli model:
#eColi_model = cameo.load_model("iML1515")


#E. coli model:
ssl._create_default_https_context = ssl._create_unverified_context
wget.download("https://raw.githubusercontent.com/BenjaSanchez/notebooks/master/e_coli_simulations/eciML1515.xml")
eColi_Model = cobra.io.read_sbml_model("eciML1515.xml")
os.remove("eciML1515.xml")


# proteomics data:
proteomics_dataset = f"{INTERMEDIATE}/proteomics_concentrations.csv"

# %%
from collections import namedtuple
from cobra.medium.boundary_types import find_external_compartment
from cobra.io.dict import reaction_to_dict
import pandas as pd
import numpy as np

# %%
def reset_proteomics():
    data = pd.read_csv(proteomics_dataset)  # yeast
    print(data.isna().values.any())
    data = data.dropna()
    print(data.isna().values.any())

    data = data.reset_index(drop=True)
        
    # cols_measurements 
    cols_measurements = data.columns[data.columns.get_loc("glucose"):data.columns.get_loc("fructose")]

    # cols uncertainties
    cols_uncertainties = data.columns[data.columns.get_loc("glucose_uncertainty"):data.columns.get_loc("fructose_uncertainty")]

    # E. coli
    proteomics_all = dict()
    for i in range(0,len(cols_measurements)):
        measurement = cols_measurements[i]
        proteomics = []
        for j in range(0,data.shape[0]):
            protein = {"identifier":data["Uniprot Accession"][j], \
            "measurement":data[cols_measurements[i]][j], \
            "uncertainty":data[cols_uncertainties[i]][j]}
            proteomics.append(protein)
        proteomics_all[cols_measurements[i]] = proteomics
    return(proteomics_all)

# %%
proteomics_data_dict = reset_proteomics()
    ####### hacky!!! #######
# Out:
# True
# False
# {'glucose': [{'identifier': 'P0A8T7',
#    'measurement': 4.901690917919181e-06,
#    'uncertainty': 1.0033761308980561e-06},
#   {'identifier': 'P0A8V2',
#    'measurement': 6.979485772654262e-06,
#    'uncertainty': 1.2667766677367487e-06},
#   {'identifier': 'P36683',
#    'measurement': 1.3398072764488699e-05,
#    'uncertainty': 2.308487937321403e-06},
#   {'identifier': 'P15254',
#    'measurement': 4.331972973878916e-06,
#    'uncertainty': 4.033066838681271e-07},
#   {'identifier': 'P09831',
#    'measurement': 5.0427975294461814e-06,
#    'uncertainty': 3.1769624435510943e-07},
#   {'identifier': 'P0AFG8',
#    'measurement': 1.0256686825368851e-05,
#    'uncertainty': 2.280061481279496e-06},
#   {'identifier': 'P0A9Q7',
#    'measurement': 8.556352156468494e-06,
#    'uncertainty': 2.013309662417036e-06},
#   {'identifier': 'P0CE47',
#    'measurement': 0.0004452830786651792,
#    'uncertainty': 4.207925093385943e-05},
#   {'identifier': 'P25665',
#    'measurement': 9.098554311260992e-05,
#    'uncertainty': 5.904961748008385e-06},
#   {'identifier': 'P0A6F5',
#    'measurement': 4.010779049390581e-05,
#    'uncertainty': 1.6404086312007475e-06},
#   {'identifier': 'P00968',
#    'measurement': 7.840236102968967e-06,
#    'uncertainty': 3.2850589271439965e-07},
#   {'identifier': 'P09373',
#    'measurement': 8.140087652463841e-06,
#    'uncertainty': 8.978516680667616e-07},
#   {'identifier': 'P0A6Y8',
#    'measurement': 3.2816106343248056e-05,
#    'uncertainty': 2.592472401116596e-06},
#   {'identifier': 'P0A705',
#    'measurement': 5.374398066534632e-06,
#    'uncertainty': 1.0066247578619364e-06},
#   {'identifier': 'P05793',
#    'measurement': 5.8802652688589296e-05,
#    'uncertainty': 5.997870574236105e-06},
#   {'identifier': 'P00864',
#    'measurement': 6.408003995969911e-06,
#    'uncertainty': 4.2292826373401423e-07},
#   {'identifier': 'P00957',
#    'measurement': 3.4359459906824622e-06,
#    'uncertainty': 2.181825704083364e-07},
#   {'identifier': 'P0A6M8',
#    'measurement': 6.883709660080311e-05,
#    'uncertainty': 6.87682595042023e-06},
#   {'identifier': 'P00961',
#    'measurement': 5.139808324870993e-06,
#    'uncertainty': 2.63672167065882e-07},
#   {'identifier': 'P76558',
#    'measurement': 8.272375100770405e-07,
#    'uncertainty': 2.5751903688698266e-07},
#   {'identifier': 'P0AG67',
#    'measurement': 4.197392543135039e-05,
#    'uncertainty': 5.55734772711079e-06},
#   {'identifier': 'P07813',
#    'measurement': 3.2560350609855368e-06,
#    'uncertainty': 3.3276678323272194e-07},
#   {'identifier': 'P00561',
#    'measurement': 1.0059137569231046e-05,
#    'uncertainty': 4.375724842615505e-07},
#   {'identifier': 'P0AFG3',
#    'measurement': 3.009098490813285e-06,
#    'uncertainty': 3.737300325590101e-07},
#   {'identifier': 'P00956',
#    'measurement': 3.820461507093538e-06,
#    'uncertainty': 1.5778506024296313e-07},
#   {'identifier': 'P25553',
#    'measurement': 6.17517808695036e-06,
#    'uncertainty': 1.922950456276342e-06},
#   {'identifier': 'P10408',
#    'measurement': 1.2452658467257795e-06,
#    'uncertainty': 2.3759672355527873e-07},
#   {'identifier': 'P21889',
#    'measurement': 4.007427767366815e-06,
#    'uncertainty': 3.0015633977577446e-07},
#   {'identifier': 'P07395',
#    'measurement': 8.859731371251546e-06,
#    'uncertainty': 1.335161517647608e-06},
#   {'identifier': 'P07118',
#    'measurement': 3.0320283151864237e-06,
#    'uncertainty': 2.70456925714629e-07},
#   {'identifier': 'P23847',
#    'measurement': 8.711569429148194e-06,
#    'uncertainty': 5.555367824967803e-06},
#   {'identifier': 'P06959',
#    'measurement': 1.5975032257500546e-05,
#    'uncertainty': 2.140654322505074e-06},
#   {'identifier': 'P13029',
#    'measurement': 3.878667984348427e-06,
#    'uncertainty': 1.0418102205959874e-06},
#   {'identifier': 'P0AES4',
#    'measurement': 1.32287448306563e-06,
#    'uncertainty': 2.346779332958427e-07},
#   {'identifier': 'P08200',
#    'measurement': 5.9388245126426354e-05,
#    'uncertainty': 6.081356300946057e-06},
#   {'identifier': 'P0ABB4',
#    'measurement': 4.260714135057781e-05,
#    'uncertainty': 1.964189216261636e-06},
#   {'identifier': 'P04825',
#    'measurement': 2.285927106737408e-06,
#    'uncertainty': 2.0093299268221816e-07},
#   {'identifier': 'P0AD61',
#    'measurement': 1.5701638197666986e-05,
#    'uncertainty': 4.3336521425560863e-07},
#   {'identifier': 'P0A9G6',
#    'measurement': 4.9692457081877316e-05,
#    'uncertainty': 2.544253802592119e-05},
#   {'identifier': 'P0AC33',
#    'measurement': 2.3847017348063092e-06,
#    'uncertainty': 2.577862575325619e-07},
#   {'identifier': 'P09546',
#    'measurement': 2.2577057844320088e-07,
#    'uncertainty': 1.3236929014124865e-07},
#   {'identifier': 'P21179',
#    'measurement': 2.0813225200232572e-06,
#    'uncertainty': 1.0901967359881822e-06},
#   {'identifier': 'P0A6Z3',
#    'measurement': 3.6969932220074133e-06,
#    'uncertainty': 3.793115045779606e-07},
#   {'identifier': 'P0A6P1',
#    'measurement': 3.505088230330693e-05,
#    'uncertainty': 4.91763878715396e-06},
#   {'identifier': 'P08839',
#    'measurement': 1.7917011998640892e-05,
#    'uncertainty': 1.3043584735010568e-06},
#   {'identifier': 'P0A6E4',
#    'measurement': 1.4683906762028492e-05,
#    'uncertainty': 1.6724969801950451e-06},
#   {'identifier': 'P0A6F3',
#    'measurement': 8.74860991467403e-07,
#    'uncertainty': 1.2702981596106697e-07},
#   {'identifier': 'P0A9M8',
#    'measurement': 2.024879875412457e-06,
#    'uncertainty': 3.926242078424755e-07},
#   {'identifier': 'P0A850',
#    'measurement': 4.397058398445745e-05,
#    'uncertainty': 4.410249573641082e-06},
#   {'identifier': 'P0A940',
#    'measurement': 3.578816434853551e-06,
#    'uncertainty': 2.258233170392589e-07},
#   {'identifier': 'P05055',
#    'measurement': 5.593113314401483e-06,
#    'uncertainty': 9.754389620316186e-07},
#   {'identifier': 'P0A6T1',
#    'measurement': 8.115393995446616e-06,
#    'uncertainty': 3.132542082242394e-07},
#   {'identifier': 'P0AC41',
#    'measurement': 3.6740633976342767e-06,
#    'uncertainty': 2.715132850851729e-07},
#   {'identifier': 'P0A9M0',
#    'measurement': 2.00900538161567e-06,
#    'uncertainty': 3.1119493361226725e-07},
#   {'identifier': 'P27550',
#    'measurement': 1.7550134808670692e-06,
#    'uncertainty': 9.731549751407897e-07},
#   {'identifier': 'P23538',
#    'measurement': 2.0425182018533325e-06,
#    'uncertainty': 2.4714470242425323e-08},
#   {'identifier': 'P04079',
#    'measurement': 6.82603233261865e-06,
#    'uncertainty': 1.4471188545151535e-07},
#   {'identifier': 'P22523',
#    'measurement': 3.510026961734137e-07,
#    'uncertainty': 5.591472950042481e-08},
#   {'identifier': 'P0A9W3',
#    'measurement': 4.534813727948978e-06,
#    'uncertainty': 1.8955521382826726e-07},
#   {'identifier': 'P0AES6',
#    'measurement': 1.4851470863216806e-06,
#    'uncertainty': 1.1257414914318335e-07},
#   {'identifier': 'P21513',
#    'measurement': 1.4957300821862054e-06,
#    'uncertainty': 2.957058372482128e-07},
#   {'identifier': 'P0A8M3',
#    'measurement': 1.6562388527981683e-06,
#    'uncertainty': 2.6499821644770693e-07},
#   {'identifier': 'P0A799',
#    'measurement': 7.062209523661966e-05,
#    'uncertainty': 6.5749170665292925e-06},
#   {'identifier': 'P00370',
#    'measurement': 1.1187990461447052e-05,
#    'uncertainty': 1.0371267157761416e-06},
#   {'identifier': 'P0A825',
#    'measurement': 4.3231538106584776e-05,
#    'uncertainty': 2.8748972840878887e-06},
#   {'identifier': 'P23843',
#    'measurement': 1.01508568667236e-05,
#    'uncertainty': 3.817737267574745e-06},
#   {'identifier': 'P0A9A6',
#    'measurement': 1.0706464149611163e-05,
#    'uncertainty': 7.665828331121592e-07},
#   {'identifier': 'P08997',
#    'measurement': 7.748516805476416e-06,
#    'uncertainty': 3.829317005266444e-06},
#   {'identifier': 'P33602',
#    'measurement': 1.647419689577731e-06,
#    'uncertainty': 1.3245254304204953e-07},
#   {'identifier': 'P17846',
#    'measurement': 5.3109000913474816e-06,
#    'uncertainty': 1.0313767977396808e-06},
#   {'identifier': 'P00582',
#    'measurement': 7.760863633985028e-07,
#    'uncertainty': 5.2929089983777896e-08},
#   {'identifier': 'P0A9B2',
#    'measurement': 8.304653238157205e-05,
#    'uncertainty': 6.419496953095521e-06},
#   {'identifier': 'P15639',
#    'measurement': 4.811735453070717e-06,
#    'uncertainty': 1.9872467421182066e-07},
#   {'identifier': 'P0A853',
#    'measurement': 1.0812294108256412e-06,
#    'uncertainty': 8.950417062814659e-07},
#   {'identifier': 'P25516',
#    'measurement': 1.0494804232320664e-06,
#    'uncertainty': 4.2367524685878527e-07},
#   {'identifier': 'P33599',
#    'measurement': 1.6491835222218184e-06,
#    'uncertainty': 2.4754244668549496e-07},
#   {'identifier': 'P0A9C5',
#    'measurement': 3.1445608378792075e-05,
#    'uncertainty': 5.575306365559833e-06},
#   {'identifier': 'P09151',
#    'measurement': 4.7817502981212295e-06,
#    'uncertainty': 2.959903434537041e-07},
#   {'identifier': 'P37685',
#    'measurement': 1.0388974273675414e-06,
#    'uncertainty': 3.5748460475717103e-07},
#   {'identifier': 'P06149',
#    'measurement': 1.0724102476052037e-06,
#    'uncertainty': 2.228468494523614e-07},
#   {'identifier': 'P37330',
#    'measurement': 4.974008056326768e-07,
#    'uncertainty': 5.95040583778371e-07},
#   {'identifier': 'P0ABH7',
#    'measurement': 1.7058025500970274e-05,
#    'uncertainty': 5.6530296510215485e-06},
#   {'identifier': 'P35340',
#    'measurement': 4.2949324883530775e-06,
#    'uncertainty': 3.255558826171633e-07},
#   {'identifier': 'P0A910',
#    'measurement': 0.0002110954908443928,
#    'uncertainty': 5.425154114700893e-06},
#   {'identifier': 'P17169',
#    'measurement': 7.0994263924522124e-06,
#    'uncertainty': 4.912803063576931e-07},
#   {'identifier': 'P16659',
#    'measurement': 7.623284687746201e-06,
#    'uncertainty': 3.3542452626083297e-07},
#   {'identifier': 'P60422',
#    'measurement': 2.50305490522458e-05,
#    'uncertainty': 6.252631153251e-06},
#   {'identifier': 'P00452',
#    'measurement': 9.877462806890035e-07,
#    'uncertainty': 1.1062758343716838e-07},
#   {'identifier': 'P27298',
#    'measurement': 2.381174069518133e-06,
#    'uncertainty': 1.3620315677643723e-07},
#   {'identifier': 'P0A6B7',
#    'measurement': 2.4134522069049344e-05,
#    'uncertainty': 1.3925619233841473e-06},
#   {'identifier': 'P13035',
#    'measurement': 2.3811740695181342e-07,
#    'uncertainty': 3.845596122271785e-08},
#   {'identifier': 'P0ABB0',
#    'measurement': 2.5667292636761388e-05,
#    'uncertainty': 1.96098115744857e-06},
#   {'identifier': 'P38038',
#    'measurement': 5.850632880438258e-06,
#    'uncertainty': 6.722377179623559e-07},
#   {'identifier': 'P0AAI3',
#    'measurement': 3.9439297921796634e-06,
#    'uncertainty': 3.482490006494643e-07},
#   {'identifier': 'P0AG30',
#    'measurement': 5.720109264775783e-06,
#    'uncertainty': 6.53808488963872e-07},
#   {'identifier': 'P0A817',
#    'measurement': 2.2046144218449742e-05,
#    'uncertainty': 2.731517268665924e-06},
#   {'identifier': 'P0ADG7',
#    'measurement': 1.9820187421611312e-05,
#    'uncertainty': 1.5955250874397103e-06},
#   {'identifier': 'Q59385',
#    'measurement': 4.8840525914783034e-06,
#    'uncertainty': 2.930431554886983e-07},
#   {'identifier': 'P0AFF6',
#    'measurement': 9.835130823431937e-06,
#    'uncertainty': 1.5972252457253462e-06},
#   {'identifier': 'P0A7Z4',
#    'measurement': 2.5707860787575407e-05,
#    'uncertainty': 3.223765742761955e-06},
#   {'identifier': 'P0A8N3',
#    'measurement': 4.5242307320844525e-06,
#    'uncertainty': 4.031089582287248e-07},
#   {'identifier': 'P00959',
#    'measurement': 3.672299564990188e-06,
#    'uncertainty': 2.750552374177652e-07},
#   {'identifier': 'P00350',
#    'measurement': 2.487004028163384e-05,
#    'uncertainty': 6.938741238575842e-07},
#   {'identifier': 'P0AEE5',
#    'measurement': 5.684832611894032e-06,
#    'uncertainty': 7.953080824039752e-07},
#   {'identifier': 'P0AD96',
#    'measurement': 4.0511708169401835e-05,
#    'uncertainty': 1.9162037964127072e-06},
#   {'identifier': 'P13009',
#    'measurement': 7.425735431608403e-07,
#    'uncertainty': 4.990094210040846e-08},
#   {'identifier': 'P61889',
#    'measurement': 9.372653904152193e-05,
#    'uncertainty': 2.5980996622309868e-05},
#   {'identifier': 'P32132',
#    'measurement': 5.3144277566356565e-06,
#    'uncertainty': 8.90698092012136e-07},
#   {'identifier': 'P77804',
#    'measurement': 2.1430566625663203e-06,
#    'uncertainty': 1.2065409010248384e-07},
#   {'identifier': 'P06971',
#    'measurement': 1.5398258982883931e-06,
#    'uncertainty': 1.0886569100898941e-07},
#   {'identifier': 'P0ADY1',
#    'measurement': 1.864371104800494e-06,
#    'uncertainty': 2.593340206777487e-07},
#   {'identifier': 'P30850',
#    'measurement': 2.2224291315502584e-06,
#    'uncertainty': 2.564683217808998e-07},
#   {'identifier': 'P00962',
#    'measurement': 1.7620688114434189e-06,
#    'uncertainty': 3.118861796254852e-08},
#   {'identifier': 'P0AB71',
#    'measurement': 3.5363080681310415e-05,
#    'uncertainty': 2.6204042784851017e-06},
#   {'identifier': 'P0ABK5',
#    'measurement': 0.00012930304347276694,
#    'uncertainty': 2.902853325963617e-05},
#   {'identifier': 'P0ACY3',
#    'measurement': 9.154291422814156e-07,
#    'uncertainty': 3.2635048922332466e-07},
#   {'identifier': 'P23845',
#    'measurement': 2.681025619013009e-06,
#    'uncertainty': 6.214617384872156e-07},
#   {'identifier': 'P23865',
#    'measurement': 8.924993179082783e-07,
#    'uncertainty': 1.2941240109670033e-08},
#   {'identifier': 'P21177',
#    'measurement': 3.0514304742713863e-07,
#    'uncertainty': 9.886634736639294e-08},
#   {'identifier': 'P36938',
#    'measurement': 2.3705910736536087e-06,
#    'uncertainty': 3.389945235324661e-07},
#   {'identifier': 'P0A870',
#    'measurement': 1.8747777174006104e-05,
#    'uncertainty': 1.0086304119615284e-06},
#   {'identifier': 'P68767',
#    'measurement': 1.8978839250381568e-06,
#    'uncertainty': 3.717954609149749e-07},
#   {'identifier': 'P00934',
#    'measurement': 2.5767831097474382e-05,
#    'uncertainty': 2.2752994859069883e-06},
#   {'identifier': 'P0A9P0',
#    'measurement': 2.2217235984926232e-05,
#    'uncertainty': 3.043761329934893e-07},
#   {'identifier': 'P75691',
#    'measurement': 2.599889317384984e-06,
#    'uncertainty': 1.4598378517116688e-06},
#   {'identifier': 'P0ABZ6',
#    'measurement': 2.740995928911985e-06,
#    'uncertainty': 1.8200212967975586e-07},
#   {'identifier': 'P21499',
#    'measurement': 4.4272199366596405e-07,
#    'uncertainty': 9.748738300524527e-08},
#   {'identifier': 'P0A8M0',
#    'measurement': 9.750466856515736e-06,
#    'uncertainty': 1.5278981564160157e-06},
#   {'identifier': 'P0A8L1',
#    'measurement': 4.458968924253217e-06,
#    'uncertainty': 4.458968924253216e-07},
#   {'identifier': 'P0AEX9',
#    'measurement': 3.7781295236354377e-06,
#    'uncertainty': 1.047675316904107e-06},
#   {'identifier': 'P0A786',
#    'measurement': 1.567694454064976e-05,
#    'uncertainty': 2.7810899615112664e-06},
#   {'identifier': 'P05791',
#    'measurement': 2.11483534026092e-06,
#    'uncertainty': 1.1039440476162005e-07},
#   {'identifier': 'P77748',
#    'measurement': 4.0744534078421396e-07,
#    'uncertainty': 4.534866642928302e-08},
#   {'identifier': 'P17315',
#    'measurement': 1.0142037703503158e-06,
#    'uncertainty': 5.4969844352987136e-08},
#   {'identifier': 'P0ABH9',
#    'measurement': 9.348313013663784e-07,
#    'uncertainty': 1.689240161569046e-07},
#   {'identifier': 'P0C0V0',
#    'measurement': 5.887673365964096e-06,
#    'uncertainty': 7.595098642093685e-08},
#   {'identifier': 'P31554',
#    'measurement': 9.224844728577658e-07,
#    'uncertainty': 7.702745348362343e-08},
#   {'identifier': 'P06612',
#    'measurement': 6.261605886510648e-07,
#    'uncertainty': 4.827698138499708e-08},
#   {'identifier': 'P11875',
#    'measurement': 1.6597665180863439e-06,
#    'uncertainty': 3.302935370991823e-08},
#   {'identifier': 'P04805',
#    'measurement': 4.517175401508104e-06,
#    'uncertainty': 4.033837633546736e-07},
#   {'identifier': 'P0A7V0',
#    'measurement': 5.142630457101534e-05,
#    'uncertainty': 6.680276963774894e-06},
#   {'identifier': 'P33363',
#    'measurement': 2.769217251217385e-07,
#    'uncertainty': 3.73844328914347e-09},
#   {'identifier': 'P0C8J6',
#    'measurement': 8.711569429148194e-06,
#    'uncertainty': 1.8782143689243504e-06},
#   {'identifier': 'P69786',
#    'measurement': 4.894635587342832e-06,
#    'uncertainty': 1.0210209835197143e-06},
#   {'identifier': 'P05020',
#    'measurement': 7.910789408732466e-06,
#    'uncertainty': 5.86980574127949e-07},
#   {'identifier': 'P11447',
#    'measurement': 5.0851295129042815e-06,
#    'uncertainty': 1.6882629982842208e-07},
#   {'identifier': 'P22106',
#    'measurement': 2.0354628712769827e-06,
#    'uncertainty': 1.3128735519736537e-07},
#   {'identifier': 'P00509',
#    'measurement': 1.2320371018951233e-05,
#    'uncertainty': 2.106783444240661e-07},
#   {'identifier': 'P0A836',
#    'measurement': 1.0958692217715679e-05,
#    'uncertainty': 2.062425875374091e-06},
#   {'identifier': 'P0AGE9',
#    'measurement': 1.2212777227661895e-05,
#    'uncertainty': 2.392483058898965e-06},
#   {'identifier': 'P0A6H1',
#    'measurement': 5.734219925928483e-06,
#    'uncertainty': 2.528790987334461e-07},
#   {'identifier': 'P0A6H5',
#    'measurement': 2.4111592244676217e-06,
#    'uncertainty': 7.884490664009122e-08},
#   {'identifier': 'P30958',
#    'measurement': 1.2875978301838795e-07,
#    'uncertainty': 2.275185365934916e-08},
#   {'identifier': 'P08312',
#    'measurement': 8.956742166676358e-06,
#    'uncertainty': 2.7228496186696125e-07},
#   {'identifier': 'P24182',
#    'measurement': 3.1925370857983867e-06,
#    'uncertainty': 3.5149833314640237e-07},
#   {'identifier': 'P0A953',
#    'measurement': 2.375353421792645e-05,
#    'uncertainty': 8.741300592196931e-07},
#   {'identifier': 'Q47146',
#    'measurement': 1.5168960739152553e-07,
#    'uncertainty': 6.472595547396396e-08},
#   {'identifier': 'P0C8J8',
#    'measurement': 2.4922955260956465e-06,
#    'uncertainty': 3.7957660862436704e-07},
#   {'identifier': 'P0A7D4',
#    'measurement': 1.2105183436372556e-05,
#    'uncertainty': 9.18783422820677e-07},
#   {'identifier': 'P0A7E5',
#    'measurement': 1.6932793383240066e-06,
#    'uncertainty': 2.2266623298960681e-07},
#   {'identifier': 'P00895',
#    'measurement': 1.9225775820553814e-06,
#    'uncertainty': 3.089582174362999e-07},
#   {'identifier': 'P09832',
#    'measurement': 5.229763789719456e-06,
#    'uncertainty': 3.357508352999891e-07},
#   {'identifier': 'P08142',
#    'measurement': 3.2154669101715237e-06,
#    'uncertainty': 1.295833164799124e-07},
#   {'identifier': 'P26616',
#    'measurement': 9.313036360782032e-07,
#    'uncertainty': 1.7229117267446758e-08},
#   {'identifier': 'P07014',
#    'measurement': 4.3760687899811035e-06,
#    'uncertainty': 4.91870131993876e-07},
#   {'identifier': 'P37689',
#    'measurement': 4.6847395026964175e-06,
#    'uncertainty': 2.276783398310459e-07},
#   {'identifier': 'P38054',
#    'measurement': 6.279244212951523e-07,
#    'uncertainty': 9.45026254049204e-08},
#   {'identifier': 'P0ABC7',
#    'measurement': 2.379410236874046e-06,
#    'uncertainty': 7.875847884053093e-08},
#   {'identifier': 'P02930',
#    'measurement': 8.614558633723379e-06,
#    'uncertainty': 8.63178775099083e-07},
#   {'identifier': 'P62399',
#    'measurement': 5.603519927001599e-05,
#    'uncertainty': 7.721650459408203e-06},
#   {'identifier': 'P0ABD5',
#    'measurement': 6.746659863634712e-06,
#    'uncertainty': 2.1386911767722039e-07},
#   {'identifier': 'P0A7A7',
#    'measurement': 3.3865586766480125e-07,
#    'uncertainty': 8.754254179135113e-08},
#   {'identifier': 'P05459',
#    'measurement': 1.299944658692492e-06,
#    'uncertainty': 6.239734361723963e-08},
#   {'identifier': 'P23721',
#    'measurement': 3.2013562490188243e-05,
#    'uncertainty': 2.8876233366149786e-06},
#   {'identifier': 'P0A867',
#    'measurement': 2.5505020033505346e-06,
#    'uncertainty': 5.333099689005968e-07},
#   {'identifier': 'P00944',
#    'measurement': 4.585964874627517e-07,
#    'uncertainty': 8.988491154269932e-09},
#   {'identifier': 'P0AC53',
#    'measurement': 2.1765694828039834e-06,
#    'uncertainty': 1.4387124281334323e-07},
#   {'identifier': 'P08660',
#    'measurement': 6.5614574360055235e-06,
#    'uncertainty': 3.8122067703192096e-07},
#   {'identifier': 'P07023',
#    'measurement': 2.4975870240279084e-06,
#    'uncertainty': 1.2987452524945127e-07},
#   {'identifier': 'P0AEM9',
#    'measurement': 2.0111219807885744e-05,
#    'uncertainty': 2.7411592598148273e-06},
#   {'identifier': 'P0AFG6',
#    'measurement': 9.263649046747584e-06,
#    'uncertainty': 1.5766730677564389e-06},
#   {'identifier': 'P22259',
#    'measurement': 2.023116042768369e-06,
#    'uncertainty': 2.822246879661876e-07},
#   {'identifier': 'P0AFK0',
#    'measurement': 2.2841632740933206e-06,
#    'uncertainty': 1.1260924941280072e-07},
#   {'identifier': 'P0ADE8',
#    'measurement': 2.8397705569808856e-06,
#    'uncertainty': 2.260457363356784e-07},
#   {'identifier': 'P05825',
#    'measurement': 6.596734088887275e-07,
#    'uncertainty': 5.646804380087508e-08},
#   {'identifier': 'P75780',
#    'measurement': 3.562941941056763e-07,
#    'uncertainty': 5.982179519034304e-08},
#   {'identifier': 'P09169',
#    'measurement': 2.453138441396904e-05,
#    'uncertainty': 3.260220988616485e-06},
#   {'identifier': 'P0A698',
#    'measurement': 2.2400674579911323e-07,
#    'uncertainty': 4.408452757326551e-08},
#   {'identifier': 'P18843',
#    'measurement': 6.947736785060687e-06,
#    'uncertainty': 5.071847853094301e-07},
#   {'identifier': 'P0A6P9',
#    'measurement': 6.376255008376336e-05,
#    'uncertainty': 6.465522578493604e-06},
#   {'identifier': 'P27302',
#    'measurement': 6.848962156991788e-06,
#    'uncertainty': 5.260002936569693e-07},
#   {'identifier': 'P0ABP8',
#    'measurement': 4.8752334282578665e-06,
#    'uncertainty': 1.9793447718726944e-07},
#   {'identifier': 'P24171',
#    'measurement': 1.0424250926557163e-06,
#    'uncertainty': 8.245582482906718e-08},
#   {'identifier': 'P37095',
#    'measurement': 5.564891992096082e-06,
#    'uncertainty': 2.153613200941184e-07},
#   {'identifier': 'P09551',
#    'measurement': 1.0866972920223126e-05,
#    'uncertainty': 9.66073892607836e-07},
#   {'identifier': 'P31660',
#    'measurement': 8.290013427211281e-07,
#    'uncertainty': 9.259944998194999e-08},
#   {'identifier': 'P27306',
#    'measurement': 7.849055266189403e-07,
#    'uncertainty': 8.123772200506033e-08},
#   {'identifier': 'Q46856',
#    'measurement': 1.8555519415800568e-06,
#    'uncertainty': 1.3842417484187223e-07},
#   {'identifier': 'P11454',
#    'measurement': 7.584480369576276e-08,
#    'uncertainty': 2.8358372101845694e-08},
#   {'identifier': 'P0AE06',
#    'measurement': 4.273766496624028e-06,
#    'uncertainty': 5.355029420269908e-07},
#   {'identifier': 'P02931',
#    'measurement': 4.236196861304963e-05,
#    'uncertainty': 2.8085985190451912e-06},
#   {'identifier': 'P0A903',
#    'measurement': 3.091998625085399e-06,
#    'uncertainty': 1.9108551503027765e-07},
#   {'identifier': 'P60906',
#    'measurement': 3.3318798646813e-06,
#    'uncertainty': 2.882076082949324e-07},
#   {'identifier': 'P0A7L0',
#    'measurement': 5.0272758021782105e-05,
#    'uncertainty': 7.963204870650284e-06},
#   {'identifier': 'P0AEK4',
#    'measurement': 8.843856877454757e-06,
#    'uncertainty': 3.617137462878995e-07},
#   {'identifier': 'P02943',
#    'measurement': 1.5927408776110184e-06,
#    'uncertainty': 5.968000068408486e-07},
#   {'identifier': 'P00490',
#    'measurement': 4.832901444799768e-07,
#    'uncertainty': 1.2536546347810594e-07},
#   {'identifier': 'P0A796',
#    'measurement': 2.554029668638709e-06,
#    'uncertainty': 2.6561908553842568e-08},
#   {'identifier': 'P00550',
#    'measurement': 1.0053846071298784e-06,
#    'uncertainty': 2.366675365183734e-07},
#   {'identifier': 'P02925',
#    'measurement': 8.886188860912856e-06,
#    'uncertainty': 2.816921868909376e-07},
#   {'identifier': 'P0AB89',
#    'measurement': 3.4094885010211494e-06,
#    'uncertainty': 2.8503323868536813e-07},
#   {'identifier': 'P18335',
#    'measurement': 6.912460132178937e-06,
#    'uncertainty': 2.156687561239829e-07},
#   {'identifier': 'P0A6A6',
#    'measurement': 4.87346959561378e-06,
#    'uncertainty': 5.438792068704978e-07},
#   {'identifier': 'P0A879',
#    'measurement': 9.48412812725852e-06,
#    'uncertainty': 2.1965240742730736e-06},
#   {'identifier': 'P33195',
#    'measurement': 5.944116010574896e-07,
#    'uncertainty': 2.1856514570883888e-07},
#   {'identifier': 'P00562',
#    'measurement': 6.049945969220146e-07,
#    'uncertainty': 1.5754059303849257e-07},
#   {'identifier': 'P37902',
#    'measurement': 8.706277931215934e-06,
#    'uncertainty': 1.009928240021048e-07},
#   {'identifier': 'P0A9X4',
#    'measurement': 5.780079574674757e-06,
#    'uncertainty': 7.28868034366487e-07},
#   {'identifier': 'P06715',
#    'measurement': 1.739138987070281e-06,
#    'uncertainty': 1.5965295901305182e-07},
#   {'identifier': 'P31979',
#    'measurement': 6.931862291263899e-07,
#    'uncertainty': 9.44119644070143e-08},
#   {'identifier': 'P67910',
#    'measurement': 5.111587002565593e-06,
#    'uncertainty': 4.3397373651781894e-07},
#   {'identifier': 'P0AGD7',
#    'measurement': 1.631545195780943e-06,
#    'uncertainty': 8.125095074989097e-08},
#   {'identifier': 'P0AG90',
#    'measurement': 7.584480369576277e-07,
#    'uncertainty': 1.6412815519763063e-07},
#   {'identifier': 'P76116',
#    'measurement': 6.1134439444072974e-06,
#    'uncertainty': 1.1639997270151494e-06},
#   {'identifier': 'P16700',
#    'measurement': 6.903640968958499e-06,
#    'uncertainty': 2.0966357622726966e-06},
#   {'identifier': 'P60785',
#    'measurement': 1.319346817777455e-06,
#    'uncertainty': 2.1650481279728032e-07},
#   {'identifier': 'P06996',
#    'measurement': 5.930181732686605e-05,
#    'uncertainty': 2.348351966143895e-06},
#   {'identifier': 'P0A8J8',
#    'measurement': 8.766248241114909e-07,
#    'uncertainty': 1.0800017833053568e-07},
#   {'identifier': 'P46837',
#    'measurement': 2.980877168507886e-07,
#    'uncertainty': 5.3834641663252414e-08},
#   {'identifier': 'P60240',
#    'measurement': 1.4816194210335054e-07,
#    'uncertainty': 3.287713495273349e-08},
#   {'identifier': 'P0A7V3',
#    'measurement': 2.8136658338483906e-05,
#    'uncertainty': 9.158482289176507e-06},
#   {'identifier': 'P0AB77',
#    'measurement': 3.0337921478305106e-07,
#    'uncertainty': 3.5798747344400033e-08},
#   {'identifier': 'P0A6K6',
#    'measurement': 1.7849986358165566e-06,
#    'uncertainty': 1.0531491951317684e-07},
#   {'identifier': 'P21599',
#    'measurement': 3.354809689054437e-06,
#    'uncertainty': 4.8309259522383886e-08},
#   {'identifier': 'P0A858',
#    'measurement': 1.3119387206722873e-05,
#    'uncertainty': 1.6805935011811997e-06},
#   {'identifier': 'P31120',
#    'measurement': 1.91728608412312e-06,
#    'uncertainty': 2.105180120367185e-07},
#   {'identifier': 'P69797',
#    'measurement': 4.040940587604477e-06,
#    'uncertainty': 2.703389253107395e-07},
#   {'identifier': 'P69441',
#    'measurement': 9.318327858714296e-06,
#    'uncertainty': 9.066733006529007e-07},
#   {'identifier': 'P0AB91',
#    'measurement': 1.1778874397216369e-05,
#    'uncertainty': 1.2202913875516158e-06},
#   {'identifier': 'P21170',
#    'measurement': 2.2841632740933206e-06,
#    'uncertainty': 2.2110700493223343e-07},
#   {'identifier': 'P0AEZ1',
#    'measurement': 7.734406144323714e-06,
#    'uncertainty': 1.5089826387575568e-06},
#   {'identifier': 'P25526',
#    'measurement': 1.2664318384548293e-06,
#    'uncertainty': 1.0128921843961729e-06},
#   {'identifier': 'P00393',
#    'measurement': 1.1676572103859292e-06,
#    'uncertainty': 1.7701683309450683e-07},
#   {'identifier': 'P45464',
#    'measurement': 8.642779956028782e-07,
#    'uncertainty': 5.782019790583254e-08},
#   {'identifier': 'P77243',
#    'measurement': 1.6403643590013812e-07,
#    'uncertainty': 1.2794842000210773e-08},
#   {'identifier': 'P76578',
#    'measurement': 5.1151146678537685e-08,
#    'uncertainty': 1.148343242933171e-08},
#   {'identifier': 'P0ABT2',
#    'measurement': 8.286485761923104e-06,
#    'uncertainty': 4.7788163389010555e-06},
#   {'identifier': 'P0AB24',
#    'measurement': 1.121797561639654e-06,
#    'uncertainty': 1.5850999545968313e-07},
#   {'identifier': 'P08506',
#    'measurement': 1.7426666523584565e-06,
#    'uncertainty': 3.035725308408432e-07},
#   {'identifier': 'P0AEP3',
#    'measurement': 2.8556450507776728e-06,
#    'uncertainty': 1.4106886550841706e-07},
#   {'identifier': 'P0A715',
#    'measurement': 4.665337343611454e-06,
#    'uncertainty': 2.8645171289774327e-07},
#   {'identifier': 'P0A7I4',
#    'measurement': 1.4551619313721928e-06,
#    'uncertainty': 1.5701197239505962e-07},
#   {'identifier': 'P0A7V8',
#    'measurement': 2.4002234620742785e-05,
#    'uncertainty': 4.058777874367605e-06},
#   {'identifier': 'P02359',
#    'measurement': 9.528576709889526e-05,
#    'uncertainty': 3.420759038850341e-06},
#   {'identifier': 'P23830',
#    'measurement': 5.220944626499019e-07,
#    'uncertainty': 1.1063181663551418e-07},
#   {'identifier': 'P06129',
#    'measurement': 1.1923508674031544e-06,
#    'uncertainty': 9.991900268838432e-08},
#   {'identifier': 'P0A9T0',
#    'measurement': 2.002479200832546e-05,
#    'uncertainty': 1.467817254210256e-06},
#   {'identifier': 'P0A991',
#    'measurement': 3.8098785112290146e-06,
#    'uncertainty': 1.7757843740838432e-06},
#   {'identifier': 'P52697',
#    'measurement': 3.1784264246456857e-06,
#    'uncertainty': 1.0644550096138406e-06},
#   {'identifier': 'P33221',
#    'measurement': 4.1961578602841785e-06,
#    'uncertainty': 8.51820045637688e-08},
#   {'identifier': 'P0A9Q9',
#    'measurement': 2.4286211676440882e-05,
#    'uncertainty': 2.9847754150345836e-06},
#   {'identifier': 'P22256',
#    'measurement': 1.0565357538084162e-06,
#    'uncertainty': 8.89814411857448e-07},
#   {'identifier': 'P18956',
#    'measurement': 3.0337921478305106e-07,
#    'uncertainty': 3.525266475779053e-08},
#   {'identifier': 'P21165',
#    'measurement': 2.1853886460244204e-06,
#    'uncertainty': 1.955922838191856e-07},
#   {'identifier': 'P07004',
#    'measurement': 1.665058016018606e-06,
#    'uncertainty': 1.072297362315982e-07},
#   {'identifier': 'P0A7B5',
#    'measurement': 1.199406197979504e-06,
#    'uncertainty': 7.328371869654772e-08},
#   {'identifier': 'P0AEZ3',
#    'measurement': 4.896399419986917e-06,
#    'uncertainty': 4.92577781650684e-07},
#   {'identifier': 'P77735',
#    'measurement': 8.201821795006904e-07,
#    'uncertainty': 2.0750609141367468e-07},
#   {'identifier': 'P0ABJ1',
#    'measurement': 4.614186196932917e-06,
#    'uncertainty': 6.37680532416129e-07},
#   {'identifier': 'P19926',
#    'measurement': 8.836801546878406e-07,
#    'uncertainty': 1.2256643745520348e-07},
#   {'identifier': 'P33136',
#    'measurement': 1.751485815578894e-06,
#    'uncertainty': 2.2016176701826697e-07},
#   {'identifier': 'P0AE78',
#    'measurement': 3.7922401847881385e-07,
#    'uncertainty': 1.2514392609800858e-08},
#   {'identifier': 'P23836',
#    'measurement': 5.233291455007631e-06,
#    'uncertainty': 2.9358765062592804e-07},
#   {'identifier': 'P0ABD3',
#    'measurement': 6.0199608142706595e-06,
#    'uncertainty': 4.551692371670047e-06},
#   {'identifier': 'P09372',
#    'measurement': 1.0415431763336724e-05,
#    'uncertainty': 8.530238614172776e-07},
#   {'identifier': 'P0ACC7',
#    'measurement': 7.214075514317901e-07,
#    'uncertainty': 7.877770461635151e-08},
#   {'identifier': 'P77239',
#    'measurement': 4.115021558656152e-06,
#    'uncertainty': 2.6089236681879997e-07},
#   {'identifier': 'P60438',
#    'measurement': 2.9106766292732026e-05,
#    'uncertainty': 4.1942850227826854e-06},
#   {'identifier': 'P62620',
#    'measurement': 1.0406612600116286e-06,
#    'uncertainty': 1.7691241420197687e-07},
#   {'identifier': 'P18133',
#    'measurement': 1.0459527579438912e-06,
#    'uncertainty': 4.8323017417007784e-08},
#   {'identifier': 'Q46829',
#    'measurement': 6.5085424566829e-07,
#    'uncertainty': 6.853495206887092e-08},
#   {'identifier': 'P07650',
#    'measurement': 2.3811740695181342e-07,
#    'uncertainty': 2.100195529314994e-08},
#   {'identifier': 'P12758',
#    'measurement': 3.0443751436950364e-06,
#    'uncertainty': 2.5146538686921e-07},
#   {'identifier': 'P0A8F0',
#    'measurement': 4.1106119770459334e-05,
#    'uncertainty': 4.842300908960109e-06},
#   {'identifier': 'P0A717',
#    'measurement': 1.3101748880281994e-05,
#    'uncertainty': 1.2525271929549592e-06},
#   {'identifier': 'P23908',
#    'measurement': 3.783421021567701e-06,
#    'uncertainty': 6.61720336672191e-07},
#   {'identifier': 'P0AC38',
#    'measurement': 1.940215908496257e-07,
#    'uncertainty': 1.4823249540911403e-08},
#   {'identifier': 'P0A9D8',
#    'measurement': 1.939510375438622e-05,
#    'uncertainty': 1.1675852460140505e-06},
#   {'identifier': 'P60757',
#    'measurement': 7.0994263924522124e-06,
#    'uncertainty': 2.853969409765789e-07},
#   {'identifier': 'P15288',
#    'measurement': 4.2473090069627154e-06,
#    'uncertainty': 2.943385141825162e-07},
#   {'identifier': 'P15034',
#    'measurement': 1.0882847414019917e-06,
#    'uncertainty': 7.650641732056e-08},
#   {'identifier': 'P00893',
#    'measurement': 7.778501960425905e-07,
#    'uncertainty': 1.5471440399287119e-07},
#   {'identifier': 'P0AEU0',
#    'measurement': 1.8977075417737486e-05,
#    'uncertainty': 1.738300108264753e-06},
#   {'identifier': 'P0A6A3',
#    'measurement': 5.400855556195945e-06,
#    'uncertainty': 4.4070981338558903e-07},
#   {'identifier': 'P05042',
#    'measurement': 8.78388656755578e-07,
#    'uncertainty': 1.7154930466436438e-07},
#   {'identifier': 'P0ABA6',
#    'measurement': 4.0691619099098774e-06,
#    'uncertainty': 1.725324649801788e-07},
#   {'identifier': 'P32176',
#    'measurement': 2.2929824373137585e-08,
#    'uncertainty': 3.0725964660004364e-10},
#   {'identifier': 'P76177',
#    'measurement': 4.8134992857148064e-06,
#    'uncertainty': 2.7196270964288645e-07},
#   {'identifier': 'P45578',
#    'measurement': 1.2152806917762915e-05,
#    'uncertainty': 4.4236217180657033e-07},
#   {'identifier': 'P0A8W8',
#    'measurement': 2.173041817515808e-06,
#    'uncertainty': 2.683706644632023e-07},
#   {'identifier': 'Q46857',
#    'measurement': 5.785371072607021e-07,
#    'uncertainty': 8.284651375973254e-08},
#   {'identifier': 'P39342',
#    'measurement': 3.069068800712261e-07,
#    'uncertainty': 1.0539182261645905e-07},
#   {'identifier': 'P28635',
#    'measurement': 5.2710374735911045e-05,
#    'uncertainty': 2.9148837228958803e-06},
#   {'identifier': 'P0AAB6',
#    'measurement': 8.581045813485719e-06,
#    'uncertainty': 1.190191054330469e-06},
#   {'identifier': 'P0A749',
#    'measurement': 1.146491218656879e-06,
#    'uncertainty': 8.54135957899375e-08},
#   {'identifier': 'P37759',
#    'measurement': 1.7797071378842938e-06,
#    'uncertainty': 1.804623037814674e-07},
#   {'identifier': 'P0A7G6',
#    'measurement': 2.6704426231484845e-06,
#    'uncertainty': 1.5248227378177847e-07},
#   {'identifier': 'P15042',
#    'measurement': 5.115114667853769e-07,
#    'uncertainty': 4.158588224965114e-08},
#   {'identifier': 'P21507',
#    'measurement': 5.309136258703394e-07,
#    'uncertainty': 1.1037694281844356e-07},
#   {'identifier': 'P07604',
#    'measurement': 2.3282590901955085e-07,
#    'uncertainty': 3.4388386762187656e-08},
#   {'identifier': 'P0AE18',
#    'measurement': 2.6087084806054227e-06,
#    'uncertainty': 3.524365157297925e-07},
#   {'identifier': 'P0A7W1',
#    'measurement': 3.1823068564626785e-05,
#    'uncertainty': 6.040018413566164e-06},
#   {'identifier': 'P02358',
#    'measurement': 3.078240730461516e-05,
#    'uncertainty': 3.1890573967581298e-06},
#   {'identifier': 'P0AEI1',
#    'measurement': 1.7056261668326186e-06,
#    'uncertainty': 1.1751764289476745e-07},
#   {'identifier': 'P0AA39',
#    'measurement': 2.681025619013009e-07,
#    'uncertainty': 3.2976615113860026e-08},
#   {'identifier': 'P0AGJ9',
#    'measurement': 4.0162469305872526e-06,
#    'uncertainty': 4.875723773732926e-07},
#   {'identifier': 'P0A6W9',
#    'measurement': 9.701079542481284e-07,
#    'uncertainty': 4.132659885097028e-08},
#   {'identifier': 'P23893',
#    'measurement': 5.130989161650557e-06,
#    'uncertainty': 3.463417684114125e-07},
#   {'identifier': 'P0A887',
#    'measurement': 1.6386005263572936e-06,
#    'uncertainty': 1.5009580821432807e-07},
#   {'identifier': 'P77488',
#    'measurement': 5.256221279380769e-07,
#    'uncertainty': 2.4546553374708183e-08},
#   {'identifier': 'P15877',
#    'measurement': 7.584480369576276e-08,
#    'uncertainty': 2.248798429579366e-08},
#   {'identifier': 'P09424',
#    'measurement': 1.2787786669634422e-06,
#    'uncertainty': 1.2966815683009306e-07},
#   {'identifier': 'P33570',
#    'measurement': 1.3299298136419798e-06,
#    'uncertainty': 6.115017283125824e-07},
#   {'identifier': 'P13482',
#    'measurement': 1.164129545097754e-07,
#    'uncertainty': 9.205936442633038e-08},
#   {'identifier': 'P09323',
#    'measurement': 4.6917948332727654e-07,
#    'uncertainty': 1.2695996818836108e-07},
#   {'identifier': 'P15640',
#    'measurement': 3.730506042245076e-06,
#    'uncertainty': 1.9846292144743809e-07},
#   {'identifier': 'P0A7E1',
#    'measurement': 2.725121435115197e-06,
#    'uncertainty': 3.384600822413075e-07},
#   {'identifier': 'P00963',
#    'measurement': 3.114928449458536e-06,
#    'uncertainty': 1.6777004628783681e-06},
#   {'identifier': 'P04036',
#    'measurement': 5.436132209077695e-06,
#    'uncertainty': 5.593780043140948e-07},
#   {'identifier': 'P04968',
#    'measurement': 2.469365701722509e-07,
#    'uncertainty': 2.316265028215713e-08},
#   {'identifier': 'P04693',
#    'measurement': 3.121983780034887e-06,
#    'uncertainty': 6.80592464047605e-08},
#   {'identifier': 'P0AEQ3',
#    'measurement': 1.1921744841387456e-05,
#    'uncertainty': 4.786580553817063e-06},
#   {'identifier': 'P07001',
#    'measurement': 3.4183076642415867e-06,
#    'uncertainty': 8.070624395274389e-07},
#   {'identifier': 'P0AB67',
#    'measurement': 5.250929781448507e-06,
#    'uncertainty': 1.2113895005801701e-06},
#   {'identifier': 'P37666',
#    'measurement': 3.153732767628461e-06,
#    'uncertainty': 3.6204852172374727e-07},
#   {'identifier': 'P76658',
#    'measurement': 1.4145937805581802e-06,
#    'uncertainty': 1.3127430283579912e-07},
#   {'identifier': 'P31224',
#    'measurement': 4.974008056326768e-07,
#    'uncertainty': 8.664722034121232e-08},
#   {'identifier': 'P0A855',
#    'measurement': 2.980877168507885e-06,
#    'uncertainty': 1.4606298125688642e-07},
#   {'identifier': 'P0ACJ8',
#    'measurement': 3.6123292550912124e-06,
#    'uncertainty': 1.0620248009968164e-07},
#   {'identifier': 'P29217',
#    'measurement': 1.5133684086270802e-06,
#    'uncertainty': 4.464436805449887e-08},
#   {'identifier': 'P30871',
#    'measurement': 5.062199688531144e-07,
#    'uncertainty': 3.670094774185078e-08},
#   {'identifier': 'P63389',
#    'measurement': 9.877462806890037e-08,
#    'uncertainty': 2.3626891034080968e-08},
#   {'identifier': 'P04335',
#    'measurement': 4.374304957337015e-07,
#    'uncertainty': 4.8292326729000664e-08},
#   {'identifier': 'P37329',
#    'measurement': 1.3352213115742422e-06,
#    'uncertainty': 2.439449336246141e-07},
#   {'identifier': 'P0AE08',
#    'measurement': 0.000103161279854746,
#    'uncertainty': 5.343754296475842e-06},
#   {'identifier': 'P0AE52',
#    'measurement': 1.3396308931844607e-05,
#    'uncertainty': 1.2137055892251214e-06},
#   {'identifier': 'P0A6Z1',
#    'measurement': 1.0353697620793664e-06,
#    'uncertainty': 6.657427570170326e-08},
#   {'identifier': 'P0ACA3',
#    'measurement': 8.321762414804855e-06,
#    'uncertainty': 1.0818291139246314e-07},
#   {'identifier': 'P0A9P4',
#    'measurement': 7.829653107104442e-06,
#    'uncertainty': 4.3141388620145475e-07},
#   {'identifier': 'P39099',
#    'measurement': 1.4922024168980302e-06,
#    'uncertainty': 3.0545383473902683e-07},
#   {'identifier': 'P0AEB2',
#    'measurement': 2.379410236874046e-06,
#    'uncertainty': 1.7797988571817863e-07},
#   {'identifier': 'P0AGC3',
#    'measurement': 1.4110661152700049e-07,
#    'uncertainty': 1.1147422310633039e-08},
#   {'identifier': 'P0A9P6',
#    'measurement': 9.877462806890035e-07,
#    'uncertainty': 2.545422165335562e-07},
#   {'identifier': 'P06993',
#    'measurement': 3.704048552583764e-08,
#    'uncertainty': 1.4931019715465152e-08},
#   {'identifier': 'P0AFG0',
#    'measurement': 6.938917621840248e-06,
#    'uncertainty': 7.993633100359969e-07},
#   {'identifier': 'P00579',
#    'measurement': 1.142963553368704e-06,
#    'uncertainty': 1.4218466603906678e-07},
#   {'identifier': 'P07012',
#    'measurement': 2.966766507355185e-06,
#    'uncertainty': 5.933533014710373e-07},
#   {'identifier': 'P0ABU2',
#    'measurement': 4.8717057629696924e-06,
#    'uncertainty': 4.291972777176301e-07},
#   {'identifier': 'P0A6R0',
#    'measurement': 3.7393252054655134e-06,
#    'uncertainty': 2.553959115332945e-07},
#   {'identifier': 'P77718',
#    'measurement': 3.492388635293263e-07,
#    'uncertainty': 7.190828200068827e-08},
#   {'identifier': 'P0A9C3',
#    'measurement': 2.1871524786685082e-06,
#    'uncertainty': 1.7847164225935028e-07},
#   {'identifier': 'P62707',
#    'measurement': 2.1264766357118974e-05,
#    'uncertainty': 1.186573962727239e-06},
#   {'identifier': 'P0AF96',
#    'measurement': 2.796380273936333e-05,
#    'uncertainty': 4.9467967045933725e-06},
#   {'identifier': 'P0A6L0',
#    'measurement': 2.0495735324296824e-06,
#    'uncertainty': 2.566066062601963e-07},
#   {'identifier': 'P0A7D7',
#    'measurement': 1.4442261689788505e-05,
#    'uncertainty': 9.286374266534008e-07},
#   {'identifier': 'P25524',
#    'measurement': 5.406147054128207e-06,
#    'uncertainty': 1.2812568518283848e-07},
#   {'identifier': 'P00888',
#    'measurement': 3.661716569125663e-06,
#    'uncertainty': 4.3501192841212884e-07},
#   {'identifier': 'P27248',
#    'measurement': 1.1676572103859292e-06,
#    'uncertainty': 3.0639325200526783e-07},
#   {'identifier': 'P0A877',
#    'measurement': 7.737933809611893e-06,
#    'uncertainty': 4.96001557196122e-07},
#   {'identifier': 'P0A6F1',
#    'measurement': 1.6326034953673964e-05,
#    'uncertainty': 1.2260852250209144e-06},
#   {'identifier': 'P04816',
#    'measurement': 4.668865008899628e-06,
#    'uncertainty': 5.67267098581305e-07},
#   {'identifier': 'P0ABH0',
#    'measurement': 1.0089122724180536e-06,
#    'uncertainty': 1.1178747978392033e-07},
#   {'identifier': 'P0A9C0',
#    'measurement': 2.4693657017225086e-08,
#    'uncertainty': 1.8643711048004945e-09},
#   {'identifier': 'P08957',
#    'measurement': 6.102860948542773e-07,
#    'uncertainty': 6.841307123316448e-08},
#   {'identifier': 'P10121',
#    'measurement': 2.026643708056545e-06,
#    'uncertainty': 1.819926049834777e-07},
#   {'identifier': 'P11557',
#    'measurement': 1.6068515387637181e-06,
#    'uncertainty': 9.657177747969947e-08},
#   {'identifier': 'P0A8M6',
#    'measurement': 3.576523452416237e-05,
#    'uncertainty': 4.452771698258214e-06},
#   {'identifier': 'P23839',
#    'measurement': 1.2523211773021296e-06,
#    'uncertainty': 7.889623417003416e-08},
#   {'identifier': 'P0A9U3',
#    'measurement': 6.049945969220146e-07,
#    'uncertainty': 2.8495245515026892e-08},
#   {'identifier': 'P0A8E1',
#    'measurement': 1.3987192867613921e-06,
#    'uncertainty': 1.8784800021205504e-07},
#   {'identifier': 'P0A6P5',
#    'measurement': 4.709433159713642e-07,
#    'uncertainty': 8.693613612831384e-08},
#   {'identifier': 'P0ADV7',
#    'measurement': 2.7639257532851228e-06,
#    'uncertainty': 9.093315728308053e-08},
#   {'identifier': 'P00448',
#    'measurement': 3.820461507093538e-05,
#    'uncertainty': 2.1853039820575037e-06},
#   {'identifier': 'P08622',
#    'measurement': 1.2135168591322042e-06,
#    'uncertainty': 1.3142387584401774e-07},
#   {'identifier': 'P0ABC3',
#    'measurement': 2.2753441108728837e-06,
#    'uncertainty': 9.624705588992297e-08},
#   {'identifier': 'P76403',
#    'measurement': 4.674156506831892e-07,
#    'uncertainty': 6.015639424292643e-08},
#   {'identifier': 'P09147',
#    'measurement': 1.0953400719783416e-06,
#    'uncertainty': 4.9618905260618864e-08},
#   {'identifier': 'P37747',
#    'measurement': 1.4745640904571553e-06,
#    'uncertainty': 1.1059230678428666e-08},
#   {'identifier': 'P77211',
#    'measurement': 2.601653150029072e-06,
#    'uncertainty': 2.854013505581892e-07},
#   {'identifier': 'P0A8F8',
#    'measurement': 2.3635357430772587e-07,
#    'uncertainty': 3.200227396126608e-08},
#   {'identifier': 'P0ACQ4',
#    'measurement': 6.96713894414565e-07,
#    'uncertainty': 8.430238122416239e-08},
#   {'identifier': 'P0ACP7',
#    'measurement': 1.4569257640162804e-06,
#    'uncertainty': 1.8808911613450177e-07},
#   {'identifier': 'P0A8N5',
#    'measurement': 8.695694935351405e-07,
#    'uncertainty': 8.713086325222111e-08},
#   {'identifier': 'P0AG55',
#    'measurement': 3.193242618856022e-05,
#    'uncertainty': 4.208693771652237e-06},
#   {'identifier': 'P0A847',
#    'measurement': 1.4922024168980302e-06,
#    'uncertainty': 2.1935375528401047e-07},
#   {'identifier': 'P00954',
#    'measurement': 3.2066477469510864e-06,
#    'uncertainty': 1.0485738132530053e-07},
#   {'identifier': 'P0AAI5',
#    'measurement': 3.3812671787157503e-06,
#    'uncertainty': 2.6373883993982856e-07},
#   {'identifier': 'P0AEK2',
#    'measurement': 8.245917611109092e-06,
#    'uncertainty': 6.753406523498347e-07},
#   {'identifier': 'P0A6T5',
#    'measurement': 2.500409156258449e-05,
#    'uncertainty': 2.235365785695053e-06},
#   {'identifier': 'P30011',
#    'measurement': 1.1129783984192163e-06,
#    'uncertainty': 4.251577481961406e-08},
#   {'identifier': 'P0A6T3',
#    'measurement': 6.5085424566829e-07,
#    'uncertainty': 4.3997747007176384e-08},
#   {'identifier': 'P0A6V8',
#    'measurement': 8.766248241114909e-07,
#    'uncertainty': 7.240921047160912e-08},
#   {'identifier': 'P00946',
#    'measurement': 1.6121430366959803e-06,
#    'uncertainty': 2.2876309690715966e-07},
#   {'identifier': 'P06999',
#    'measurement': 1.6562388527981683e-06,
#    'uncertainty': 6.338426089658592e-07},
#   {'identifier': 'P76015',
#    'measurement': 1.3299298136419798e-06,
#    'uncertainty': 2.736995556475194e-07},
#   {'identifier': 'P0A993',
#    'measurement': 1.665058016018606e-06,
#    'uncertainty': 1.7316603366593507e-07},
#   {'identifier': 'P0AAG8',
#    'measurement': 4.4095816102187664e-08,
#    'uncertainty': 1.2964169934043171e-08},
#   {'identifier': 'P0AG80',
#    'measurement': 1.9931308878188818e-07,
#    'uncertainty': 9.325859424104551e-08},
#   {'identifier': 'P0A6D3',
#    'measurement': 3.6264399162439134e-06,
#    'uncertainty': 3.2311579653733266e-07},
#   {'identifier': 'P06986',
#    'measurement': 3.8857233149247774e-06,
#    'uncertainty': 1.5154320928206627e-07},
#   {'identifier': 'P06988',
#    'measurement': 6.079931124169635e-06,
#    'uncertainty': 3.848596401599378e-07},
#   {'identifier': 'P0AFK9',
#    'measurement': 5.8929648638963585e-06,
#    'uncertainty': 6.71797994484185e-07},
#   {'identifier': 'P76108',
#    'measurement': 1.4463427681517553e-07,
#    'uncertainty': 8.053236533068973e-08},
#   {'identifier': 'D9IX93',
#    'measurement': 5.573711155316521e-07,
#    'uncertainty': 1.375591913132117e-07},
#   {'identifier': 'P0A9J8',
#    'measurement': 2.79391090823461e-06,
#    'uncertainty': 1.50871189044669e-07},
#   {'identifier': 'P30859',
#    'measurement': 3.398905505156625e-06,
#    'uncertainty': 9.979186563139849e-07},
#   {'identifier': 'P00904',
#    'measurement': 1.8079284601896943e-06,
#    'uncertainty': 4.382418587499817e-07},
#   {'identifier': 'P30125',
#    'measurement': 8.092464171073476e-06,
#    'uncertainty': 4.216173833129281e-07},
#   {'identifier': 'Q46851',
#    'measurement': 2.9456005156261356e-07,
#    'uncertainty': 7.897154982393671e-08},
#   {'identifier': 'P77674',
#    'measurement': 5.520796175993896e-07,
#    'uncertainty': 2.0730589640857075e-07},
#   {'identifier': 'P26646',
#    'measurement': 1.934924410563994e-06,
#    'uncertainty': 5.065632106856537e-07},
#   {'identifier': 'P0AEE1',
#    'measurement': 3.838099833534414e-06,
#    'uncertainty': 1.7348211247575548e-07},
#   {'identifier': 'P64451',
#    'measurement': 2.592833986808634e-06,
#    'uncertainty': 6.728404195768407e-07},
#   {'identifier': 'P63224',
#    'measurement': 5.944116010574896e-06,
#    'uncertainty': 6.479086451526638e-07},
#   {'identifier': 'P0ABQ0',
#    'measurement': 4.4448582631005173e-07,
#    'uncertainty': 1.1321053996117012e-07},
#   {'identifier': 'P76372',
#    'measurement': 2.887394038371248e-06,
#    'uncertainty': 3.410012359316445e-07},
#   {'identifier': 'P0AAC0',
#    'measurement': 2.5487381707064467e-06,
#    'uncertainty': 4.832407571659424e-07},
#   {'identifier': 'P0AA16',
#    'measurement': 1.4604534293044554e-06,
#    'uncertainty': 1.0646705499629481e-07},
#   {'identifier': 'P0A9K3',
#    'measurement': 1.2946531607602294e-06,
#    'uncertainty': 3.71565457138186e-08},
#   {'identifier': 'P0ADE6',
#    'measurement': 3.2754372200704985e-06,
#    'uncertainty': 1.5974307322283826e-06},
#   {'identifier': 'P0A8G6',
#    'measurement': 9.35889600952831e-06,
#    'uncertainty': 4.093581114567682e-06},
#   {'identifier': 'P25522',
#    'measurement': 5.150391320735518e-07,
#    'uncertainty': 8.549649592420962e-09},
#   {'identifier': 'P36979',
#    'measurement': 3.7922401847881385e-07,
#    'uncertainty': 7.846144942326659e-08},
# ...
#    'uncertainty': 1.0732411905311457e-07},
#   {'identifier': 'P63177',
#    'measurement': 3.766671448009505e-07,
#    'uncertainty': 7.985343469780151e-09},
#   {'identifier': 'P33643',
#    'measurement': 3.4171864682972825e-07,
#    'uncertainty': 4.6371220374794135e-08},
#   {'identifier': 'P0A951',
#    'measurement': 1.203781596786543e-07,
#    'uncertainty': 9.245042663320649e-09},
#   {'identifier': 'P0AF93',
#    'measurement': 2.1231212517517497e-05,
#    'uncertainty': 1.6921276376461443e-06},
#   {'identifier': 'P0A6Q3',
#    'measurement': 4.389919661829635e-06,
#    'uncertainty': 3.4548667738599235e-07},
#   {'identifier': 'P0A6Q6',
#    'measurement': 7.760508132831956e-06,
#    'uncertainty': 1.3549847199924595e-06},
#   {'identifier': 'P41407',
#    'measurement': 1.566857659043129e-06,
#    'uncertainty': 2.1121241243901385e-07},
#   {'identifier': 'P31808',
#    'measurement': 3.3201073072661103e-07,
#    'uncertainty': 3.0378981861484905e-08},
#   {'identifier': 'P0A794',
#    'measurement': 3.1356569013068823e-06,
#    'uncertainty': 1.5051153126273028e-07},
#   {'identifier': 'P76290',
#    'measurement': 5.086948038033456e-07,
#    'uncertainty': 6.399380631846088e-08},
#   {'identifier': 'P0A7J0',
#    'measurement': 4.329730581990307e-07,
#    'uncertainty': 7.74155828059867e-08},
#   {'identifier': 'P0A6U8',
#    'measurement': 6.271313802613764e-07,
#    'uncertainty': 1.6399485593834994e-07},
#   {'identifier': 'P08194',
#    'measurement': 1.2231974289927777e-07,
#    'uncertainty': 6.226074913573239e-09},
#   {'identifier': 'P31677',
#    'measurement': 2.485226522398025e-07,
#    'uncertainty': 8.007399855166433e-08},
#   {'identifier': 'P76014',
#    'measurement': 6.407224628057405e-08,
#    'uncertainty': 1.8811611507976543e-08},
#   {'identifier': 'P20966',
#    'measurement': 2.698800676666604e-07,
#    'uncertainty': 5.34092653912321e-08},
#   {'identifier': 'P37188',
#    'measurement': 4.983655810696288e-05,
#    'uncertainty': 2.8805530585824543e-06},
#   {'identifier': 'P69828',
#    'measurement': 2.5939551827529377e-05,
#    'uncertainty': 5.369487228298582e-07},
#   {'identifier': 'P0A6I0',
#    'measurement': 1.2697954262877405e-06,
#    'uncertainty': 5.790267143872096e-08},
#   {'identifier': 'P0A9M5',
#    'measurement': 5.787859580678524e-06,
#    'uncertainty': 4.3698339834122847e-07},
#   {'identifier': 'P09029',
#    'measurement': 4.387978078609012e-07,
#    'uncertainty': 3.7999890160754036e-08},
#   {'identifier': 'P39377',
#    'measurement': 2.834711502110247e-07,
#    'uncertainty': 3.5774059156631297e-08},
#   {'identifier': 'P41409',
#    'measurement': 5.999492151726482e-07,
#    'uncertainty': 1.3810830933274354e-07},
#   {'identifier': 'P22564',
#    'measurement': 5.009284709208517e-07,
#    'uncertainty': 4.874034022059888e-08},
#   {'identifier': 'P07639',
#    'measurement': 4.795710554939937e-07,
#    'uncertainty': 1.53462737758078e-09},
#   {'identifier': 'P00887',
#    'measurement': 3.630760622565864e-07,
#    'uncertainty': 5.30091050894616e-09},
#   {'identifier': 'P0AED7',
#    'measurement': 1.3396924222301849e-07,
#    'uncertainty': 2.7852205458165544e-08},
#   {'identifier': 'P60664',
#    'measurement': 1.0795202706666417e-06,
#    'uncertainty': 3.184584798466593e-08},
#   {'identifier': 'P00861',
#    'measurement': 1.4057062517313823e-06,
#    'uncertainty': 5.229227256440744e-08},
#   {'identifier': 'P40874',
#    'measurement': 9.377846955611296e-07,
#    'uncertainty': 3.3197578222863985e-08},
#   {'identifier': 'P09158',
#    'measurement': 9.513757781054935e-07,
#    'uncertainty': 7.744198833778719e-08},
#   {'identifier': 'P0A6L4',
#    'measurement': 2.9317906631414195e-07,
#    'uncertainty': 1.2008614556227254e-07},
#   {'identifier': 'P22731',
#    'measurement': 4.329730581990307e-07,
#    'uncertainty': 1.7405516939601037e-08},
#   {'identifier': 'P69874',
#    'measurement': 3.921998105659382e-07,
#    'uncertainty': 3.5925502647839935e-08},
#   {'identifier': 'Q5H777',
#    'measurement': 1.9027515562109872e-07,
#    'uncertainty': 5.5312987739053405e-08},
#   {'identifier': 'P0ADQ2',
#    'measurement': 3.2424439784411715e-07,
#    'uncertainty': 3.073836891562232e-08},
#   {'identifier': 'P0A9R7',
#    'measurement': 5.999492151726482e-07,
#    'uncertainty': 6.58144289044395e-08},
#   {'identifier': 'P46889',
#    'measurement': 4.46564140743395e-08,
#    'uncertainty': 1.3459443202005924e-08},
#   {'identifier': 'P0A734',
#    'measurement': 5.904354573915931e-06,
#    'uncertainty': 3.383195170853828e-07},
#   {'identifier': 'P60293',
#    'measurement': 7.183857916306787e-08,
#    'uncertainty': 4.777265514344015e-09},
#   {'identifier': 'P61949',
#    'measurement': 1.5155998620186704e-05,
#    'uncertainty': 4.713515570878063e-07},
#   {'identifier': 'P09148',
#    'measurement': 2.2522365359232092e-07,
#    'uncertainty': 1.7342221326608716e-08},
#   {'identifier': 'P0A9S1',
#    'measurement': 2.582305683429197e-07,
#    'uncertainty': 2.7217501903343736e-08},
#   {'identifier': 'P0ACD8',
#    'measurement': 1.9415832206234565e-09,
#    'uncertainty': 1.0752487875812703e-09},
#   {'identifier': 'P23883',
#    'measurement': 1.3591082544364196e-07,
#    'uncertainty': 3.132744526475947e-08},
#   {'identifier': 'P52643',
#    'measurement': 4.4656414074339495e-07,
#    'uncertainty': 1.4383830973344753e-07},
#   {'identifier': 'P76594',
#    'measurement': 6.213066305995062e-08,
#    'uncertainty': 2.269633121579996e-08},
#   {'identifier': 'P77212',
#    'measurement': 5.0481163736209866e-08,
#    'uncertainty': 1.2665723981415055e-08},
#   {'identifier': 'P0A784',
#    'measurement': 9.669084438704814e-07,
#    'uncertainty': 3.886971944359335e-08},
#   {'identifier': 'P07102',
#    'measurement': 1.1649499323740738e-08,
#    'uncertainty': 4.294005450730836e-09},
#   {'identifier': 'P0AD59',
#    'measurement': 2.0308960487721357e-06,
#    'uncertainty': 2.526434684672537e-07},
#   {'identifier': 'P0ADX7',
#    'measurement': 1.9804148850359255e-07,
#    'uncertainty': 4.614366682133706e-09},
#   {'identifier': 'P0ADK0',
#    'measurement': 2.3978552774699693e-06,
#    'uncertainty': 3.88452554950135e-08},
#   {'identifier': 'P65556',
#    'measurement': 1.6891774019424069e-06,
#    'uncertainty': 4.2398352788754414e-08},
#   {'identifier': 'P62517',
#    'measurement': 1.5920982409112346e-07,
#    'uncertainty': 6.296748542803931e-08},
#   {'identifier': 'P27828',
#    'measurement': 1.0096232747241973e-07,
#    'uncertainty': 4.20003282285266e-09},
#   {'identifier': 'P40120',
#    'measurement': 1.281444925611481e-07,
#    'uncertainty': 7.176091583424294e-09},
#   {'identifier': 'P0AF12',
#    'measurement': 4.009369350587439e-06,
#    'uncertainty': 3.079195661251152e-07},
#   {'identifier': 'P75957',
#    'measurement': 7.203273748513023e-07,
#    'uncertainty': 4.574078830305769e-08},
#   {'identifier': 'P08956',
#    'measurement': 2.329899864748148e-08,
#    'uncertainty': 4.14955165911645e-09},
#   {'identifier': 'P36879',
#    'measurement': 5.281106360095803e-07,
#    'uncertainty': 4.879742276728521e-08},
#   {'identifier': 'P60752',
#    'measurement': 1.9415832206234566e-07,
#    'uncertainty': 1.6484041543093148e-08},
#   {'identifier': 'P69428',
#    'measurement': 2.797821420918401e-06,
#    'uncertainty': 2.6831107426607473e-07},
#   {'identifier': 'P0ABU7',
#    'measurement': 1.6736447361774191e-06,
#    'uncertainty': 1.0510488943194194e-07},
#   {'identifier': 'P00803',
#    'measurement': 2.116325710479568e-07,
#    'uncertainty': 1.2105383063943129e-08},
#   {'identifier': 'P0AG93',
#    'measurement': 9.280767794580124e-07,
#    'uncertainty': 1.322509410727667e-07},
#   {'identifier': 'P37177',
#    'measurement': 1.0484549391366665e-07,
#    'uncertainty': 1.873588976237223e-08},
#   {'identifier': 'P39838',
#    'measurement': 6.989699594244446e-08,
#    'uncertainty': 1.005118801652351e-08},
#   {'identifier': 'P39396',
#    'measurement': 2.1357415426858016e-08,
#    'uncertainty': 2.161370441198032e-09},
#   {'identifier': 'P77213',
#    'measurement': 1.4173557510551234e-07,
#    'uncertainty': 3.797096057076675e-08},
#   {'identifier': 'P75838',
#    'measurement': 3.8055031124219744e-07,
#    'uncertainty': 4.688379834503873e-08},
#   {'identifier': 'P0AB43',
#    'measurement': 1.3979399188488892e-07,
#    'uncertainty': 1.3196552833933508e-08},
#   {'identifier': 'P21362',
#    'measurement': 4.67921556170253e-07,
#    'uncertainty': 1.1852453017792508e-07},
#   {'identifier': 'P31130',
#    'measurement': 5.4364330177456786e-08,
#    'uncertainty': 1.8864422571577507e-08},
#   {'identifier': 'P77148',
#    'measurement': 5.630591339808024e-08,
#    'uncertainty': 1.7285915413210636e-08},
#   {'identifier': 'P64483',
#    'measurement': 5.417017185539443e-07,
#    'uncertainty': 8.883908184284687e-08},
#   {'identifier': 'P33218',
#    'measurement': 6.795541272182097e-07,
#    'uncertainty': 9.248731671439836e-08},
#   {'identifier': 'P76402',
#    'measurement': 6.154818809376358e-07,
#    'uncertainty': 1.1244853964730603e-07},
#   {'identifier': 'P0ADS6',
#    'measurement': 1.8095555616210618e-06,
#    'uncertainty': 3.3187249000130263e-07},
#   {'identifier': 'P0ADU5',
#    'measurement': 3.277392476412395e-06,
#    'uncertainty': 6.338477049381569e-07},
#   {'identifier': 'P0ADP9',
#    'measurement': 2.419212692896826e-06,
#    'uncertainty': 6.58025852467937e-08},
#   {'identifier': 'P77214',
#    'measurement': 5.52516337092817e-05,
#    'uncertainty': 1.9382273105216026e-05},
#   {'identifier': 'Q46920',
#    'measurement': 9.513757781054936e-08,
#    'uncertainty': 2.7837255267366742e-08},
#   {'identifier': 'P64530',
#    'measurement': 5.65000717201426e-07,
#    'uncertainty': 5.650007172014258e-08},
#   {'identifier': 'P0A8A8',
#    'measurement': 6.892620433213271e-07,
#    'uncertainty': 5.2935324927077906e-08},
#   {'identifier': 'P0A8X0',
#    'measurement': 2.310484032541913e-07,
#    'uncertainty': 1.1344476599780794e-08},
#   {'identifier': 'Q46868',
#    'measurement': 2.085260378949592e-06,
#    'uncertainty': 1.4430001822331177e-07},
#   {'identifier': 'P0AF36',
#    'measurement': 8.473069174800765e-06,
#    'uncertainty': 1.3582329887205627e-06},
#   {'identifier': 'P66948',
#    'measurement': 4.4850572396401855e-07,
#    'uncertainty': 4.9694434215213245e-08},
#   {'identifier': 'P23827',
#    'measurement': 3.883166441246913e-07,
#    'uncertainty': 1.1637849824416994e-07},
#   {'identifier': 'P0AFZ3',
#    'measurement': 4.5238889040526544e-07,
#    'uncertainty': 7.903233915379986e-08},
#   {'identifier': 'P75736',
#    'measurement': 4.019077266690555e-07,
#    'uncertainty': 2.4034082054809515e-08},
#   {'identifier': 'P21829',
#    'measurement': 5.921828822901543e-07,
#    'uncertainty': 3.807735933125692e-08},
#   {'identifier': 'P67095',
#    'measurement': 1.139709350505969e-06,
#    'uncertainty': 5.242663012327457e-08},
#   {'identifier': 'P77775',
#    'measurement': 2.1357415426858026e-07,
#    'uncertainty': 4.06004467264571e-08},
#   {'identifier': 'P67080',
#    'measurement': 2.6405531800479014e-07,
#    'uncertainty': 3.1924287946779114e-08},
#   {'identifier': 'P46852',
#    'measurement': 1.9998307172421602e-07,
#    'uncertainty': 3.029743536621873e-08},
#   {'identifier': 'P37648',
#    'measurement': 8.9312828148679e-08,
#    'uncertainty': 1.7683939973438442e-08},
#   {'identifier': 'P42641',
#    'measurement': 6.310145467026233e-07,
#    'uncertainty': 9.995270419769556e-08},
#   {'identifier': 'Q5H776',
#    'measurement': 6.989699594244446e-08,
#    'uncertainty': 2.9713212975133126e-08},
#   {'identifier': 'P75876',
#    'measurement': 3.2424439784411715e-07,
#    'uncertainty': 8.4660212277099e-08},
#   {'identifier': 'Q46948',
#    'measurement': 7.028531258656912e-07,
#    'uncertainty': 4.6950588807828175e-08},
#   {'identifier': 'P64429',
#    'measurement': 1.8639198917985178e-07,
#    'uncertainty': 5.259981934655418e-08},
#   {'identifier': 'P64596',
#    'measurement': 1.0736955210047717e-06,
#    'uncertainty': 3.99414733813775e-08},
#   {'identifier': 'P27848',
#    'measurement': 1.2193142625515309e-06,
#    'uncertainty': 3.682329072905623e-08},
#   {'identifier': 'P75931',
#    'measurement': 5.4364330177456786e-08,
#    'uncertainty': 1.016612974318442e-09},
#   {'identifier': 'P0A6J1',
#    'measurement': 8.737124492805556e-07,
#    'uncertainty': 5.72281654278764e-08},
#   {'identifier': 'P0AFJ7',
#    'measurement': 3.6501764547720974e-07,
#    'uncertainty': 6.245451914115058e-08},
#   {'identifier': 'P0AGD3',
#    'measurement': 1.135826184064722e-05,
#    'uncertainty': 6.019878775543027e-07},
#   {'identifier': 'P0AGD1',
#    'measurement': 3.766671448009505e-07,
#    'uncertainty': 1.1676681488829469e-08},
#   {'identifier': 'P0A9L3',
#    'measurement': 6.2441316375250354e-06,
#    'uncertainty': 3.927558800003248e-07},
#   {'identifier': 'P0A9N4',
#    'measurement': 2.174573207098272e-07,
#    'uncertainty': 3.629362682647016e-08},
#   {'identifier': 'P63284',
#    'measurement': 2.0192465494483946e-07,
#    'uncertainty': 2.148478328613093e-08},
#   {'identifier': 'P77544',
#    'measurement': 1.7280090663548762e-07,
#    'uncertainty': 2.602381653930444e-08},
#   {'identifier': 'P0ACA1',
#    'measurement': 1.071753937784148e-06,
#    'uncertainty': 2.879802830826005e-07},
#   {'identifier': 'P0AA25',
#    'measurement': 3.460483774117186e-05,
#    'uncertainty': 1.3772725420986404e-06},
#   {'identifier': 'P0AAN3',
#    'measurement': 4.8539580515586416e-08,
#    'uncertainty': 9.21766633990986e-09},
#   {'identifier': 'P08395',
#    'measurement': 8.542966170743206e-08,
#    'uncertainty': 1.1934523740528264e-08},
#   {'identifier': 'P07017',
#    'measurement': 3.883166441246913e-09,
#    'uncertainty': 2.7570481732853083e-09},
#   {'identifier': 'P0A9H7',
#    'measurement': 4.8539580515586416e-08,
#    'uncertainty': 5.790771955509459e-09},
#   {'identifier': 'P29012',
#    'measurement': 9.319599458992589e-08,
#    'uncertainty': 1.3243150831228472e-08},
#   {'identifier': 'P37760',
#    'measurement': 1.3261013396858207e-06,
#    'uncertainty': 1.604582621019843e-07},
#   {'identifier': 'P37194',
#    'measurement': 1.4523042490263456e-06,
#    'uncertainty': 1.2475293499136305e-07},
#   {'identifier': 'P37645',
#    'measurement': 4.077324763309258e-08,
#    'uncertainty': 1.6354149625633434e-08},
#   {'identifier': 'P37665',
#    'measurement': 2.6405531800479014e-07,
#    'uncertainty': 5.2520602751152745e-08},
#   {'identifier': 'P39285',
#    'measurement': 1.941583220623457e-08,
#    'uncertainty': 5.7898011638991485e-09},
#   {'identifier': 'P02929',
#    'measurement': 1.8445040595922834e-07,
#    'uncertainty': 1.0605898342655631e-08},
#   {'identifier': 'Q6BF17',
#    'measurement': 2.329899864748148e-08,
#    'uncertainty': 9.293970560480362e-09},
#   {'identifier': 'P77552',
#    'measurement': 1.4561874154675925e-07,
#    'uncertainty': 1.2028108051762309e-08},
#   {'identifier': 'P0ADA5',
#    'measurement': 7.187741082748036e-06,
#    'uncertainty': 6.361150858232014e-07},
#   {'identifier': 'P77338',
#    'measurement': 5.824749661870369e-09,
#    'uncertainty': 1.6728681028891699e-09},
#   {'identifier': 'P0AFQ7',
#    'measurement': 4.8539580515586416e-08,
#    'uncertainty': 7.072216881120941e-09},
#   {'identifier': 'P23909',
#    'measurement': 3.1065331529975304e-08,
#    'uncertainty': 1.0030995551029024e-08},
#   {'identifier': 'P0AFY8',
#    'measurement': 1.9493495535059503e-06,
#    'uncertainty': 1.5341380986091833e-07},
#   {'identifier': 'P0A9H1',
#    'measurement': 3.3201073072661103e-07,
#    'uncertainty': 3.296866556115248e-08},
#   {'identifier': 'P0A8W5',
#    'measurement': 5.125779702445924e-07,
#    'uncertainty': 7.242726719556094e-08},
#   {'identifier': 'P0A8U6',
#    'measurement': 1.1533004330503328e-06,
#    'uncertainty': 8.430626165597935e-08},
#   {'identifier': 'P45425',
#    'measurement': 2.329899864748148e-08,
#    'uncertainty': 1.3569336812293216e-08},
#   {'identifier': 'P0A9F1',
#    'measurement': 2.310484032541913e-07,
#    'uncertainty': 4.586310804595698e-08},
#   {'identifier': 'P0A8D0',
#    'measurement': 2.718216508872839e-07,
#    'uncertainty': 4.5448580028353856e-08},
#   {'identifier': 'P0A7D1',
#    'measurement': 8.659461163980616e-07,
#    'uncertainty': 5.06578478092866e-08},
#   {'identifier': 'P0A7U3',
#    'measurement': 2.3570820298368758e-05,
#    'uncertainty': 1.4566766944391897e-06},
#   {'identifier': 'P68679',
#    'measurement': 3.17351777410904e-05,
#    'uncertainty': 2.5991110569953028e-06},
#   {'identifier': 'P0A873',
#    'measurement': 9.707916103117283e-08,
#    'uncertainty': 3.2676845603092775e-08},
#   ...]}

# %%
from simulations.modeling.driven import (
    adjust_fluxes2model,
    flexibilize_proteomics,
    minimize_distance,
)

# %%
# eColi_Model.solver = 'glpk'

# %%
data = pd.read_csv(proteomics_dataset)
cols_measurements = data.columns[data.columns.get_loc("glucose"):data.columns.get_loc("fructose")]

growth_rates = pd.read_csv(f"{RAW_INTERNAL}/proteomics/growth_conditions.csv")
growth_rates = growth_rates.drop(growth_rates.columns.difference(['Growth condition','Growth rate (h-1)', 'Stdev']), 1)
growth_rates = growth_rates.drop([0,1], axis=0)

print(cols_measurements)
# Out:
# Index(['glucose', 'lb', 'glycerolaa', 'acetate', 'fumarate', 'glucosamine',
#        'glycerol', 'pyruvate', 'chemostatµ05', 'chemostatµ035',
#        'chemostatµ020', 'chemostatµ012', 'stationaryphase1day',
#        'stationaryphase3days', 'osmoticstressglucose', '42cglucose',
#        'ph6glucose', 'xylose', 'mannose', 'galactose', 'succinate'],
#       dtype='object')

# %%
# Out:
# []

# %%
# chemo 12
chemo_data_dict_12 = proteomics_data_dict["chemostatµ012"]

growth_chemo_12 = {"measurement":float(list(growth_rates['Growth rate (h-1)'].loc[growth_rates['Growth condition'] == "chemostat µ=0.12"])[0]),\
    "uncertainty":float(list(growth_rates['Stdev'].loc[growth_rates['Growth condition'] == "chemostat µ=0.12"])[0])}
new_growth_rate_chemo12, new_proteomics_chemo12, warnings_chemo12 = flexibilize_proteomics(eColi_Model,  "BIOMASS_Ec_iML1515_core_75p37M", growth_chemo_12, chemo_data_dict_12, [])

# chemo 2
chemo_data_dict_20 = proteomics_data_dict["chemostatµ020"]

growth_chemo_20 = {"measurement":float(list(growth_rates['Growth rate (h-1)'].loc[growth_rates['Growth condition'] == "chemostat µ=0.20"])[0]),\
    "uncertainty":float(list(growth_rates['Stdev'].loc[growth_rates['Growth condition'] == "chemostat µ=0.20"])[0])}
new_growth_rate_chemo20, new_proteomics_chemo20, warnings_chemo20 = flexibilize_proteomics(eColi_Model,  "BIOMASS_Ec_iML1515_core_75p37M", growth_chemo_20, chemo_data_dict_20, [])

# chemo 35
chemo_data_dict_35 = proteomics_data_dict["chemostatµ035"]

growth_chemo_35 = {"measurement":float(list(growth_rates['Growth rate (h-1)'].loc[growth_rates['Growth condition'] == "chemostat µ=0.35"])[0]),\
    "uncertainty":float(list(growth_rates['Stdev'].loc[growth_rates['Growth condition'] == "chemostat µ=0.35"])[0])}
new_growth_rate_chemo35, new_proteomics_chemo35, warnings_chemo35 = flexibilize_proteomics(eColi_Model,  "BIOMASS_Ec_iML1515_core_75p37M", growth_chemo_35, chemo_data_dict_35, [])

# chemo 50
chemo_data_dict_50 = proteomics_data_dict["chemostatµ05"]

growth_chemo_50 = {"measurement":float(list(growth_rates['Growth rate (h-1)'].loc[growth_rates['Growth condition'] == "chemostat µ=0.5"])[0]),\
    "uncertainty":float(list(growth_rates['Stdev'].loc[growth_rates['Growth condition'] == "chemostat µ=0.5"])[0])}
new_growth_rate_chemo50, new_proteomics_chemo50, warnings_chemo50 = flexibilize_proteomics(eColi_Model,  "BIOMASS_Ec_iML1515_core_75p37M", growth_chemo, chemo_data_dict_50, [])
# Out:
# P36683    3.662313e-05
# P09831    3.749847e-06
# P0AFG8    1.279594e-05
# P0A9Q7    2.193684e-05
# P25665    1.147625e-05
#               ...
# P77783    0.000000e+00
# P33607    1.104363e-08
# P43337    3.643411e-08
# P61887    2.467943e-08
# P0AC78    1.560366e-08
# Name: value, Length: 820, dtype: float64
# P36683    4.159123e-05
# P15254    3.856413e-06
# P09831    4.494580e-06
# P0AFG8    1.158131e-05
# P0A9Q7    2.088777e-05
#               ...
# P77783    0.000000e+00
# P33607    1.401275e-08
# P43337    3.935275e-08
# P61887    3.423461e-08
# P0AC78    1.435521e-08
# Name: value, Length: 856, dtype: float64
# P36683    4.359975e-05
# P15254    3.770820e-06
# P09831    4.304719e-06
# P0AFG8    1.141516e-05
# P0A9Q7    1.682622e-05
#               ...
# P77783    0.000000e+00
# P33607    9.087677e-09
# P43337    1.915300e-08
# P61887    4.086825e-08
# P0AC78    9.163651e-09
# Name: value, Length: 856, dtype: float64
# P36683    3.075390e-05
# P15254    4.635079e-06
# P09831    4.666612e-06
# P0AFG8    1.186984e-05
# P0A9Q7    2.210191e-05
#               ...
# P77783    0.000000e+00
# P33607    2.111386e-08
# P43337    3.275402e-08
# P61887    4.296737e-08
# P0AC78    2.911493e-08
# Name: value, Length: 856, dtype: float64
