# %% [markdown]
# Modify this line to briefly discribe the functionality of new_script.ipynb<br/><br/>Copyright (C) 2017  Martin Engqvist Lab<br/>This program is free software: you can redistribute it and/or modify<br/>it under the terms of the GNU General Public License as published by<br/>the Free Software Foundation, either version 3 of the License, or<br/>(at your option) any later version.<br/>This program is distributed in the hope that it will be useful,<br/>but WITHOUT ANY WARRANTY; without even the implied warranty of<br/>MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the<br/>GNU General Public License for more details.<br/>You should have received a copy of the GNU General Public License<br/>along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


# make folders specific for certain data
folder_name = ''
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(RAW_EXTERNAL, folder_name)):
        os.makedirs(join(RAW_EXTERNAL, folder_name))

    if not exists(join(INTERMEDIATE, folder_name)):
        os.makedirs(join(INTERMEDIATE, folder_name))

    if not exists(join(FINAL, folder_name)):
        os.makedirs(join(FINAL, folder_name))


print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %% [markdown]
# # Read in data
# here, data is read in as well as translations from uniprot ID to NCBI Entrez (mapper obtained from: https://www.uniprot.org/uploadlists/)

# %%
## Your code here ##
import pandas as pd

# de results loading
de_results = pd.read_csv("~/Documents/masters/thesis/thesis/data/final/de_edger_results_stress.csv")

# protein to gene translation file read in 
uniprot_to_entrez = pd.read_csv("~/Documents/masters/thesis/thesis/data/intermediate/uniprot_to_entrez.tsv", sep="\t")
uniprot_to_entrez = uniprot_to_entrez.drop_duplicates(subset ="From", keep = False)\
.set_index("From").to_dict('index')

# %%
uniprot_to_entrez
# Out:
# {'D4HZR9': {'To': 8914606},
#  'P00350': {'To': 946554},
#  'P00363': {'To': 948667},
#  'P00370': {'To': 946802},
#  'P00393': {'To': 946792},
#  'P00448': {'To': 948403},
#  'P00452': {'To': 946612},
#  'P00490': {'To': 947922},
#  'P00509': {'To': 945553},
#  'P00547': {'To': 947498},
#  'P00550': {'To': 948118},
#  'P00561': {'To': 945803},
#  'P00562': {'To': 948433},
#  'P00579': {'To': 947567},
#  'P00582': {'To': 948356},
#  'P00803': {'To': 947040},
#  'P00805': {'To': 947454},
#  'P00811': {'To': 948669},
#  'P00861': {'To': 947313},
#  'P00864': {'To': 948457},
#  'P00887': {'To': 946229},
#  'P00888': {'To': 947084},
#  'P00893': {'To': 948793},
#  'P00894': {'To': 947267},
#  'P00895': {'To': 945846},
#  'P00904': {'To': 945109},
#  'P00909': {'To': 945519},
#  'P00926': {'To': 946837},
#  'P00934': {'To': 945198},
#  'P00935': {'To': 948434},
#  'P00936': {'To': 947755},
#  'P00944': {'To': 948141},
#  'P00946': {'To': 944840},
#  'P00954': {'To': 947894},
#  'P00956': {'To': 944761},
#  'P00957': {'To': 947175},
#  'P00959': {'To': 946643},
#  'P00960': {'To': 948079},
#  'P00961': {'To': 948080},
#  'P00962': {'To': 945310},
#  'P00968': {'To': 944775},
#  'P02358': {'To': 948723},
#  'P02359': {'To': 947846},
#  'P02413': {'To': 947798},
#  'P02916': {'To': 948532},
#  'P02918': {'To': 947907},
#  'P02919': {'To': 944843},
#  'P02924': {'To': 946409},
#  'P02925': {'To': 948261},
#  'P02929': {'To': 945843},
#  'P02930': {'To': 947521},
#  'P02931': {'To': 945554},
#  'P02942': {'To': 948884},
#  'P02943': {'To': 948548},
#  'P03004': {'To': 948217},
#  'P03007': {'To': 946441},
#  'P03018': {'To': 948347},
#  'P03813': {'To': 947348},
#  'P03819': {'To': 944773},
#  'P03841': {'To': 948547},
#  'P04036': {'To': 944762},
#  'P04079': {'To': 947334},
#  'P04335': {'To': 946039},
#  'P04391': {'To': 948774},
#  'P04425': {'To': 947445},
#  'P04693': {'To': 948563},
#  'P04805': {'To': 946906},
#  'P04816': {'To': 947964},
#  'P04825': {'To': 947253},
#  'P04846': {'To': 948175},
#  'P04949': {'To': 949101},
#  'P04951': {'To': 945539},
#  'P04968': {'To': 948287},
#  'P04982': {'To': 948267},
#  'P04983': {'To': 948264},
#  'P04994': {'To': 946988},
#  'P05020': {'To': 945787},
#  'P05041': {'To': 946337},
#  'P05042': {'To': 946147},
#  'P05055': {'To': 947672},
#  'P05194': {'To': 946210},
#  'P05458': {'To': 947284},
#  'P05459': {'To': 946785},
#  'P05523': {'To': 946765},
#  'P05637': {'To': 944770},
#  'P05704': {'To': 945995},
#  'P05706': {'To': 948971},
#  'P05719': {'To': 948867},
#  'P05791': {'To': 948277},
#  'P05793': {'To': 948286},
#  'P05804': {'To': 946149},
#  'P05825': {'To': 945193},
#  'P05852': {'To': 947578},
#  'P06129': {'To': 948468},
#  'P06149': {'To': 946653},
#  'P06610': {'To': 945915},
#  'P06612': {'To': 945862},
#  'P06616': {'To': 947036},
#  'P06709': {'To': 948469},
#  'P06710': {'To': 945105},
#  'P06715': {'To': 948014},
#  'P06720': {'To': 948636},
#  'P06721': {'To': 946240},
#  'P06846': {'To': 947586},
#  'P06959': {'To': 944794},
#  'P06960': {'To': 944844},
#  'P06961': {'To': 947553},
#  'P06966': {'To': 946241},
#  'P06968': {'To': 948607},
#  'P06971': {'To': 944856},
#  'P06983': {'To': 947759},
#  'P06986': {'To': 946551},
#  'P06987': {'To': 946552},
#  'P06988': {'To': 946531},
#  'P06989': {'To': 946515},
#  'P06992': {'To': 944939},
#  'P06993': {'To': 947921},
#  'P06996': {'To': 946716},
#  'P06999': {'To': 946230},
#  'P07001': {'To': 946628},
#  'P07003': {'To': 946132},
#  'P07004': {'To': 946680},
#  'P07012': {'To': 947369},
#  'P07013': {'To': 948722},
#  'P07014': {'To': 945300},
#  'P07017': {'To': 946399},
#  'P07021': {'To': 947094},
#  'P07023': {'To': 947115},
#  'P07024': {'To': 947331},
#  'P07102': {'To': 946206},
#  'P07109': {'To': 946789},
#  'P07117': {'To': 945602},
#  'P07118': {'To': 948785},
#  'P07363': {'To': 946401},
#  'P07395': {'To': 945382},
#  'P07604': {'To': 945879},
#  'P07623': {'To': 948513},
#  'P07639': {'To': 947927},
#  'P07648': {'To': 947294},
#  'P07650': {'To': 948901},
#  'P07762': {'To': 947940},
#  'P07813': {'To': 947497},
#  'P07862': {'To': 946324},
#  'P07913': {'To': 948139},
#  'P08142': {'To': 948182},
#  'P08178': {'To': 946975},
#  'P08179': {'To': 946973},
#  'P08192': {'To': 945451},
#  'P08194': {'To': 946704},
#  'P08200': {'To': 945702},
#  'P08201': {'To': 947868},
#  'P08244': {'To': 947121},
#  'P08245': {'To': 947058},
#  'P08312': {'To': 946223},
#  'P08331': {'To': 948729},
#  'P08368': {'To': 948922},
#  'P08373': {'To': 948470},
#  'P08390': {'To': 946797},
#  'P08395': {'To': 946281},
#  'P08506': {'To': 945455},
#  'P08550': {'To': 945055},
#  'P08622': {'To': 944753},
#  'P08660': {'To': 948531},
#  'P08839': {'To': 946879},
#  'P08956': {'To': 948878},
#  'P08957': {'To': 948872},
#  'P08997': {'To': 948512},
#  'P09029': {'To': 945153},
#  'P09030': {'To': 946254},
#  'P09053': {'To': 948087},
#  'P09099': {'To': 948133},
#  'P09126': {'To': 948587},
#  'P09127': {'To': 948446},
#  'P09147': {'To': 945354},
#  'P09148': {'To': 945357},
#  'P09151': {'To': 947465},
#  'P09152': {'To': 945782},
#  'P09155': {'To': 946328},
#  'P09158': {'To': 947726},
#  'P09169': {'To': 945185},
#  'P09323': {'To': 945292},
#  'P09372': {'To': 947097},
#  'P09373': {'To': 945514},
#  'P09394': {'To': 946725},
#  'P09424': {'To': 948117},
#  'P09546': {'To': 945600},
#  'P09549': {'To': 944971},
#  'P09551': {'To': 949030},
#  'P09831': {'To': 947724},
#  'P09832': {'To': 947723},
#  'P09833': {'To': 945362},
#  'P09980': {'To': 948292},
#  'P09996': {'To': 948212},
#  'P0A698': {'To': 948559},
#  'P0A6A0': {'To': 948322},
#  'P0A6A3': {'To': 946775},
#  'P0A6A6': {'To': 945076},
#  'P0A6B4': {'To': 948564},
#  'P0A6B7': {'To': 947004},
#  'P0A6C1': {'To': 946669},
#  'P0A6C5': {'To': 947289},
#  'P0A6C8': {'To': 948464},
#  'P0A6D0': {'To': 947861},
#  'P0A6D3': {'To': 945528},
#  'P0A6D7': {'To': 2847759},
#  'P0A6E1': {'To': 945031},
#  'P0A6E4': {'To': 947590},
#  'P0A6E6': {'To': 948245},
#  'P0A6E9': {'To': 944927},
#  'P0A6F1': {'To': 949025},
#  'P0A6F3': {'To': 948423},
#  'P0A6F5': {'To': 948665},
#  'P0A6F9': {'To': 948655},
#  'P0A6G3': {'To': 947169},
#  'P0A6G7': {'To': 945082},
#  'P0A6H1': {'To': 945083},
#  'P0A6H5': {'To': 948430},
#  'P0A6H8': {'To': 945821},
#  'P0A6I0': {'To': 945535},
#  'P0A6I3': {'To': 948479},
#  'P0A6I6': {'To': 947386},
#  'P0A6I9': {'To': 949060},
#  'P0A6J1': {'To': 947221},
#  'P0A6J5': {'To': 945752},
#  'P0A6J8': {'To': 945313},
#  'P0A6K3': {'To': 947780},
#  'P0A6K6': {'To': 948910},
#  'P0A6L0': {'To': 948902},
#  'P0A6L2': {'To': 946952},
#  'P0A6L4': {'To': 947742},
#  'P0A6L7': {'To': 945542},
#  'P0A6L9': {'To': 946995},
#  'P0A6M2': {'To': 946344},
#  'P0A6M4': {'To': 948378},
#  'P0A6M8': {'To': 947847},
#  'P0A6N4': {'To': 948661},
#  'P0A6N8': {'To': 946674},
#  'P0A6P1': {'To': 944866},
#  'P0A6P5': {'To': 946983},
#  'P0A6P7': {'To': 948358},
#  'P0A6P9': {'To': 945032},
#  'P0A6Q3': {'To': 945568},
#  'P0A6Q6': {'To': 944888},
#  'P0A6R0': {'To': 946003},
#  'P0A6S0': {'To': 946996},
#  'P0A6S5': {'To': 946033},
#  'P0A6S7': {'To': 948125},
#  'P0A6T1': {'To': 948535},
#  'P0A6T3': {'To': 945358},
#  'P0A6T5': {'To': 949040},
#  'P0A6T9': {'To': 947393},
#  'P0A6U3': {'To': 948248},
#  'P0A6U5': {'To': 948250},
#  'P0A6U8': {'To': 947932},
#  'P0A6V1': {'To': 947942},
#  'P0A6V5': {'To': 947935},
#  'P0A6V8': {'To': 946858},
#  'P0A6W3': {'To': 944814},
#  'P0A6W5': {'To': 947696},
#  'P0A6W9': {'To': 944881},
#  'P0A6X1': {'To': 945777},
#  'P0A6X3': {'To': 948689},
#  'P0A6X7': {'To': 945472},
#  'P0A6Y1': {'To': 945533},
#  'P0A6Y5': {'To': 947178},
#  'P0A6Y8': {'To': 944750},
#  'P0A6Z1': {'To': 944885},
#  'P0A6Z3': {'To': 945099},
#  'P0A6Z6': {'To': 947995},
#  'P0A705': {'To': 947684},
#  'P0A707': {'To': 946225},
#  'P0A710': {'To': 946228},
#  'P0A715': {'To': 945785},
#  'P0A717': {'To': 945772},
#  'P0A720': {'To': 945663},
#  'P0A722': {'To': 944849},
#  'P0A725': {'To': 944816},
#  'P0A729': {'To': 945631},
#  'P0A731': {'To': 945574},
#  'P0A734': {'To': 945740},
#  'P0A738': {'To': 945397},
#  'P0A742': {'To': 947787},
#  'P0A744': {'To': 948734},
#  'P0A746': {'To': 947188},
#  'P0A749': {'To': 947703},
#  'P0A752': {'To': 945248},
#  'P0A759': {'To': 945290},
#  'P0A761': {'To': 947745},
#  'P0A763': {'To': 945611},
#  'P0A780': {'To': 945054},
#  'P0A784': {'To': 948675},
#  'P0A786': {'To': 948767},
#  'P0A790': {'To': 945686},
#  'P0A794': {'To': 947039},
#  'P0A796': {'To': 948412},
#  'P0A799': {'To': 947414},
#  'P0A7A2': {'To': 948918},
#  'P0A7A5': {'To': 944923},
#  'P0A7A7': {'To': 948541},
#  'P0A7A9': {'To': 948748},
#  'P0A7B1': {'To': 946971},
#  'P0A7B3': {'To': 947092},
#  'P0A7B5': {'To': 946425},
#  'P0A7B8': {'To': 948429},
#  'P0A7C2': {'To': 948544},
#  'P0A7C6': {'To': 948520},
#  'P0A7D1': {'To': 945765},
#  'P0A7D4': {'To': 948695},
#  'P0A7D7': {'To': 946957},
#  'P0A7E1': {'To': 945556},
#  'P0A7E3': {'To': 948157},
#  'P0A7E5': {'To': 946116},
#  'P0A7E9': {'To': 944989},
#  'P0A7F3': {'To': 948763},
#  'P0A7F6': {'To': 947719},
#  'P0A7F9': {'To': 944905},
#  'P0A7G2': {'To': 947685},
#  'P0A7G6': {'To': 947170},
#  'P0A7H6': {'To': 945100},
#  'P0A7I0': {'To': 949002},
#  'P0A7I4': {'To': 948897},
#  'P0A7I7': {'To': 945763},
#  'P0A7J0': {'To': 947526},
#  'P0A7J3': {'To': 948490},
#  'P0A7J7': {'To': 948484},
#  'P0A7K2': {'To': 948489},
#  'P0A7K6': {'To': 947096},
#  'P0A7L0': {'To': 948483},
#  'P0A7L8': {'To': 945190},
#  'P0A7M2': {'To': 946941},
#  'P0A7M6': {'To': 947807},
#  'P0A7M9': {'To': 948425},
#  'P0A7N4': {'To': 945657},
#  'P0A7R1': {'To': 948720},
#  'P0A7R5': {'To': 947816},
#  'P0A7R9': {'To': 947792},
#  'P0A7S9': {'To': 947791},
#  'P0A7T3': {'To': 947103},
#  'P0A7U7': {'To': 944759},
#  'P0A7V0': {'To': 947874},
#  'P0A7W1': {'To': 947795},
#  'P0A7W7': {'To': 947802},
#  'P0A7X6': {'To': 947101},
#  'P0A7Y0': {'To': 947033},
#  'P0A7Y4': {'To': 946955},
#  'P0A7Y8': {'To': 948215},
#  'P0A7Z0': {'To': 947407},
#  'P0A7Z4': {'To': 947794},
#  'P0A805': {'To': 946122},
#  'P0A812': {'To': 946371},
#  'P0A817': {'To': 945389},
#  'P0A821': {'To': 948124},
#  'P0A825': {'To': 947022},
#  'P0A830': {'To': 948039},
#  'P0A832': {'To': 947296},
#  'P0A836': {'To': 945312},
#  'P0A840': {'To': 947211},
#  'P0A843': {'To': 945228},
#  'P0A847': {'To': 949130},
#  'P0A850': {'To': 945081},
#  'P0A853': {'To': 948221},
#  'P0A855': {'To': 945429},
#  'P0A858': {'To': 948409},
#  'P0A862': {'To': 945880},
#  'P0A867': {'To': 947006},
#  'P0A870': {'To': 944748},
#  'P0A873': {'To': 947099},
#  'P0A877': {'To': 946204},
#  'P0A879': {'To': 945768},
#  'P0A881': {'To': 948917},
#  'P0A884': {'To': 949035},
#  'P0A887': {'To': 948926},
#  'P0A890': {'To': 947974},
#  'P0A894': {'To': 947727},
#  'P0A898': {'To': 946430},
#  'P0A8A0': {'To': 946379},
#  'P0A8A2': {'To': 946493},
#  'P0A8A4': {'To': 946207},
#  'P0A8A8': {'To': 947680},
#  'P0A8B2': {'To': 944847},
#  'P0A8B5': {'To': 945104},
#  'P0A8C1': {'To': 945493},
#  'P0A8C4': {'To': 947400},
#  'P0A8D0': {'To': 947437},
#  'P0A8D3': {'To': 945033},
#  'P0A8D6': {'To': 946987},
#  'P0A8E1': {'To': 945676},
#  'P0A8E7': {'To': 945063},
#  'P0A8F0': {'To': 946979},
#  'P0A8F4': {'To': 946597},
#  'P0A8F8': {'To': 945385},
#  'P0A8G0': {'To': 947203},
#  'P0A8G3': {'To': 947599},
#  'P0A8G6': {'To': 947263},
#  'P0A8G9': {'To': 945069},
#  'P0A8H6': {'To': 948363},
#  'P0A8H8': {'To': 945630},
#  'P0A8I1': {'To': 947439},
#  'P0A8I3': {'To': 944749},
#  'P0A8I5': {'To': 947448},
#  'P0A8I8': {'To': 945239},
#  'P0A8J2': {'To': 948813},
#  'P0A8J4': {'To': 945220},
#  'P0A8J8': {'To': 948290},
#  'P0A8K1': {'To': 948673},
#  'P0A8K5': {'To': 1450233},
#  'P0A8L1': {'To': 945506},
#  'P0A8M0': {'To': 945555},
#  'P0A8M3': {'To': 946222},
#  'P0A8M6': {'To': 946541},
#  'P0A8N0': {'To': 945570},
#  'P0A8N3': {'To': 947372},
#  'P0A8N5': {'To': 948645},
#  'P0A8P3': {'To': 947461},
#  'P0A8P6': {'To': 948355},
#  'P0A8P8': {'To': 947362},
#  'P0A8R0': {'To': 948419},
#  'P0A8R4': {'To': 947849},
#  'P0A8R7': {'To': 945878},
#  'P0A8S1': {'To': 944867},
#  'P0A8T1': {'To': 947708},
#  'P0A8T7': {'To': 948487},
#  'P0A8U0': {'To': 947271},
#  'P0A8U6': {'To': 948435},
#  'P0A8V0': {'To': 946760},
#  'P0A8V2': {'To': 948488},
#  'P0A8V6': {'To': 948652},
#  'P0A8W0': {'To': 945468},
#  'P0A8W2': {'To': 946167},
#  'P0A8W5': {'To': 947442},
#  'P0A8W8': {'To': 946767},
#  'P0A8X0': {'To': 948751},
#  'P0A8X2': {'To': 946145},
#  'P0A8Y1': {'To': 948899},
#  'P0A8Y3': {'To': 948380},
#  'P0A8Y5': {'To': 948204},
#  'P0A8Y8': {'To': 945215},
#  'P0A8Z0': {'To': 946634},
#  'P0A8Z7': {'To': 947488},
#  'P0A901': {'To': 948670},
#  'P0A903': {'To': 946954},
#  'P0A905': {'To': 946801},
#  'P0A908': {'To': 946301},
#  'P0A910': {'To': 945571},
#  'P0A912': {'To': 945004},
#  'P0A915': {'To': 945128},
#  'P0A917': {'To': 944967},
#  'P0A921': {'To': 948307},
#  'P0A927': {'To': 946242},
#  'P0A935': {'To': 944964},
#  'P0A937': {'To': 945583},
#  'P0A940': {'To': 944870},
#  'P0A944': {'To': 948894},
#  'P0A951': {'To': 946117},
#  'P0A953': {'To': 946799},
#  'P0A955': {'To': 946367},
#  'P0A959': {'To': 946772},
#  'P0A962': {'To': 946278},
#  'P0A964': {'To': 946400},
#  'P0A968': {'To': 945669},
#  'P0A972': {'To': 947024},
#  'P0A988': {'To': 948218},
#  'P0A991': {'To': 946632},
#  'P0A993': {'To': 948753},
#  'P0A996': {'To': 946735},
#  'P0A998': {'To': 946410},
#  'P0A9A6': {'To': 944786},
#  'P0A9A9': {'To': 945295},
#  'P0A9B2': {'To': 947679},
#  'P0A9B6': {'To': 947413},
#  'P0A9C0': {'To': 946713},
#  'P0A9C3': {'To': 944943},
#  'P0A9C5': {'To': 948370},
#  'P0A9C9': {'To': 948424},
#  'P0A9D2': {'To': 945758},
#  'P0A9D4': {'To': 948126},
#  'P0A9D8': {'To': 944862},
#  'P0A9E5': {'To': 945908},
#  'P0A9F1': {'To': 945437},
#  'P0A9F3': {'To': 945771},
#  'P0A9F6': {'To': 947278},
#  'P0A9F9': {'To': 948310},
#  'P0A9G4': {'To': 945332},
#  'P0A9G6': {'To': 948517},
#  'P0A9G8': {'To': 945366},
#  'P0A9H1': {'To': 947560},
#  'P0A9H5': {'To': 945839},
#  'P0A9H7': {'To': 944811},
#  'P0A9I3': {'To': 946950},
#  'P0A9I8': {'To': 947881},
#  'P0A9J0': {'To': 947744},
#  'P0A9J6': {'To': 948260},
#  'P0A9J8': {'To': 947081},
#  'P0A9K3': {'To': 948044},
#  'P0A9K7': {'To': 948233},
#  'P0A9K9': {'To': 947859},
#  'P0A9L3': {'To': 948726},
#  'P0A9L5': {'To': 948285},
#  'P0A9L8': {'To': 945034},
#  'P0A9M0': {'To': 945085},
#  'P0A9M2': {'To': 946624},
#  'P0A9M5': {'To': 944817},
#  'P0A9M8': {'To': 946778},
#  'P0A9N4': {'To': 945517},
#  'P0A9P0': {'To': 944854},
#  'P0A9P4': {'To': 949054},
#  'P0A9P6': {'To': 947674},
#  'P0A9Q1': {'To': 948874},
#  'P0A9Q5': {'To': 946796},
#  'P0A9Q7': {'To': 945837},
#  'P0A9Q9': {'To': 947939},
#  'P0A9R4': {'To': 947160},
#  'P0A9R7': {'To': 947968},
#  'P0A9S1': {'To': 947273},
#  'P0A9S3': {'To': 946598},
#  'P0A9S5': {'To': 948440},
#  'P0A9S7': {'To': 947967},
#  'P0A9T0': {'To': 945258},
#  'P0A9T4': {'To': 947306},
#  'P0A9T6': {'To': 948800},
#  'P0A9T8': {'To': 945122},
#  'P0A9U3': {'To': 945440},
#  'P0A9U6': {'To': 945886},
#  'P0A9V1': {'To': 947725},
#  'P0A9W0': {'To': 948706},
#  'P0A9W3': {'To': 948909},
#  'P0A9W6': {'To': 947958},
#  'P0A9W9': {'To': 947775},
#  'P0AA10': {'To': 947828},
#  'P0AA39': {'To': 945637},
#  'P0AA43': {'To': 945378},
#  'P0AA53': {'To': 947257},
#  'P0AA57': {'To': 948315},
#  'P0AA63': {'To': 947643},
#  'P0AA82': {'To': 944994},
#  'P0AA89': {'To': 945835},
#  'P0AA91': {'To': 946312},
#  'P0AA97': {'To': 946809},
#  'P0AA99': {'To': 944910},
#  'P0AAA1': {'To': 945677},
#  'P0AAA9': {'To': 948507},
#  'P0AAB4': {'To': 948326},
#  'P0AAB6': {'To': 946560},
#  'P0AAB8': {'To': 948415},
#  'P0AAC0': {'To': 945904},
#  'P0AAC4': {'To': 945401},
#  'P0AAC8': {'To': 946999},
#  'P0AAD6': {'To': 947264},
#  'P0AAE0': {'To': 948725},
#  'P0AAF6': {'To': 945489},
#  'P0AAG0': {'To': 948065},
#  'P0AAG3': {'To': 945254},
#  'P0AAG8': {'To': 949036},
#  'P0AAH0': {'To': 948240},
#  'P0AAI3': {'To': 947690},
#  'P0AAI5': {'To': 946665},
#  'P0AAI9': {'To': 945766},
#  'P0AAJ5': {'To': 948395},
#  'P0AAN3': {'To': 947194},
#  'P0AAN5': {'To': 945043},
#  'P0AAN9': {'To': 947709},
#  'P0AAP3': {'To': 944986},
#  'P0AAQ2': {'To': 945051},
#  'P0AAR3': {'To': 947083},
#  'P0AAS0': {'To': 948876},
#  'P0AAS7': {'To': 945158},
#  'P0AAS9': {'To': 949021},
#  'P0AAT6': {'To': 945237},
#  'P0AAT9': {'To': 945252},
#  'P0AAV4': {'To': 945311},
#  'P0AAV6': {'To': 945356},
#  'P0AAW1': {'To': 945408},
#  'P0AAX3': {'To': 945433},
#  'P0AAX8': {'To': 945441},
#  'P0AAY6': {'To': 945482},
#  'P0AAZ4': {'To': 945505},
#  'P0AAZ7': {'To': 945537},
#  'P0AB10': {'To': 946972},
#  'P0AB12': {'To': 945594},
#  'P0AB14': {'To': 948930},
#  'P0AB24': {'To': 945603},
#  'P0AB26': {'To': 947377},
#  'P0AB28': {'To': 945650},
#  'P0AB38': {'To': 948536},
#  'P0AB40': {'To': 945492},
#  'P0AB43': {'To': 946226},
#  'P0AB49': {'To': 945762},
#  'P0AB52': {'To': 945794},
#  'P0AB55': {'To': 949085},
#  'P0AB61': {'To': 945860},
#  'P0AB65': {'To': 945304},
#  'P0AB67': {'To': 946144},
#  'P0AB71': {'To': 947415},
#  'P0AB77': {'To': 948138},
#  'P0AB80': {'To': 948278},
#  'P0AB83': {'To': 947122},
#  'P0AB89': {'To': 945695},
#  'P0AB91': {'To': 945605},
#  'P0AB96': {'To': 948018},
#  'P0AB98': {'To': 948252},
#  'P0ABA0': {'To': 948247},
#  'P0ABA4': {'To': 948254},
#  'P0ABA6': {'To': 948243},
#  'P0ABB0': {'To': 948242},
#  'P0ABB4': {'To': 948244},
#  'P0ABB8': {'To': 948778},
#  'P0ABC3': {'To': 948697},
#  'P0ABC7': {'To': 948698},
#  'P0ABD3': {'To': 947839},
#  'P0ABD5': {'To': 944895},
#  'P0ABD8': {'To': 947758},
#  'P0ABE2': {'To': 947043},
#  'P0ABF1': {'To': 947318},
#  'P0ABF4': {'To': 946942},
#  'P0ABF6': {'To': 946663},
#  'P0ABG1': {'To': 944876},
#  'P0ABH0': {'To': 944778},
#  'P0ABH7': {'To': 945323},
#  'P0ABH9': {'To': 945764},
#  'P0ABI4': {'To': 948351},
#  'P0ABI8': {'To': 945615},
#  'P0ABJ1': {'To': 945080},
#  'P0ABJ3': {'To': 946897},
#  'P0ABJ6': {'To': 944918},
#  'P0ABJ9': {'To': 945341},
#  'P0ABK2': {'To': 945347},
#  'P0ABK5': {'To': 946877},
#  'P0ABK9': {'To': 948571},
#  'P0ABN5': {'To': 948659},
#  'P0ABP8': {'To': 945654},
#  'P0ABQ0': {'To': 949047},
#  'P0ABQ2': {'To': 947631},
#  'P0ABQ4': {'To': 944790},
#  'P0ABR1': {'To': 945022},
#  'P0ABS5': {'To': 947570},
#  'P0ABT2': {'To': 945101},
#  'P0ABT5': {'To': 947707},
#  'P0ABU0': {'To': 946747},
#  'P0ABU2': {'To': 945769},
#  'P0ABU5': {'To': 947903},
#  'P0ABU7': {'To': 945420},
#  'P0ABU9': {'To': 948900},
#  'P0ABV2': {'To': 946345},
#  'P0ABV6': {'To': 945328},
#  'P0ABY4': {'To': 947361},
#  'P0ABZ1': {'To': 946451},
#  'P0ABZ4': {'To': 947717},
#  'P0ABZ6': {'To': 944812},
#  'P0AC02': {'To': 947086},
#  'P0AC13': {'To': 947691},
#  'P0AC16': {'To': 947544},
#  'P0AC19': {'To': 946781},
#  'P0AC23': {'To': 945513},
#  'P0AC30': {'To': 947969},
#  'P0AC33': {'To': 946826},
#  'P0AC38': {'To': 948658},
#  'P0AC41': {'To': 945402},
#  'P0AC44': {'To': 945322},
#  'P0AC47': {'To': 948666},
#  'P0AC51': {'To': 948552},
#  'P0AC53': {'To': 946370},
#  'P0AC55': {'To': 945087},
#  'P0AC59': {'To': 946926},
#  'P0AC62': {'To': 948132},
#  'P0AC69': {'To': 946169},
#  'P0AC75': {'To': 949048},
#  'P0AC78': {'To': 948789},
#  'P0AC81': {'To': 946161},
#  'P0AC84': {'To': 944902},
#  'P0AC86': {'To': 947931},
#  'P0AC92': {'To': 1450249},
#  'P0ACA1': {'To': 948113},
#  'P0ACA3': {'To': 944744},
#  'P0ACA7': {'To': 945469},
#  'P0ACB0': {'To': 948555},
#  'P0ACB2': {'To': 945017},
#  'P0ACB4': {'To': 948331},
#  'P0ACB7': {'To': 948311},
#  'P0ACC3': {'To': 944857},
#  'P0ACC7': {'To': 948246},
#  'P0ACD4': {'To': 947002},
#  'P0ACD8': {'To': 945580},
#  'P0ACE0': {'To': 945182},
#  'P0ACE3': {'To': 945098},
#  'P0ACE7': {'To': 948549},
#  'P0ACF0': {'To': 948499},
#  'P0ACF4': {'To': 949095},
#  'P0ACF8': {'To': 945829},
#  'P0ACG1': {'To': 947130},
#  'P0ACG8': {'To': 947912},
#  'P0ACI0': {'To': 948916},
#  'P0ACI3': {'To': 948086},
#  'P0ACJ0': {'To': 949051},
#  'P0ACK2': {'To': 947636},
#  'P0ACK5': {'To': 945453},
#  'P0ACK8': {'To': 946905},
#  'P0ACL2': {'To': 947602},
#  'P0ACL5': {'To': 947466},
#  'P0ACL9': {'To': 944827},
#  'P0ACN4': {'To': 945333},
#  'P0ACN7': {'To': 948427},
#  'P0ACP1': {'To': 944804},
#  'P0ACP5': {'To': 947946},
#  'P0ACP7': {'To': 945226},
#  'P0ACQ4': {'To': 948462},
#  'P0ACR4': {'To': 946657},
#  'P0ACR9': {'To': 945282},
#  'P0ACS2': {'To': 948566},
#  'P0ACS7': {'To': 948603},
#  'P0ACS9': {'To': 945516},
#  'P0ACU7': {'To': 948650},
#  'P0ACV4': {'To': 944936},
#  'P0ACV6': {'To': 945969},
#  'P0ACV8': {'To': 945874},
#  'P0ACW6': {'To': 945997},
#  'P0ACX3': {'To': 946177},
#  'P0ACX5': {'To': 946180},
#  'P0ACX9': {'To': 946205},
#  'P0ACY1': {'To': 945964},
#  'P0ACY3': {'To': 946297},
#  'P0ACY9': {'To': 946364},
#  'P0ACZ4': {'To': 946841},
#  'P0ACZ8': {'To': 945003},
#  'P0AD01': {'To': 948640},
#  'P0AD05': {'To': 945061},
#  'P0AD07': {'To': 946420},
#  'P0AD10': {'To': 946388},
#  'P0AD12': {'To': 946538},
#  'P0AD14': {'To': 949027},
#  'P0AD24': {'To': 946694},
#  'P0AD27': {'To': 946685},
#  'P0AD33': {'To': 948817},
#  'P0AD37': {'To': 946857},
#  'P0AD40': {'To': 1450285},
#  'P0AD44': {'To': 947010},
#  'P0AD49': {'To': 947129},
#  'P0AD57': {'To': 947364},
#  'P0AD59': {'To': 946530},
#  'P0AD61': {'To': 946179},
#  'P0AD65': {'To': 945240},
#  'P0AD68': {'To': 944799},
#  'P0AD96': {'To': 947971},
#  'P0ADA1': {'To': 945127},
#  'P0ADA3': {'To': 947011},
#  'P0ADA5': {'To': 945521},
#  'P0ADA7': {'To': 945866},
#  'P0ADB1': {'To': 945305},
#  'P0ADB7': {'To': 2847737},
#  'P0ADC1': {'To': 946257},
#  'P0ADC3': {'To': 945673},
#  'P0ADC6': {'To': 945324},
#  'P0ADE4': {'To': 948733},
#  'P0ADE6': {'To': 947144},
#  'P0ADE8': {'To': 947384},
#  'P0ADF8': {'To': 948183},
#  'P0ADG4': {'To': 947285},
#  'P0ADG7': {'To': 946985},
#  'P0ADI4': {'To': 946178},
#  'P0ADI7': {'To': 946384},
#  'P0ADK0': {'To': 948072},
#  'P0ADK8': {'To': 948115},
#  'P0ADM4': {'To': 948199},
#  'P0ADN2': {'To': 948274},
#  'P0ADN6': {'To': 1450304},
#  'P0ADP0': {'To': 948357},
#  'P0ADP2': {'To': 948338},
#  'P0ADP7': {'To': 948915},
#  'P0ADP9': {'To': 948348},
#  'P0ADQ2': {'To': 948387},
#  'P0ADQ7': {'To': 947157},
#  'P0ADR6': {'To': 947283},
#  'P0ADR8': {'To': 947266},
#  'P0ADS2': {'To': 947404},
#  'P0ADS6': {'To': 947398},
#  'P0ADS9': {'To': 947453},
#  'P0ADT2': {'To': 945086},
#  'P0ADT5': {'To': 947249},
#  'P0ADT8': {'To': 947555},
#  'P0ADU2': {'To': 947506},
#  'P0ADU5': {'To': 946051},
#  'P0ADV1': {'To': 947920},
#  'P0ADV5': {'To': 947677},
#  'P0ADV7': {'To': 947710},
#  'P0ADV9': {'To': 947722},
#  'P0ADW3': {'To': 947815},
#  'P0ADX1': {'To': 947860},
#  'P0ADX5': {'To': 947871},
#  'P0ADX7': {'To': 947956},
#  'P0ADX9': {'To': 947977},
#  'P0ADY1': {'To': 946056},
#  'P0ADY3': {'To': 947809},
#  'P0ADY7': {'To': 947806},
#  'P0ADZ0': {'To': 947819},
#  'P0ADZ4': {'To': 947686},
#  'P0ADZ7': {'To': 945374},
#  'P0AE01': {'To': 948610},
#  'P0AE06': {'To': 945112},
#  'P0AE08': {'To': 945225},
#  'P0AE12': {'To': 946508},
#  'P0AE14': {'To': 946678},
#  'P0AE18': {'To': 947882},
#  'P0AE22': {'To': 948562},
#  'P0AE28': {'To': 945045},
#  'P0AE39': {'To': 947395},
#  'P0AE45': {'To': 948735},
#  'P0AE48': {'To': 948741},
#  'P0AE52': {'To': 946949},
#  'P0AE63': {'To': 945792},
#  'P0AE67': {'To': 946393},
#  'P0AE78': {'To': 946417},
#  'P0AE82': {'To': 948405},
#  'P0AE85': {'To': 2847688},
#  'P0AE88': {'To': 948404},
#  'P0AE91': {'To': 948920},
#  'P0AEA8': {'To': 947880},
#  'P0AEB0': {'To': 2847743},
#  'P0AEB2': {'To': 945222},
#  'P0AEB5': {'To': 945898},
#  'P0AEB7': {'To': 946357},
#  'P0AEC0': {'To': 946335},
#  'P0AEC3': {'To': 947887},
#  'P0AEC5': {'To': 947255},
#  'P0AED0': {'To': 948007},
#  'P0AED5': {'To': 946424},
#  'P0AED7': {'To': 948313},
#  'P0AED9': {'To': 946479},
#  'P0AEE1': {'To': 947983},
#  'P0AEE3': {'To': 947865},
#  'P0AEE5': {'To': 949041},
#  'P0AEF8': {'To': 948063},
#  'P0AEG1': {'To': 948064},
#  'P0AEG4': {'To': 948353},
#  'P0AEG6': {'To': 947363},
#  'P0AEH1': {'To': 944871},
#  'P0AEH3': {'To': 946750},
#  'P0AEH5': {'To': 946751},
#  'P0AEI1': {'To': 945260},
#  'P0AEI4': {'To': 945465},
#  'P0AEI6': {'To': 945689},
#  'P0AEJ2': {'To': 945511},
#  'P0AEJ6': {'To': 946924},
#  'P0AEK2': {'To': 945645},
#  'P0AEK4': {'To': 945870},
#  'P0AEL0': {'To': 948383},
#  'P0AEL3': {'To': 947909},
#  'P0AEL6': {'To': 947538},
#  'P0AEM0': {'To': 944807},
#  'P0AEM4': {'To': 946684},
#  'P0AEM6': {'To': 948824},
#  'P0AEM9': {'To': 948833},
#  'P0AEN1': {'To': 948325},
#  'P0AEN4': {'To': 944803},
#  'P0AEN8': {'To': 945842},
#  'P0AEP3': {'To': 945730},
#  'P0AEP9': {'To': 947353},
#  'P0AEQ1': {'To': 947473},
#  'P0AEQ3': {'To': 944872},
#  'P0AEQ6': {'To': 945621},
#  'P0AER0': {'To': 948422},
#  'P0AES0': {'To': 947474},
#  'P0AES2': {'To': 947258},
#  'P0AES4': {'To': 946614},
#  'P0AES6': {'To': 948211},
#  'P0AES9': {'To': 948025},
#  'P0AET2': {'To': 948026},
#  'P0AET5': {'To': 948024},
#  'P0AET8': {'To': 946151},
#  'P0AEU0': {'To': 945309},
#  'P0AEU7': {'To': 944861},
#  'P0AEV1': {'To': 945855},
#  'P0AEV4': {'To': 947193},
#  'P0AEV9': {'To': 947428},
#  'P0AEW4': {'To': 947515},
#  'P0AEW6': {'To': 946584},
#  'P0AEW9': {'To': 946676},
#  'P0AEX3': {'To': 947069},
#  'P0AEX5': {'To': 947862},
#  'P0AEX9': {'To': 948538},
#  'P0AEY3': {'To': 947254},
#  'P0AEY5': {'To': 947512},
#  'P0AEZ1': {'To': 948432},
#  'P0AEZ3': {'To': 945741},
#  'P0AEZ9': {'To': 945396},
#  'P0AF03': {'To': 944760},
#  'P0AF08': {'To': 946627},
#  'P0AF12': {'To': 948542},
#  'P0AF18': {'To': 945289},
#  'P0AF20': {'To': 945285},
#  'P0AF24': {'To': 945283},
#  'P0AF26': {'To': 945807},
#  'P0AF28': {'To': 945795},
#  'P0AF36': {'To': 948420},
#  'P0AF43': {'To': 948521},
#  'P0AF50': {'To': 948560},
#  'P0AF52': {'To': 948565},
#  'P0AF67': {'To': 948684},
#  'P0AF70': {'To': 948664},
#  'P0AF90': {'To': 948773},
#  'P0AF93': {'To': 948771},
#  'P0AF96': {'To': 948777},
#  'P0AF98': {'To': 948795},
#  'P0AFA7': {'To': 944822},
#  'P0AFA9': {'To': 947990},
#  'P0AFB1': {'To': 947673},
#  'P0AFB5': {'To': 948360},
#  'P0AFB8': {'To': 948361},
#  'P0AFC3': {'To': 946764},
#  'P0AFC7': {'To': 946738},
#  'P0AFD1': {'To': 946746},
#  'P0AFD4': {'To': 946761},
#  'P0AFD6': {'To': 946757},
#  'P0AFE4': {'To': 947580},
#  'P0AFE8': {'To': 947731},
#  'P0AFF0': {'To': 945136},
#  'P0AFF2': {'To': 946895},
#  'P0AFF6': {'To': 947682},
#  'P0AFG0': {'To': 948485},
#  'P0AFG3': {'To': 945303},
#  'P0AFG6': {'To': 945307},
#  'P0AFG8': {'To': 944834},
#  'P0AFH2': {'To': 945823},
#  'P0AFH6': {'To': 945810},
#  'P0AFH8': {'To': 948895},
#  'P0AFI2': {'To': 947499},
#  'P0AFI5': {'To': 946662},
#  'P0AFI7': {'To': 946806},
#  'P0AFJ1': {'To': 948621},
#  'P0AFJ5': {'To': 945046},
#  'P0AFJ7': {'To': 948009},
#  'P0AFK0': {'To': 948750},
#  'P0AFK2': {'To': 945350},
#  'P0AFK6': {'To': 945691},
#  'P0AFK9': {'To': 945682},
#  'P0AFL3': {'To': 947870},
#  'P0AFL6': {'To': 946970},
#  'P0AFM2': {'To': 947165},
#  'P0AFM4': {'To': 945040},
#  'P0AFM6': {'To': 945887},
#  'P0AFM9': {'To': 945893},
#  'P0AFP4': {'To': 945337},
#  'P0AFP6': {'To': 945824},
#  'P0AFQ7': {'To': 945656},
#  'P0AFR4': {'To': 945854},
#  'P0AFS3': {'To': 949096},
#  'P0AFT2': {'To': 949105},
#  'P0AFT5': {'To': 949024},
#  'P0AFU8': {'To': 945848},
#  'P0AFV4': {'To': 946686},
#  'P0AFW0': {'To': 948327},
#  'P0AFW2': {'To': 945567},
#  'P0AFW4': {'To': 947546},
#  'P0AFW8': {'To': 944891},
#  'P0AFX0': {'To': 947718},
#  'P0AFX4': {'To': 948496},
#  'P0AFX7': {'To': 947053},
#  'P0AFX9': {'To': 947054},
#  'P0AFY6': {'To': 946884},
#  'P0AFY8': {'To': 945272},
#  'P0AFZ1': {'To': 946994},
#  'P0AFZ3': {'To': 944774},
#  'P0AG00': {'To': 944815},
#  'P0AG03': {'To': 949033},
#  'P0AG14': {'To': 945858},
#  'P0AG16': {'To': 946794},
#  'P0AG18': {'To': 949031},
#  'P0AG20': {'To': 947244},
#  'P0AG24': {'To': 948159},
#  'P0AG27': {'To': 948131},
#  'P0AG30': {'To': 948297},
#  'P0AG40': {'To': 949129},
#  'P0AG51': {'To': 947797},
#  'P0AG55': {'To': 947803},
#  'P0AG59': {'To': 947801},
#  'P0AG67': {'To': 945536},
#  'P0AG71': {'To': 948966},
#  'P0AG76': {'To': 945049},
#  'P0AG78': {'To': 948411},
#  'P0AG80': {'To': 947962},
#  'P0AG82': {'To': 948237},
#  'P0AG84': {'To': 947478},
#  'P0AG86': {'To': 948123},
#  'P0AG90': {'To': 949133},
#  'P0AG93': {'To': 949120},
#  'P0AG96': {'To': 948486},
#  'P0AG99': {'To': 947720},
#  'P0AGA2': {'To': 947799},
#  'P0AGA6': {'To': 948178},
#  'P0AGB0': {'To': 948913},
#  'P0AGB6': {'To': 947050},
#  'P0AGC0': {'To': 948201},
#  'P0AGC3': {'To': 948908},
#  'P0AGD1': {'To': 945343},
#  'P0AGD3': {'To': 944953},
#  'P0AGD7': {'To': 947102},
#  'P0AGE0': {'To': 948570},
#  'P0AGE4': {'To': 947605},
#  'P0AGE6': {'To': 948225},
#  'P0AGE9': {'To': 945314},
#  'P0AGF2': {'To': 947274},
#  'P0AGF4': {'To': 948529},
#  ...}

# %%
# de results translated to gene IDs
de_results_entrez = de_results
de_results_entrez["Unnamed: 0"] = [uniprot_to_entrez[i]['To'] if i in uniprot_to_entrez else "nan" for i in de_results_entrez["Unnamed: 0"]]
de_results_entrez = de_results_entrez[de_results_entrez["Unnamed: 0"] != "nan"]
de_results_ids = [list(de_results[de_results[i] != 0]["Unnamed: 0"]) for i in de_results.columns]

# %%
# Get ontologies (from http://geneontology.org/ontology/go-basic.obo)
from goatools.base import download_go_basic_obo
from goatools.obo_parser import GODag
import os
obo_fname = download_go_basic_obo()  # Download data
obodag = GODag(obo_fname)  # Load data

# Get associations genes <-> ontologies (from ftp://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz)
from goatools.base import download_ncbi_associations
from goatools.anno.genetogo_reader import Gene2GoReader
gene2go_fname = download_ncbi_associations()  # Download data
objanno = Gene2GoReader(gene2go_fname, taxids=[511145])  # Read data (only for e. coli)
ns2assoc = objanno.get_ns2assc()

#Remove downloaded data:
os.remove(obo_fname)
os.remove(gene2go_fname)
# Out:
# requests.get(http://purl.obolibrary.org/obo/go/go-basic.obo, stream=True)
#   WROTE: go-basic.obo
#
# go-basic.obo: fmt(1.2) rel(2020-02-21) 47,245 GO Terms
# FTP RETR ftp.ncbi.nlm.nih.gov gene/DATA gene2go.gz -> gene2go.gz
#   gunzip gene2go.gz
# HMS:0:00:03.399185  43,485 annotations,  3,893 genes,  4,109 GOs, 1 taxids READ: gene2go

# %% [markdown]
# # Read in translation from gene to go
#
# chosen taxid E. coli corresponds to Escherichia coli str. K-12 substr. MG1655, as found here: https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?mode=Info&id=511145&lvl=3&lin=f&keep=1&srchmode=1&unlock

# %%
from __future__ import print_function
from goatools.anno.genetogo_reader import Gene2GoReader

for nspc, id2gos in ns2assoc.items():
    print("{NS} {N:,} annotated e. coli genes".format(NS=nspc, N=len(id2gos)))
# Out:
# CC 2,923 annotated e. coli genes
# BP 3,439 annotated e. coli genes
# MF 3,255 annotated e. coli genes

# %%
# Over-representation object:
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS
population = de_results_entrez["Unnamed: 0"]

goeaobj = GOEnrichmentStudyNS(
    population,  # Population (all mapped yeast genes in Entrez format)
    ns2assoc,  # geneid/GO associations
    obodag,  # Ontologies
    propagate_counts = False,  # ???
    alpha = 0.05,  # default significance cut-off
    methods = ['fdr_bh'])  # default multipletest correction method
# Out:
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  88%  1,764 of  1,997 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  81%  1,619 of  1,997 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  89%  1,777 of  1,997 population items found in association

# %% [markdown]
# # Run Gene ontology
# run gene ontology enrichment on the top genes contained within the

# %%
# %%capture
# 'p_' means "pvalue". 'fdr_bh' is the multipletest method we are currently using.
# genes to be analysed
geneids_study = list(de_results_entrez["Unnamed: 0"][0:400])

goea_results_sig = []
for i in de_results_ids:
    goea_results_all = goeaobj.run_study(i)
    goea_results_sig.append([r for r in goea_results_all if r.p_fdr_bh < 0.05])
# Out:
#  88%  1,764 of  1,997 study items found in association
#  97%  1,997 of  2,057 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,470 GO terms are associated with  1,764 of  1,998 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  81%  1,619 of  1,997 study items found in association
#  97%  1,997 of  2,057 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      167 GO terms are associated with  1,619 of  1,998 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,777 of  1,997 study items found in association
#  97%  1,997 of  2,057 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,610 GO terms are associated with  1,777 of  1,998 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,415 of  1,583 study items found in association
#  97%  1,583 of  1,633 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,319 GO terms are associated with  1,415 of  1,584 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       87 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  84%  1,329 of  1,583 study items found in association
#  97%  1,583 of  1,633 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      154 GO terms are associated with  1,329 of  1,584 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  3 enriched +   4 purified): statsmodels fdr_bh
#      921 study items associated with significant GO IDs (enriched)
#      356 study items associated with significant GO IDs (purified)
#  90%  1,421 of  1,583 study items found in association
#  97%  1,583 of  1,633 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,410 GO terms are associated with  1,421 of  1,584 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#      275 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,284 of  1,442 study items found in association
#  96%  1,442 of  1,495 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,269 GO terms are associated with  1,284 of  1,443 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       83 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  84%  1,217 of  1,442 study items found in association
#  96%  1,442 of  1,495 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      144 GO terms are associated with  1,217 of  1,443 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  4 enriched +   5 purified): statsmodels fdr_bh
#      840 study items associated with significant GO IDs (enriched)
#      318 study items associated with significant GO IDs (purified)
#  89%  1,287 of  1,442 study items found in association
#  96%  1,442 of  1,495 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,304 GO terms are associated with  1,287 of  1,443 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
#       35 study items associated with significant GO IDs (enriched)
#      179 study items associated with significant GO IDs (purified)
#  89%  1,270 of  1,425 study items found in association
#  97%  1,425 of  1,474 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,256 GO terms are associated with  1,270 of  1,426 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,186 of  1,425 study items found in association
#  97%  1,425 of  1,474 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      140 GO terms are associated with  1,186 of  1,426 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  4 enriched +   4 purified): statsmodels fdr_bh
#      814 study items associated with significant GO IDs (enriched)
#      317 study items associated with significant GO IDs (purified)
#  90%  1,279 of  1,425 study items found in association
#  97%  1,425 of  1,474 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,322 GO terms are associated with  1,279 of  1,426 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
#      251 study items associated with significant GO IDs (enriched)
#      122 study items associated with significant GO IDs (purified)
#  88%  1,239 of  1,400 study items found in association
#  96%  1,400 of  1,455 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,255 GO terms are associated with  1,239 of  1,401 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#      154 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  84%  1,174 of  1,400 study items found in association
#  96%  1,400 of  1,455 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      141 GO terms are associated with  1,174 of  1,401 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  4 enriched +   4 purified): statsmodels fdr_bh
#      804 study items associated with significant GO IDs (enriched)
#      314 study items associated with significant GO IDs (purified)
#  90%  1,255 of  1,400 study items found in association
#  96%  1,400 of  1,455 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,302 GO terms are associated with  1,255 of  1,401 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,237 of  1,395 study items found in association
#  96%  1,395 of  1,447 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,240 GO terms are associated with  1,237 of  1,396 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       75 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  84%  1,173 of  1,395 study items found in association
#  96%  1,395 of  1,447 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      141 GO terms are associated with  1,173 of  1,396 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  3 enriched +   3 purified): statsmodels fdr_bh
#      815 study items associated with significant GO IDs (enriched)
#      302 study items associated with significant GO IDs (purified)
#  90%  1,251 of  1,395 study items found in association
#  96%  1,395 of  1,447 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,311 GO terms are associated with  1,251 of  1,396 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,157 of  1,300 study items found in association
#  96%  1,300 of  1,351 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,221 GO terms are associated with  1,157 of  1,301 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#      153 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  85%  1,099 of  1,300 study items found in association
#  96%  1,300 of  1,351 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      136 GO terms are associated with  1,099 of  1,301 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  3 enriched +   4 purified): statsmodels fdr_bh
#      760 study items associated with significant GO IDs (enriched)
#      285 study items associated with significant GO IDs (purified)
#  90%  1,167 of  1,300 study items found in association
#  96%  1,300 of  1,351 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,261 GO terms are associated with  1,167 of  1,301 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,229 of  1,381 study items found in association
#  96%  1,381 of  1,432 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,245 GO terms are associated with  1,229 of  1,382 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
#       73 study items associated with significant GO IDs (enriched)
#        9 study items associated with significant GO IDs (purified)
#  85%  1,169 of  1,381 study items found in association
#  96%  1,381 of  1,432 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      141 GO terms are associated with  1,169 of  1,382 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
#      667 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,244 of  1,381 study items found in association
#  96%  1,381 of  1,432 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,304 GO terms are associated with  1,244 of  1,382 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,366 of  1,521 study items found in association
#  97%  1,521 of  1,575 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,321 GO terms are associated with  1,366 of  1,522 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  85%  1,288 of  1,521 study items found in association
#  97%  1,521 of  1,575 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      146 GO terms are associated with  1,288 of  1,522 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#      853 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  91%  1,379 of  1,521 study items found in association
#  97%  1,521 of  1,575 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,393 GO terms are associated with  1,379 of  1,522 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,394 of  1,563 study items found in association
#  97%  1,563 of  1,614 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,320 GO terms are associated with  1,394 of  1,564 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,297 of  1,563 study items found in association
#  97%  1,563 of  1,614 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      148 GO terms are associated with  1,297 of  1,564 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#      719 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,405 of  1,563 study items found in association
#  97%  1,563 of  1,614 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,385 GO terms are associated with  1,405 of  1,564 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,430 of  1,610 study items found in association
#  97%  1,610 of  1,660 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,346 GO terms are associated with  1,430 of  1,611 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,336 of  1,610 study items found in association
#  97%  1,610 of  1,660 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      153 GO terms are associated with  1,336 of  1,611 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#      734 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,443 of  1,610 study items found in association
#  97%  1,610 of  1,660 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,431 GO terms are associated with  1,443 of  1,611 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,424 of  1,605 study items found in association
#  97%  1,605 of  1,657 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,323 GO terms are associated with  1,424 of  1,606 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,328 of  1,605 study items found in association
#  97%  1,605 of  1,657 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      146 GO terms are associated with  1,328 of  1,606 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  2 enriched +   1 purified): statsmodels fdr_bh
#      877 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,435 of  1,605 study items found in association
#  97%  1,605 of  1,657 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,413 GO terms are associated with  1,435 of  1,606 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  88%  1,416 of  1,605 study items found in association
#  97%  1,605 of  1,662 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,315 GO terms are associated with  1,416 of  1,606 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,331 of  1,605 study items found in association
#  97%  1,605 of  1,662 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      148 GO terms are associated with  1,331 of  1,606 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  2 enriched +   4 purified): statsmodels fdr_bh
#      734 study items associated with significant GO IDs (enriched)
#      366 study items associated with significant GO IDs (purified)
#  89%  1,427 of  1,605 study items found in association
#  97%  1,605 of  1,662 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,409 GO terms are associated with  1,427 of  1,606 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,414 of  1,594 study items found in association
#  97%  1,594 of  1,644 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,322 GO terms are associated with  1,414 of  1,595 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  0 enriched +   1 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#       19 study items associated with significant GO IDs (purified)
#  83%  1,327 of  1,594 study items found in association
#  97%  1,594 of  1,644 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      153 GO terms are associated with  1,327 of  1,595 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  2 enriched +   4 purified): statsmodels fdr_bh
#      888 study items associated with significant GO IDs (enriched)
#      364 study items associated with significant GO IDs (purified)
#  89%  1,426 of  1,594 study items found in association
#  97%  1,594 of  1,644 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,430 GO terms are associated with  1,426 of  1,595 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,331 of  1,502 study items found in association
#  97%  1,502 of  1,556 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,267 GO terms are associated with  1,331 of  1,503 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,253 of  1,502 study items found in association
#  97%  1,502 of  1,556 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      140 GO terms are associated with  1,253 of  1,503 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  3 enriched +   5 purified): statsmodels fdr_bh
#      858 study items associated with significant GO IDs (enriched)
#      338 study items associated with significant GO IDs (purified)
#  89%  1,340 of  1,502 study items found in association
#  97%  1,502 of  1,556 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,338 GO terms are associated with  1,340 of  1,503 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  88%  1,300 of  1,474 study items found in association
#  97%  1,474 of  1,525 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,247 GO terms are associated with  1,300 of  1,475 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,227 of  1,474 study items found in association
#  97%  1,474 of  1,525 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      141 GO terms are associated with  1,227 of  1,475 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#      835 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,309 of  1,474 study items found in association
#  97%  1,474 of  1,525 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,319 GO terms are associated with  1,309 of  1,475 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  88%  1,309 of  1,489 study items found in association
#  97%  1,489 of  1,539 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,275 GO terms are associated with  1,309 of  1,490 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  0 enriched +   1 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
#  83%  1,241 of  1,489 study items found in association
#  97%  1,489 of  1,539 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      148 GO terms are associated with  1,241 of  1,490 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  2 enriched +   5 purified): statsmodels fdr_bh
#      839 study items associated with significant GO IDs (enriched)
#      334 study items associated with significant GO IDs (purified)
#  88%  1,316 of  1,489 study items found in association
#  97%  1,489 of  1,539 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,341 GO terms are associated with  1,316 of  1,490 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,243 of  1,388 study items found in association
#  97%  1,388 of  1,435 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,243 GO terms are associated with  1,243 of  1,389 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  2 enriched +   4 purified): statsmodels fdr_bh
#      153 study items associated with significant GO IDs (enriched)
#       16 study items associated with significant GO IDs (purified)
#  83%  1,157 of  1,388 study items found in association
#  97%  1,388 of  1,435 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      132 GO terms are associated with  1,157 of  1,389 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  3 enriched +   4 purified): statsmodels fdr_bh
#      804 study items associated with significant GO IDs (enriched)
#      303 study items associated with significant GO IDs (purified)
#  90%  1,254 of  1,388 study items found in association
#  97%  1,388 of  1,435 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,301 GO terms are associated with  1,254 of  1,389 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,326 of  1,481 study items found in association
#  97%  1,481 of  1,534 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,292 GO terms are associated with  1,326 of  1,482 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
#       77 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
#  84%  1,241 of  1,481 study items found in association
#  97%  1,481 of  1,534 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      142 GO terms are associated with  1,241 of  1,482 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  3 enriched +   3 purified): statsmodels fdr_bh
#      856 study items associated with significant GO IDs (enriched)
#      328 study items associated with significant GO IDs (purified)
#  91%  1,341 of  1,481 study items found in association
#  97%  1,481 of  1,534 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,359 GO terms are associated with  1,341 of  1,482 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,346 of  1,520 study items found in association
#  97%  1,520 of  1,571 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,288 GO terms are associated with  1,346 of  1,521 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       86 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  83%  1,260 of  1,520 study items found in association
#  97%  1,520 of  1,571 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      142 GO terms are associated with  1,260 of  1,521 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  3 enriched +   4 purified): statsmodels fdr_bh
#      865 study items associated with significant GO IDs (enriched)
#      333 study items associated with significant GO IDs (purified)
#  90%  1,363 of  1,520 study items found in association
#  97%  1,520 of  1,571 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,381 GO terms are associated with  1,363 of  1,521 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  89%  1,285 of  1,447 study items found in association
#  96%  1,447 of  1,502 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,275 GO terms are associated with  1,285 of  1,448 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  1 enriched +   1 purified): statsmodels fdr_bh
#       82 study items associated with significant GO IDs (enriched)
#       21 study items associated with significant GO IDs (purified)
#  84%  1,218 of  1,447 study items found in association
#  96%  1,447 of  1,502 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      144 GO terms are associated with  1,218 of  1,448 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  2 enriched +   2 purified): statsmodels fdr_bh
#      680 study items associated with significant GO IDs (enriched)
#      293 study items associated with significant GO IDs (purified)
#  90%  1,305 of  1,447 study items found in association
#  96%  1,447 of  1,502 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,311 GO terms are associated with  1,305 of  1,448 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,229 of  1,370 study items found in association
#  97%  1,370 of  1,418 study items found in population(1997)
# Calculating 1,470 uncorrected p-values using fisher_scipy_stats
#    1,470 GO terms are associated with  1,764 of  1,997 population items
#    1,226 GO terms are associated with  1,229 of  1,371 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       78 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  85%  1,158 of  1,370 study items found in association
#  97%  1,370 of  1,418 study items found in population(1997)
# Calculating 167 uncorrected p-values using fisher_scipy_stats
#      167 GO terms are associated with  1,619 of  1,997 population items
#      138 GO terms are associated with  1,158 of  1,371 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#      782 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#  90%  1,238 of  1,370 study items found in association
#  97%  1,370 of  1,418 study items found in population(1997)
# Calculating 1,610 uncorrected p-values using fisher_scipy_stats
#    1,610 GO terms are associated with  1,777 of  1,997 population items
#    1,287 GO terms are associated with  1,238 of  1,371 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
from goatools.godag_plot import plot_gos, plot_results, plot_goid2goobj

# goeaobj.wr_tsv(join(FINAL, "p_values_" + group_name + ".tsv"), goea_results_sig)

# save results of goe analysis
j = 0
for i in de_results.columns[1:]:
    goeaobj.wr_tsv("/Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_{}.tsv".format(i), goea_results_sig[j])
    j += 1
# Out:
#       0 items. NOT WRITING /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_LB-Glucose.tsv
#       9 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Glycerol...AA-Glucose.tsv
#      12 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Acetate-Glucose.tsv
#      10 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Fumarate-Glucose.tsv
#      10 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Glucosamine-Glucose.tsv
#       7 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Glycerol-Glucose.tsv
#       9 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Pyruvate-Glucose.tsv
#       6 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Chemostat.µ.0.5-Glucose.tsv
#       2 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Chemostat.µ.0.35-Glucose.tsv
#       2 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Chemostat.µ.0.20-Glucose.tsv
#       2 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Chemostat.µ.0.12-Glucose.tsv
#       3 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Stationary.phase.1.day-Glucose.tsv
#       6 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Stationary.phase.3.days-Glucose.tsv
#       7 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Osmotic.stress.glucose-Glucose.tsv
#       8 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_X42.C.glucose-Glucose.tsv
#       3 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_pH6.glucose-Glucose.tsv
#       8 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Xylose-Glucose.tsv
#      13 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Mannose-Glucose.tsv
#       8 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Galactose-Glucose.tsv
#       8 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Succinate-Glucose.tsv
#       6 items WROTE: /Users/jonas/Documents/masters/thesis/thesis/data/final/go_analysis/p_values_go_Fructose-Glucose.tsv

# %%
# plot_results("/Users/jonas/Documents/masters/thesis/thesis/results/figures/nbt3102_{NS}.png", goea_results_sig)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Library/Python/3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# /Library/Python/3.7/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-94-01081ab4859d> in <module>
# ----> 1 plot_results("/Users/jonas/Documents/masters/thesis/thesis/results/figures/nbt3102_{NS}.png", goea_results_sig)
#
# /Library/Python/3.7/site-packages/goatools/godag_plot.py in plot_results(fout_png, goea_results, *args, **kws)
#      35         for ns_name, ns_res in ns2goea_results.items():
#      36             png = fout_png.format(NS=ns_name)
# ---> 37             plt_goea_results(png, ns_res, *args, **kws)
#      38
#      39 def plt_goea_results(fout_png, goea_results, *args, **kws):
#
# /Library/Python/3.7/site-packages/goatools/godag_plot.py in plt_goea_results(fout_png, goea_results, *args, **kws)
#      42     godagsmall = OboToGoDagSmall(goea_results=goea_results).godag
#      43     godagplot = GODagSmallPlot(godagsmall, *args, goea_results=goea_results, **kws)
# ---> 44     godagplot.plt(fout_png, engine)
#      45
#      46 class GODagPltVars(object):
#
# /Library/Python/3.7/site-packages/goatools/godag_plot.py in plt(self, fout_img, engine)
#     161         """Plot using pydot, graphviz, or GML."""
#     162         if engine == "pydot":
# --> 163             self._plt_pydot(fout_img)
#     164         elif engine == "pygraphviz":
#     165             raise Exception("TO BE IMPLEMENTED SOON: ENGINE pygraphvis")
#
# /Library/Python/3.7/site-packages/goatools/godag_plot.py in _plt_pydot(self, fout_img)
#     173         dag = self._get_pydot_graph()
#     174         img_fmt = os.path.splitext(fout_img)[1][1:]
# --> 175         dag.write(fout_img, format=img_fmt)
#     176         self.log.write("  {GO_USR:>3} usr {GO_ALL:>3} GOs  WROTE: {F}\n".format(
#     177             F=fout_img,
#
# /Library/Python/3.7/site-packages/pydot.py in write(self, path, prog, format, encoding)
#    1815                 f.write(s)
#    1816         else:
# -> 1817             s = self.create(prog, format, encoding=encoding)
#    1818             with io.open(path, mode='wb') as f:
#    1819                 f.write(s)
#
# /Library/Python/3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [Errno 2] "dot" not found in path.
