# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


# make folders specific for certain data
folder_name = ''
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(RAW_EXTERNAL, folder_name)):
        os.makedirs(join(RAW_EXTERNAL, folder_name))

    if not exists(join(INTERMEDIATE, folder_name)):
        os.makedirs(join(INTERMEDIATE, folder_name))

    if not exists(join(FINAL, folder_name)):
        os.makedirs(join(FINAL, folder_name))


print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %%
import cobra
import os
import pandas as pd
import cameo
import wget
import ssl


#E. coli model:
#eColi_model = cameo.load_model("iML1515")


#E. coli model:
ssl._create_default_https_context = ssl._create_unverified_context
wget.download("https://raw.githubusercontent.com/BenjaSanchez/notebooks/master/e_coli_simulations/eciML1515.xml")
eColi_Model = cobra.io.read_sbml_model("eciML1515.xml")
os.remove("eciML1515.xml")



#proteomics data:
proteomics_dataset = "~/Documents/masters/thesis/thesis/data/raw_internal/proteomics/protein_values.csv"

# %%
from collections import namedtuple
from cobra.medium.boundary_types import find_external_compartment
from cobra.io.dict import reaction_to_dict
import pandas as pd
import numpy as np

def apply_medium(model, is_ec_model, medium):
    operations = []
    warnings = []
    errors = []

    # Convert the list of dicts to a set of namedtuples to avoid duplicates, as
    # looking up metabolites in the model is a somewhat expensive operation.
    Compound = namedtuple("Compound", ["id", "namespace"])
    medium = set(Compound(id=c["identifier"], namespace=c["namespace"]) for c in medium)

    # Add trace metals
    medium.update(
        [
            Compound(id="CHEBI:25517", namespace="chebi"),
            Compound(id="CHEBI:25368", namespace="chebi"),
        ]
    )

    try:
        extracellular = find_external_compartment(model)
    except RuntimeError as error:
        # cobrapy throws RuntimeError if it for any reason is unable to find an
        # external compartment. See:
        # https://github.com/opencobra/cobrapy/blob/95d920d135fa824e6087f1fcbc88d50882da4dab/cobra/medium/boundary_types.py#L26
        message = (
            f"Cannot find an external compartment in model {model.id}: {str(error)}"
        )
        errors.append(message)
        # Cannot continue without knowing the external compartment, so
        # immediately return the error.
        return operations, warnings, errors

    # Create a map of exchange reactions and corresponding fluxes to apply to
    # the medium.
    medium_mapping = {}
    for compound in medium:
        print(compound)
        try:
            extracellular_metabolite = find_metabolite(
                model, compound.id, compound.namespace, extracellular
            )
        except MetaboliteNotFound:
            warning = (
                f"Cannot add medium compound '{compound.id}' - metabolite not found in "
                f"extracellular compartment '{extracellular}'"
            )
            warnings.append(warning)
        else:
            exchange_reactions = extracellular_metabolite.reactions.intersection(
                model.exchanges
            )
            if is_ec_model and len(exchange_reactions) == 2:
                exchange_reactions = get_ec_exchange_reaction(exchange_reactions, True)
            if len(exchange_reactions) != 1:
                errors.append(
                    f"Medium compound metabolite '{extracellular_metabolite.id}' has "
                    f"{len(exchange_reactions)} exchange reactions in the model; "
                    f"expected 1"
                )
                continue
            exchange_reaction = next(iter(exchange_reactions))

            # If someone already figured out the uptake rate for the compound, it's
            # likely more accurate than our assumptions, so keep it
            if exchange_reaction.id in model.medium:
                medium_mapping[exchange_reaction.id] = model.medium[
                    exchange_reaction.id
                ]
                continue

            if not extracellular_metabolite.formula:
                warning = (
                    f"No formula for metabolite '{extracellular_metabolite.id}', cannot"
                    f" check if it is a carbon source"
                )
                warnings.append(warning)
                # If we don't know, it's most likely that the metabolite does not have a
                # higher uptake rate than a carbon source, so set the bound still to 10
                medium_mapping[exchange_reaction.id] = 10
            elif "C" in extracellular_metabolite.elements:
                # Limit the uptake rate for carbon sources to 10
                medium_mapping[exchange_reaction.id] = 10
            else:
                medium_mapping[exchange_reaction.id] = 1000

    # Apply the medium to the model, letting cobrapy deal with figuring out the correct
    # bounds to change
    model.medium = medium_mapping

    # Add all exchange reactions to operations, to make sure any changed bounds is
    # properly updated
    for reaction in model.exchanges:
        operations.append(
            {
                "operation": "modify",
                "type": "reaction",
                "id": reaction.id,
                "data": reaction_to_dict(reaction),
            }
        )

    return operations, warnings, errors


def apply_measurements(
    model,
    biomass_reaction,
    is_ec_model,
    fluxomics,
    metabolomics,
    proteomics,
    uptake_secretion_rates,
    molar_yields,
    growth_rate,
):
    operations = []
    warnings = []
    errors = []

    def bounds(measurement, uncertainty):
        """Return resolved bounds based on measurement and uncertainty"""
        if uncertainty:
            return (measurement - uncertainty, measurement + uncertainty)
        else:
            return (measurement, measurement)

    # If an enzyme constrained model with proteomics was supplied, flexibilize the
    # proteomics data and redefine the growth rate based on simulations.
    if growth_rate and proteomics and is_ec_model:
        growth_rate, proteomics, prot_warnings = flexibilize_proteomics(
            model, biomass_reaction, growth_rate, proteomics
        )
        for warning in prot_warnings:
            warnings.append(warning)

    # Constrain the model with the observed growth rate
    if growth_rate:
        reaction = model.reactions.get_by_id(biomass_reaction)
        reaction.bounds = bounds(growth_rate["measurement"], growth_rate["uncertainty"])
        operations.append(
            {
                "operation": "modify",
                "type": "reaction",
                "id": reaction.id,
                "data": reaction_to_dict(reaction),
            }
        )

    for measure in fluxomics:
        try:
            reaction = model.reactions.get_by_id(measure["identifier"])
        except KeyError:
            errors.append(
                f"Cannot find reaction '{measure['identifier']}' in the model"
            )
        else:
            reaction.bounds = bounds(measure["measurement"], measure["uncertainty"])
            operations.append(
                {
                    "operation": "modify",
                    "type": "reaction",
                    "id": reaction.id,
                    "data": reaction_to_dict(reaction),
                }
            )

    for metabolite in metabolomics:
        warning = (
            f"Cannot apply metabolomics measure for '{metabolite['identifier']}'; "
            f"feature has not yet been implemented"
        )
        warnings.append(warning)

    for measure in proteomics:
        if is_ec_model:
            try:
                reaction = model.reactions.get_by_id(
                    f"prot_{measure['identifier']}_exchange"
                )
            except KeyError:
                warning = f"Cannot find protein '{measure['identifier']}' in the model"
                warnings.append(warning)
            else:
                # measurement only modifies the upper bound (enzymes can be unsaturated)
                lb, ub = bounds(measure["measurement"], measure["uncertainty"])
                reaction.bounds = 0, ub
                operations.append(
                    {
                        "operation": "modify",
                        "type": "reaction",
                        "id": reaction.id,
                        "data": reaction_to_dict(reaction),
                    }
                )
        else:
            warning = (
                f"Cannot apply proteomics measurements for "
                f"non enzyme-constrained model {model.id}"
            )
            warnings.append(warning)
            break

    for rate in uptake_secretion_rates:
        try:
            metabolite = find_metabolite(
                model, rate["identifier"], rate["namespace"], "e"
            )
        except MetaboliteNotFound as error:
            errors.append(str(error))
        else:
            exchange_reactions = metabolite.reactions.intersection(model.exchanges)
            if is_ec_model and len(exchange_reactions) == 2:
                exchange_reactions = get_ec_exchange_reaction(
                    exchange_reactions, rate["measurement"] < 0
                )
            if len(exchange_reactions) != 1:
                errors.append(
                    f"Measured metabolite '{metabolite['identifier']}' has "
                    f"{len(exchange_reactions)} exchange reactions in the model; "
                    f"expected 1"
                )
                continue
            exchange_reaction = next(iter(exchange_reactions))
            lower_bound, upper_bound = bounds(rate["measurement"], rate["uncertainty"])

            # data is adjusted assuming a forward exchange reaction, i.e. x -->
            # (sign = -1), so if we instead actually have --> x, then multiply with -1
            direction = exchange_reaction.metabolites[metabolite]
            if direction > 0:
                lower_bound, upper_bound = -1 * lower_bound, -1 * upper_bound
            exchange_reaction.bounds = lower_bound, upper_bound
            operations.append(
                {
                    "operation": "modify",
                    "type": "reaction",
                    "id": exchange_reaction.id,
                    "data": reaction_to_dict(exchange_reaction),
                }
            )

    for molar_yield in molar_yields:
        warning = (
            f"Cannot apply molar yield measurement for '"
            f"{molar_yield['product_identifier']}/{molar_yield['substrate_identifier']}"
            f"'; feature has not yet been implemented"
        )
        warnings.append(warning)
    return operations, warnings, errors


def flexibilize_proteomics(model, biomass_reaction, growth_rate, proteomics):
    # reset growth rate in model:
    model.reactions.get_by_id(biomass_reaction).bounds = (0, 1000)

    # build a table with protein ids, met ids in model and values to constrain with:
    prot_df = pd.DataFrame()
    for protein in proteomics:
        protein_id = protein["identifier"]
        lb, ub = bounds(protein["measurement"], protein["uncertainty"])
        
        for met in model.metabolites.query(lambda m: protein_id in m.id):
            new_row = pd.DataFrame(
                data={"met_id": met.id, "value": ub}, index=[protein_id]
            )
            prot_df = prot_df.append(new_row)

    # constrain the model with all proteins and optimize:
    
    limit_proteins(model, prot_df["value"])
    solution = model.optimize()
    new_growth_rate = solution.objective_value

    # while the model cannot grow to the desired level, remove the protein with
    # the highest shadow price:
    minimal_growth, ub = bounds(growth_rate["measurement"], growth_rate["uncertainty"])
    prots_to_remove = []
    warnings = []
    while new_growth_rate < minimal_growth and not prot_df.empty:
        # get most influential protein in model:
        top_protein = top_shadow_prices(solution, list(prot_df["met_id"]))
        value = top_protein[top_protein.index[0]]
        top_protein = top_protein.index[0]
        top_protein = prot_df.index[prot_df["met_id"] == top_protein][0]
        print("working: " + top_protein + " (sp=" + str(value) + ") - mu = " + str(new_growth_rate))

        # update data: append protein to list, remove from current dataframe and
        # increase the corresponding upper bound to +1000:
        prots_to_remove.append(top_protein)
        prot_df = prot_df.drop(labels=top_protein)
        limit_proteins(model, pd.Series(data=[1000], index=[top_protein]))
        warning = (
            f"Removed protein '{top_protein}' from the proteomics data for feasible "
            f"simulations"
        )
        warnings.append(warning)

        # re-compute solution:
        solution = model.optimize()
        if solution.objective_value == new_growth_rate:  # the algorithm is stuck
            break
        new_growth_rate = solution.objective_value

    # update growth rate if optimization was not successful:
    if new_growth_rate < minimal_growth:
        if growth_rate["uncertainty"]:
            growth_rate["measurement"] = new_growth_rate + growth_rate["uncertainty"]
        else:
            growth_rate["measurement"] = new_growth_rate

    # update proteomics by removing flexibilized proteins:
    for protein in prots_to_remove:
        index = next(
            (
                index
                for (index, dic) in enumerate(proteomics)
                if dic["identifier"] == protein
            ),
            None,
        )
        del proteomics[index]

    return growth_rate, proteomics, warnings


def limit_proteins(model, measurements):
    for protein_id, measure in measurements.items():
        try:
            rxn = model.reactions.get_by_id(f"prot_{protein_id}_exchange")
        except KeyError:
            pass
        else:
            # update only upper_bound (as enzymes can be unsaturated):
            rxn.bounds = (0, measure)
    return


def top_shadow_prices(solution, met_ids, top=1):
    shadow_pr = solution.shadow_prices
    shadow_pr = shadow_pr.loc[shadow_pr.index.isin(met_ids)]
    return shadow_pr.sort_values()[:top]


def bounds(measurement, uncertainty):
    if uncertainty:
        return measurement - uncertainty, measurement + uncertainty
    else:
        return measurement, measurement


def find_metabolite(model, id, namespace, compartment):
    def query_fun(metabolite):
        if metabolite.compartment != compartment:
            return False

        result = _query_item(metabolite, id, namespace)
        if result:
            return result

        # If the original query fails, retry with the compartment id appended
        # to the identifier (a regular convenation with BiGG metabolites, but
        # may also be the case in other namespaces).
        return _query_item(metabolite, f"{id}_{compartment}", namespace)

    metabolites = model.metabolites.query(query_fun)
    if len(metabolites) == 0:
        raise MetaboliteNotFound(
            f"Could not find metabolite {id} or {id}_{compartment} in "
            f"namespace {namespace} and compartment {compartment} for model "
            f"{model.id}"
        )
    elif len(metabolites) > 1:
        raise IndexError(f"Expected single metabolite, found {metabolites}")
    else:
        return metabolites[0]

def _query_item(item, query_id, query_namespace):
    # Try the default identifiers (without confirming the namespace)
    if query_id.lower() == item.id.lower():
        return True

    # Otherwise, try to find a case insensitive match for the namespace key
    for namespace in item.annotation:
        if query_namespace.lower() == namespace.lower():
            annotation = item.annotation[namespace]
            # Compare the identifier case insensitively as well
            # Annotations may contain a single id or a list of ids
            if isinstance(annotation, list):
                if query_id.lower() in [i.lower() for i in annotation]:
                    return True
            else:
                if query_id.lower() == annotation.lower():
                    return True
    return False

def compute_measurements(proteomics, ecModel):
    measurements = pd.DataFrame()
    for protein in proteomics:
        protein_id = protein["identifier"]
        lb, ub = bounds(protein["measurement"], protein["uncertainty"])
        for met in ecModel.metabolites:
            if protein_id in met.id:
                new_row = pd.DataFrame(data={"met_id": met.id, "value": ub}, index=[protein_id])
                measurements = measurements.append(new_row)
    return measurements

def get_ec_exchange_reaction(exchange_reactions, consumption):
    ec_exchange_reaction = []
    for reaction in exchange_reactions:
        if (reaction.products and consumption) or (reaction.reactants and not consumption):
            ec_exchange_reaction.append(reaction)
    return ec_exchange_reaction

class MetaboliteNotFound(Exception):
    pass

# %%
def reset_proteomics():
    data = pd.read_csv(proteomics_dataset)  # yeast

    # cols_measurements 
    cols_measurements = data.columns[data.columns.get_loc("Glucose"):data.columns.get_loc("Fructose")]

    # cols uncertainties
    cols_uncertainties = data.columns[data.columns.get_loc("Glucose.1"):data.columns.get_loc("Fructose.1")]

    # E. coli
    proteomics_all = dict()
    for i in range(0,len(cols_measurements)):
        measurement = cols_measurements[i]
        proteomics = []
        for j in range(0,data.shape[0]):
            protein = {"identifier":data["Uniprot Accession"][j], \
            "measurement":data[cols_measurements[i]][j], \
            "uncertainty":data[cols_uncertainties[i]][j]}
            proteomics.append(protein)
        proteomics_all[cols_measurements[i]] = proteomics
    return(proteomics_all)

# %%
proteomics_data_dict = reset_proteomics()

# %%
#solution = ecModel.optimize()
ecModel.reactions.CPGNR1.
# Out:
# ''

# %%
fake_proteomics = [
    {"identifier": "P0A8V2", "measurement": 5.03e-6, "uncertainty": 0},  # not in model
    {"identifier": "P0AFG8", "measurement": 8.2e-3, "uncertainty": 8.2e-6},  # will stay
    {"identifier": "P15254", "measurement": 6.54e-8, "uncertainty": 0},  # to remove
    {"identifier": "P0A6C5", "measurement": 5.93e-8, "uncertainty": 0},  # to remove
]
measurements = compute_measurements(proteomics_data_dict["Glucose"], ecModel)

# %%
# check if incorporation seems to work
new_growth_rate, new_proteomics, warnings = flexibilize_proteomics(ecModel, "BIOMASS_Ec_iML1515_core_75p37M", {"measurement":0.1, "uncertainty":0.01}, fake_proteomics)
print(new_growth_rate)
print(new_proteomics)
solution = ecModel.optimize()
print(solution)
# Out:
# {'identifier': 'P0A8V2', 'measurement': 5.03e-06, 'uncertainty': 0}
# {'identifier': 'P0AFG8', 'measurement': 0.0082, 'uncertainty': 8.2e-06}
# {'identifier': 'P15254', 'measurement': 6.54e-08, 'uncertainty': 0}
# {'identifier': 'P0A6C5', 'measurement': 5.93e-08, 'uncertainty': 0}
# working: P15254 (sp=-406.0679673236969) - mu = 2.6556845062340096e-05
# working: P0A6C5 (sp=-9493.16684698304) - mu = 0.0005629447940260943
# {'measurement': 0.1, 'uncertainty': 0.01}
# [{'identifier': 'P0A8V2', 'measurement': 5.03e-06, 'uncertainty': 0}, {'identifier': 'P0AFG8', 'measurement': 0.0082, 'uncertainty': 8.2e-06}]
# <Solution 0.877 at 0x13692d550>

# %%
# run on real data and growth rates
data = pd.read_csv(proteomics_dataset)
cols_measurements = data.columns[data.columns.get_loc("Glucose"):data.columns.get_loc("Fructose")]

growth_rates = pd.read_csv("/Users/jonas/Documents/masters/thesis/thesis/data/raw_internal/proteomics/growth_conditions.csv")
growth_rates = growth_rates.drop(growth_rates.columns.difference(['Growth condition','Growth rate (h-1)', 'Stdev']), 1)
growth_rates = growth_rates.drop([0,1], axis=0)

# %%
# run 
solutions = dict()
errors = []
counter = 0
for i in cols_measurements:
    counter += 1
    print("Model {} of {}".format(counter, len(cols_measurements)))

    new_growth_rate, new_proteomics, warnings = flexibilize_proteomics(eColi_model, "BIOMASS_Ec_iML1515_core_75p37M", \
    {"measurement":float(list(growth_rates['Growth rate (h-1)'].loc[growth_rates['Growth condition'] == i])[0]),\
    "uncertainty":float(list(growth_rates['Stdev'].loc[growth_rates['Growth condition'] == i])[0])}, \
    proteomics_data_dict[i])
    solutions[i] = ecModel.optimize()
# Out:
# Model 1 of 21
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Python/3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-6cab5c266a52> in <module>
#      10     {"measurement":float(list(growth_rates['Growth rate (h-1)'].loc[growth_rates['Growth condition'] == i])[0]),\
#      11     "uncertainty":float(list(growth_rates['Stdev'].loc[growth_rates['Growth condition'] == i])[0])}, \
# ---> 12     proteomics_data_dict[i])
#      13     solutions[i] = ecModel.optimize()
#
# <ipython-input-45-e37c53ffdc2c> in flexibilize_proteomics(model, biomass_reaction, growth_rate, proteomics)
#     273     # constrain the model with all proteins and optimize:
#     274
# --> 275     limit_proteins(model, prot_df["value"])
#     276     solution = model.optimize()
#     277     new_growth_rate = solution.objective_value
#
# /Library/Python/3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /Library/Python/3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'

# %%
proteomics_data_dict
# Out:
# {'Glucose': [{'identifier': 'P0A8T7',
#    'measurement': 2779,
#    'uncertainty': 0.715},
#   {'identifier': 'P0A8V2',
#    'measurement': 3957,
#    'uncertainty': 0.9890000000000001},
#   {'identifier': 'P36683', 'measurement': 7596, 'uncertainty': 1.18},
#   {'identifier': 'P15254',
#    'measurement': 2456,
#    'uncertainty': 0.5760000000000001},
#   {'identifier': 'P09831', 'measurement': 2859, 'uncertainty': 0.775},
#   {'identifier': 'P0AFG8',
#    'measurement': 5815,
#    'uncertainty': 0.9620000000000001},
#   {'identifier': 'P0A9Q7', 'measurement': 4851, 'uncertainty': 0.774},
#   {'identifier': 'P0CE47', 'measurement': 252452, 'uncertainty': 18.1},
#   {'identifier': 'P25665', 'measurement': 51584, 'uncertainty': 7.25},
#   {'identifier': 'P0A6F5', 'measurement': 22739, 'uncertainty': 2.16},
#   {'identifier': 'P00968',
#    'measurement': 4445,
#    'uncertainty': 0.8690000000000001},
#   {'identifier': 'P09373', 'measurement': 4615, 'uncertainty': 0.654},
#   {'identifier': 'P0A6Y8', 'measurement': 18605, 'uncertainty': 2.13},
#   {'identifier': 'P0A705',
#    'measurement': 3047,
#    'uncertainty': 0.40299999999999997},
#   {'identifier': 'P05793', 'measurement': 33338, 'uncertainty': 2.99},
#   {'identifier': 'P00864', 'measurement': 3633, 'uncertainty': 0.597},
#   {'identifier': 'P00957', 'measurement': 1948, 'uncertainty': 0.31},
#   {'identifier': 'P0A6M8', 'measurement': 39027, 'uncertainty': 5.02},
#   {'identifier': 'P00961', 'measurement': 2914, 'uncertainty': 0.371},
#   {'identifier': 'P76558', 'measurement': 469, 'uncertainty': 0.0641},
#   {'identifier': 'P0AG67', 'measurement': 23797, 'uncertainty': 2.41},
#   {'identifier': 'P07813', 'measurement': 1846, 'uncertainty': 0.298},
#   {'identifier': 'P00561', 'measurement': 5703, 'uncertainty': 0.843},
#   {'identifier': 'P0AFG3', 'measurement': 1706, 'uncertainty': 0.297},
#   {'identifier': 'P00956', 'measurement': 2166, 'uncertainty': 0.375},
#   {'identifier': 'P25553', 'measurement': 3501, 'uncertainty': 0.304},
#   {'identifier': 'P10408', 'measurement': 706, 'uncertainty': 0.12},
#   {'identifier': 'P21889', 'measurement': 2272, 'uncertainty': 0.248},
#   {'identifier': 'P07395', 'measurement': 5023, 'uncertainty': 0.728},
#   {'identifier': 'P07118', 'measurement': 1719, 'uncertainty': 0.309},
#   {'identifier': 'P23847', 'measurement': 4939, 'uncertainty': 0.494},
#   {'identifier': 'P06959', 'measurement': 9057, 'uncertainty': 0.993},
#   {'identifier': 'P13029', 'measurement': 2199, 'uncertainty': 0.292},
#   {'identifier': 'P0AES4', 'measurement': 750, 'uncertainty': 0.121},
#   {'identifier': 'P08200', 'measurement': 33670, 'uncertainty': 2.56},
#   {'identifier': 'P0ABB4', 'measurement': 24156, 'uncertainty': 2.02},
#   {'identifier': 'P04825', 'measurement': 1296, 'uncertainty': 0.213},
#   {'identifier': 'P0AD61',
#    'measurement': 8902,
#    'uncertainty': 0.7490000000000001},
#   {'identifier': 'P0A9G6', 'measurement': 28173, 'uncertainty': 2.22},
#   {'identifier': 'P0AC33', 'measurement': 1352, 'uncertainty': 0.135},
#   {'identifier': 'P09546', 'measurement': 128, 'uncertainty': 0.0306},
#   {'identifier': 'P21179', 'measurement': 1180, 'uncertainty': 0.165},
#   {'identifier': 'P0A6Z3', 'measurement': 2096, 'uncertainty': 0.248},
#   {'identifier': 'P0A6P1', 'measurement': 19872, 'uncertainty': 1.0},
#   {'identifier': 'P08839', 'measurement': 10158, 'uncertainty': 1.07},
#   {'identifier': 'P0A6E4',
#    'measurement': 8325,
#    'uncertainty': 0.6890000000000001},
#   {'identifier': 'P0A6F3', 'measurement': 496, 'uncertainty': 0.0463},
#   {'identifier': 'P0A9M8', 'measurement': 1148, 'uncertainty': 0.147},
#   {'identifier': 'P0A850', 'measurement': 24929, 'uncertainty': 1.99},
#   {'identifier': 'P0A940', 'measurement': 2029, 'uncertainty': 0.305},
#   {'identifier': 'P05055', 'measurement': 3171, 'uncertainty': 0.406},
#   {'identifier': 'P0A6T1', 'measurement': 4601, 'uncertainty': 0.47},
#   {'identifier': 'P0AC41', 'measurement': 2083, 'uncertainty': 0.223},
#   {'identifier': 'P0A9M0', 'measurement': 1139, 'uncertainty': 0.165},
#   {'identifier': 'P27550',
#    'measurement': 995,
#    'uncertainty': 0.11900000000000001},
#   {'identifier': 'P23538', 'measurement': 1158, 'uncertainty': 0.168},
#   {'identifier': 'P04079', 'measurement': 3870, 'uncertainty': 0.377},
#   {'identifier': 'P22523', 'measurement': 199, 'uncertainty': 0.0561},
#   {'identifier': 'P0A9W3', 'measurement': 2571, 'uncertainty': 0.266},
#   {'identifier': 'P0AES6', 'measurement': 842, 'uncertainty': 0.126},
#   {'identifier': 'P21513', 'measurement': 848, 'uncertainty': 0.166},
#   {'identifier': 'P0A8M3', 'measurement': 939, 'uncertainty': 0.115},
#   {'identifier': 'P0A799', 'measurement': 40039, 'uncertainty': 2.73},
#   {'identifier': 'P00370', 'measurement': 6343, 'uncertainty': 0.511},
#   {'identifier': 'P0A825', 'measurement': 24510, 'uncertainty': 1.84},
#   {'identifier': 'P23843', 'measurement': 5755, 'uncertainty': 0.581},
#   {'identifier': 'P0A9A6', 'measurement': 6070, 'uncertainty': 0.406},
#   {'identifier': 'P08997', 'measurement': 4393, 'uncertainty': 0.439},
#   {'identifier': 'P33602', 'measurement': 934, 'uncertainty': 0.155},
#   {'identifier': 'P17846', 'measurement': 3011, 'uncertainty': 0.32},
#   {'identifier': 'P00582', 'measurement': 440, 'uncertainty': 0.0752},
#   {'identifier': 'P0A9B2', 'measurement': 47083, 'uncertainty': 2.77},
#   {'identifier': 'P15639', 'measurement': 2728, 'uncertainty': 0.259},
#   {'identifier': 'P0A853', 'measurement': 613, 'uncertainty': 0.0537},
#   {'identifier': 'P25516', 'measurement': 595, 'uncertainty': 0.0965},
#   {'identifier': 'P33599', 'measurement': 935, 'uncertainty': 0.106},
#   {'identifier': 'P0A9C5', 'measurement': 17828, 'uncertainty': 1.54},
#   {'identifier': 'P09151', 'measurement': 2711, 'uncertainty': 0.258},
#   {'identifier': 'P37685', 'measurement': 589, 'uncertainty': 0.055},
#   {'identifier': 'P06149', 'measurement': 608, 'uncertainty': 0.0652},
#   {'identifier': 'P37330', 'measurement': 282, 'uncertainty': 0.0377},
#   {'identifier': 'P0ABH7', 'measurement': 9671, 'uncertainty': 0.77},
#   {'identifier': 'P35340',
#    'measurement': 2435,
#    'uncertainty': 0.22699999999999998},
#   {'identifier': 'P0A910', 'measurement': 119680, 'uncertainty': 7.38},
#   {'identifier': 'P17169', 'measurement': 4025, 'uncertainty': 0.447},
#   {'identifier': 'P16659', 'measurement': 4322, 'uncertainty': 0.457},
#   {'identifier': 'P60422', 'measurement': 14191, 'uncertainty': 0.703},
#   {'identifier': 'P00452', 'measurement': 560, 'uncertainty': 0.077},
#   {'identifier': 'P27298',
#    'measurement': 1350,
#    'uncertainty': 0.17300000000000001},
#   {'identifier': 'P0A6B7', 'measurement': 13683, 'uncertainty': 1.02},
#   {'identifier': 'P13035', 'measurement': 135, 'uncertainty': 0.0127},
#   {'identifier': 'P0ABB0', 'measurement': 14552, 'uncertainty': 1.33},
#   {'identifier': 'P38038', 'measurement': 3317, 'uncertainty': 0.365},
#   {'identifier': 'P0AAI3', 'measurement': 2236, 'uncertainty': 0.262},
#   {'identifier': 'P0AG30', 'measurement': 3243, 'uncertainty': 0.253},
#   {'identifier': 'P0A817', 'measurement': 12499, 'uncertainty': 0.87},
#   {'identifier': 'P0ADG7', 'measurement': 11237, 'uncertainty': 0.97},
#   {'identifier': 'Q59385',
#    'measurement': 2769,
#    'uncertainty': 0.40399999999999997},
#   {'identifier': 'P0AFF6', 'measurement': 5576, 'uncertainty': 0.508},
#   {'identifier': 'P0A7Z4', 'measurement': 14575, 'uncertainty': 0.883},
#   {'identifier': 'P0A8N3', 'measurement': 2565, 'uncertainty': 0.245},
#   {'identifier': 'P00959', 'measurement': 2082, 'uncertainty': 0.263},
#   {'identifier': 'P00350', 'measurement': 14100, 'uncertainty': 1.2},
#   {'identifier': 'P0AEE5', 'measurement': 3223, 'uncertainty': 0.191},
#   {'identifier': 'P0AD96', 'measurement': 22968, 'uncertainty': 1.49},
#   {'identifier': 'P13009', 'measurement': 421, 'uncertainty': 0.095},
#   {'identifier': 'P61889', 'measurement': 53138, 'uncertainty': 2.85},
#   {'identifier': 'P32132', 'measurement': 3013, 'uncertainty': 0.337},
#   {'identifier': 'P77804', 'measurement': 1215, 'uncertainty': 0.11},
#   {'identifier': 'P06971',
#    'measurement': 873,
#    'uncertainty': 0.11900000000000001},
#   {'identifier': 'P0ADY1',
#    'measurement': 1057,
#    'uncertainty': 0.11900000000000001},
#   {'identifier': 'P30850', 'measurement': 1260, 'uncertainty': 0.152},
#   {'identifier': 'P00962', 'measurement': 999, 'uncertainty': 0.105},
#   {'identifier': 'P0AB71', 'measurement': 20049, 'uncertainty': 1.3},
#   {'identifier': 'P0ABK5', 'measurement': 73308, 'uncertainty': 4.19},
#   {'identifier': 'P0ACY3', 'measurement': 519, 'uncertainty': 0.0641},
#   {'identifier': 'P23845', 'measurement': 1520, 'uncertainty': 0.133},
#   {'identifier': 'P23865', 'measurement': 506, 'uncertainty': 0.0643},
#   {'identifier': 'P21177', 'measurement': 173, 'uncertainty': 0.0229},
#   {'identifier': 'P36938', 'measurement': 1344, 'uncertainty': 0.13},
#   {'identifier': 'P0A870', 'measurement': 10629, 'uncertainty': 0.621},
#   {'identifier': 'P68767', 'measurement': 1076, 'uncertainty': 0.0979},
#   {'identifier': 'P00934', 'measurement': 14609, 'uncertainty': 1.14},
#   {'identifier': 'P0A9P0', 'measurement': 12596, 'uncertainty': 1.06},
#   {'identifier': 'P75691', 'measurement': 1474, 'uncertainty': 0.0928},
#   {'identifier': 'P0ABZ6', 'measurement': 1554, 'uncertainty': 0.122},
#   {'identifier': 'P21499', 'measurement': 251, 'uncertainty': 0.0383},
#   {'identifier': 'P0A8M0',
#    'measurement': 5528,
#    'uncertainty': 0.48200000000000004},
#   {'identifier': 'P0A8L1', 'measurement': 2528, 'uncertainty': 0.203},
#   {'identifier': 'P0AEX9', 'measurement': 2142, 'uncertainty': 0.154},
#   {'identifier': 'P0A786', 'measurement': 8888, 'uncertainty': 0.508},
#   {'identifier': 'P05791', 'measurement': 1199, 'uncertainty': 0.13},
#   {'identifier': 'P77748', 'measurement': 231, 'uncertainty': 0.0434},
#   {'identifier': 'P17315', 'measurement': 575, 'uncertainty': 0.0705},
#   {'identifier': 'P0ABH9', 'measurement': 530, 'uncertainty': 0.074},
#   {'identifier': 'P0C0V0', 'measurement': 3338, 'uncertainty': 0.273},
#   {'identifier': 'P31554', 'measurement': 523, 'uncertainty': 0.0779},
#   {'identifier': 'P06612', 'measurement': 355, 'uncertainty': 0.0573},
#   {'identifier': 'P11875',
#    'measurement': 941,
#    'uncertainty': 0.10099999999999999},
#   {'identifier': 'P04805',
#    'measurement': 2561,
#    'uncertainty': 0.22899999999999998},
#   {'identifier': 'P0A7V0', 'measurement': 29156, 'uncertainty': 1.29},
#   {'identifier': 'P33363', 'measurement': 157, 'uncertainty': 0.0218},
#   {'identifier': 'P0C8J6', 'measurement': 4939, 'uncertainty': 0.252},
#   {'identifier': 'P69786', 'measurement': 2775, 'uncertainty': 0.233},
#   {'identifier': 'P05020', 'measurement': 4485, 'uncertainty': 0.289},
#   {'identifier': 'P11447',
#    'measurement': 2883,
#    'uncertainty': 0.24100000000000002},
#   {'identifier': 'P22106', 'measurement': 1154, 'uncertainty': 0.12},
#   {'identifier': 'P00509', 'measurement': 6985, 'uncertainty': 0.505},
#   {'identifier': 'P0A836',
#    'measurement': 6213,
#    'uncertainty': 0.42700000000000005},
#   {'identifier': 'P0AGE9', 'measurement': 6924, 'uncertainty': 0.342},
#   {'identifier': 'P0A6H1', 'measurement': 3251, 'uncertainty': 0.25},
#   {'identifier': 'P0A6H5',
#    'measurement': 1367,
#    'uncertainty': 0.11199999999999999},
#   {'identifier': 'P30958', 'measurement': 73, 'uncertainty': 0.0158},
#   {'identifier': 'P08312', 'measurement': 5078, 'uncertainty': 0.31},
#   {'identifier': 'P24182',
#    'measurement': 1810,
#    'uncertainty': 0.14800000000000002},
#   {'identifier': 'P0A953',
#    'measurement': 13467,
#    'uncertainty': 0.9520000000000001},
#   {'identifier': 'Q47146', 'measurement': 86, 'uncertainty': 0.0128},
#   {'identifier': 'P0C8J8', 'measurement': 1413, 'uncertainty': 0.11},
#   {'identifier': 'P0A7D4', 'measurement': 6863, 'uncertainty': 0.539},
#   {'identifier': 'P0A7E5', 'measurement': 960, 'uncertainty': 0.0962},
#   {'identifier': 'P00895',
#    'measurement': 1090,
#    'uncertainty': 0.10400000000000001},
#   {'identifier': 'P09832', 'measurement': 2965, 'uncertainty': 0.256},
#   {'identifier': 'P08142', 'measurement': 1823, 'uncertainty': 0.183},
#   {'identifier': 'P26616', 'measurement': 528, 'uncertainty': 0.0554},
#   {'identifier': 'P07014', 'measurement': 2481, 'uncertainty': 0.11},
#   {'identifier': 'P37689', 'measurement': 2656, 'uncertainty': 0.248},
#   {'identifier': 'P38054', 'measurement': 356, 'uncertainty': 0.0678},
#   {'identifier': 'P0ABC7', 'measurement': 1349, 'uncertainty': 0.102},
#   {'identifier': 'P02930', 'measurement': 4884, 'uncertainty': 0.435},
#   {'identifier': 'P62399', 'measurement': 31769, 'uncertainty': 1.07},
#   {'identifier': 'P0ABD5',
#    'measurement': 3825,
#    'uncertainty': 0.22399999999999998},
#   {'identifier': 'P0A7A7', 'measurement': 192, 'uncertainty': 0.0292},
#   {'identifier': 'P05459', 'measurement': 737, 'uncertainty': 0.0506},
#   {'identifier': 'P23721', 'measurement': 18150, 'uncertainty': 1.2},
#   {'identifier': 'P0A867', 'measurement': 1446, 'uncertainty': 0.0855},
#   {'identifier': 'P00944', 'measurement': 260, 'uncertainty': 0.0215},
#   {'identifier': 'P0AC53', 'measurement': 1234, 'uncertainty': 0.114},
#   {'identifier': 'P08660', 'measurement': 3720, 'uncertainty': 0.3},
#   {'identifier': 'P07023', 'measurement': 1416, 'uncertainty': 0.0988},
#   {'identifier': 'P0AEM9',
#    'measurement': 11402,
#    'uncertainty': 0.5489999999999999},
#   {'identifier': 'P0AFG6',
#    'measurement': 5252,
#    'uncertainty': 0.38299999999999995},
#   {'identifier': 'P22259', 'measurement': 1147, 'uncertainty': 0.114},
#   {'identifier': 'P0AFK0',
#    'measurement': 1295,
#    'uncertainty': 0.10400000000000001},
#   {'identifier': 'P0ADE8', 'measurement': 1610, 'uncertainty': 0.0964},
#   {'identifier': 'P05825', 'measurement': 374, 'uncertainty': 0.0509},
#   {'identifier': 'P75780', 'measurement': 202, 'uncertainty': 0.0275},
#   {'identifier': 'P09169', 'measurement': 13908, 'uncertainty': 0.82},
#   {'identifier': 'P0A698', 'measurement': 127, 'uncertainty': 0.0219},
#   {'identifier': 'P0A9P9', 'measurement': 601, 'uncertainty': 0.0275},
#   {'identifier': 'P18843', 'measurement': 3939, 'uncertainty': 0.2},
#   {'identifier': 'P0A6P9', 'measurement': 36150, 'uncertainty': 2.74},
#   {'identifier': 'P27302', 'measurement': 3883, 'uncertainty': 0.465},
#   {'identifier': 'P0ABP8',
#    'measurement': 2764,
#    'uncertainty': 0.11900000000000001},
#   {'identifier': 'P24171', 'measurement': 591, 'uncertainty': 0.076},
#   {'identifier': 'P37095', 'measurement': 3155, 'uncertainty': 0.242},
#   {'identifier': 'P09551',
#    'measurement': 6161,
#    'uncertainty': 0.28600000000000003},
#   {'identifier': 'P31660', 'measurement': 470, 'uncertainty': 0.0336},
#   {'identifier': 'P27306', 'measurement': 445, 'uncertainty': 0.038},
#   {'identifier': 'Q46856', 'measurement': 1052, 'uncertainty': 0.0734},
#   {'identifier': 'P11454', 'measurement': 43, 'uncertainty': 0.0101},
#   {'identifier': 'P0AE06', 'measurement': 2423, 'uncertainty': 0.17},
#   {'identifier': 'P02931', 'measurement': 24017, 'uncertainty': 1.57},
#   {'identifier': 'P0A903', 'measurement': 1753, 'uncertainty': 0.107},
#   {'identifier': 'P60906', 'measurement': 1889, 'uncertainty': 0.147},
#   {'identifier': 'P0A7L0', 'measurement': 28502, 'uncertainty': 1.17},
#   {'identifier': 'P0AEK4',
#    'measurement': 5014,
#    'uncertainty': 0.23199999999999998},
#   {'identifier': 'P02943', 'measurement': 903, 'uncertainty': 0.0747},
#   {'identifier': 'P00490', 'measurement': 274, 'uncertainty': 0.0412},
#   {'identifier': 'P0A796', 'measurement': 1448, 'uncertainty': 0.0837},
#   {'identifier': 'P00550', 'measurement': 570, 'uncertainty': 0.0643},
#   {'identifier': 'P02925', 'measurement': 5038, 'uncertainty': 0.259},
#   {'identifier': 'P0AB89', 'measurement': 1933, 'uncertainty': 0.165},
#   {'identifier': 'P18335', 'measurement': 3919, 'uncertainty': 0.285},
#   {'identifier': 'P0A6A6',
#    'measurement': 2763,
#    'uncertainty': 0.22899999999999998},
#   {'identifier': 'P0A879',
#    'measurement': 5377,
#    'uncertainty': 0.38299999999999995},
#   {'identifier': 'P33195', 'measurement': 337, 'uncertainty': 0.0584},
#   {'identifier': 'P00562', 'measurement': 343, 'uncertainty': 0.0506},
#   {'identifier': 'P37902',
#    'measurement': 4936,
#    'uncertainty': 0.27399999999999997},
#   {'identifier': 'P0A9X4', 'measurement': 3277, 'uncertainty': 0.201},
#   {'identifier': 'P06715', 'measurement': 986, 'uncertainty': 0.0798},
#   {'identifier': 'P31979', 'measurement': 393, 'uncertainty': 0.0322},
#   {'identifier': 'P67910', 'measurement': 2898, 'uncertainty': 0.168},
#   {'identifier': 'P0AGD7', 'measurement': 925, 'uncertainty': 0.0764},
#   {'identifier': 'P0AG90', 'measurement': 430, 'uncertainty': 0.0475},
#   {'identifier': 'P76116', 'measurement': 3466, 'uncertainty': 0.222},
#   {'identifier': 'P16700', 'measurement': 3914, 'uncertainty': 0.244},
#   {'identifier': 'P60785', 'measurement': 748, 'uncertainty': 0.0826},
#   {'identifier': 'P06996', 'measurement': 33621, 'uncertainty': 2.25},
#   {'identifier': 'P0A8J8', 'measurement': 497, 'uncertainty': 0.0388},
#   {'identifier': 'P46837', 'measurement': 169, 'uncertainty': 0.0239},
#   {'identifier': 'P60240', 'measurement': 84, 'uncertainty': 0.0153},
#   {'identifier': 'P0A7V3', 'measurement': 15952, 'uncertainty': 0.687},
#   {'identifier': 'P0AB77', 'measurement': 172, 'uncertainty': 0.0123},
#   {'identifier': 'P0A6K6', 'measurement': 1012, 'uncertainty': 0.0745},
#   {'identifier': 'P21599', 'measurement': 1902, 'uncertainty': 0.162},
#   {'identifier': 'P0A858',
#    'measurement': 7438,
#    'uncertainty': 0.33299999999999996},
#   {'identifier': 'P31120', 'measurement': 1087, 'uncertainty': 0.0858},
#   {'identifier': 'P69797', 'measurement': 2291, 'uncertainty': 0.133},
#   {'identifier': 'P69441', 'measurement': 5283, 'uncertainty': 0.207},
#   {'identifier': 'P0AB91',
#    'measurement': 6678,
#    'uncertainty': 0.42100000000000004},
#   {'identifier': 'P21170', 'measurement': 1295, 'uncertainty': 0.159},
#   {'identifier': 'P0AEZ1',
#    'measurement': 4385,
#    'uncertainty': 0.24100000000000002},
#   {'identifier': 'P39346', 'measurement': 274, 'uncertainty': 0.0169},
#   {'identifier': 'P25526', 'measurement': 718, 'uncertainty': 0.0616},
#   {'identifier': 'P00393', 'measurement': 662, 'uncertainty': 0.052},
#   {'identifier': 'P45464', 'measurement': 490, 'uncertainty': 0.0592},
#   {'identifier': 'P77243', 'measurement': 93, 'uncertainty': 0.00836},
#   {'identifier': 'P76578', 'measurement': 29, 'uncertainty': 0.00869},
#   {'identifier': 'P0ABT2', 'measurement': 4698, 'uncertainty': 0.146},
#   {'identifier': 'P0AB24', 'measurement': 636, 'uncertainty': 0.0434},
#   {'identifier': 'P08506', 'measurement': 988, 'uncertainty': 0.0714},
#   {'identifier': 'P0AEP3', 'measurement': 1619, 'uncertainty': 0.0885},
#   {'identifier': 'P0A715', 'measurement': 2645, 'uncertainty': 0.135},
#   {'identifier': 'P0A7I4', 'measurement': 825, 'uncertainty': 0.0815},
#   {'identifier': 'P0A7V8', 'measurement': 13608, 'uncertainty': 0.53},
#   {'identifier': 'P02359', 'measurement': 54022, 'uncertainty': 1.79},
#   {'identifier': 'P23830', 'measurement': 296, 'uncertainty': 0.0259},
#   {'identifier': 'P06129', 'measurement': 676, 'uncertainty': 0.0767},
#   {'identifier': 'P0A9T0',
#    'measurement': 11353,
#    'uncertainty': 0.8320000000000001},
#   {'identifier': 'P0A991',
#    'measurement': 2160,
#    'uncertainty': 0.13699999999999998},
#   {'identifier': 'P52697', 'measurement': 1802, 'uncertainty': 0.109},
#   {'identifier': 'P33221',
#    'measurement': 2379,
#    'uncertainty': 0.16699999999999998},
#   {'identifier': 'P0A9Q9', 'measurement': 13769, 'uncertainty': 0.914},
#   {'identifier': 'P22256', 'measurement': 599, 'uncertainty': 0.0455},
#   {'identifier': 'P18956', 'measurement': 172, 'uncertainty': 0.0176},
#   {'identifier': 'P21165',
#    'measurement': 1239,
#    'uncertainty': 0.10300000000000001},
#   {'identifier': 'P07004', 'measurement': 944, 'uncertainty': 0.0699},
#   {'identifier': 'P0A7B5', 'measurement': 680, 'uncertainty': 0.044},
#   {'identifier': 'P0AEZ3', 'measurement': 2776, 'uncertainty': 0.136},
#   {'identifier': 'P77735', 'measurement': 465, 'uncertainty': 0.0281},
#   {'identifier': 'P0ABJ1', 'measurement': 2616, 'uncertainty': 0.151},
#   {'identifier': 'P19926', 'measurement': 501, 'uncertainty': 0.038},
#   {'identifier': 'P33136', 'measurement': 993, 'uncertainty': 0.0954},
#   {'identifier': 'P0AE78', 'measurement': 215, 'uncertainty': 0.0119},
#   {'identifier': 'P23836', 'measurement': 2967, 'uncertainty': 0.126},
#   {'identifier': 'P0ABD3', 'measurement': 3413, 'uncertainty': 0.105},
#   {'identifier': 'P09372', 'measurement': 5905, 'uncertainty': 0.213},
#   {'identifier': 'P0ACC7', 'measurement': 409, 'uncertainty': 0.0334},
#   {'identifier': 'P77239', 'measurement': 2333, 'uncertainty': 0.171},
#   {'identifier': 'P60438', 'measurement': 16502, 'uncertainty': 0.609},
#   {'identifier': 'P62620', 'measurement': 590, 'uncertainty': 0.0398},
#   {'identifier': 'P18133', 'measurement': 593, 'uncertainty': 0.0451},
#   {'identifier': 'Q46829', 'measurement': 369, 'uncertainty': 0.0339},
#   {'identifier': 'P07650', 'measurement': 135, 'uncertainty': 0.0106},
#   {'identifier': 'P12758', 'measurement': 1726, 'uncertainty': 0.0777},
#   {'identifier': 'P0A8F0', 'measurement': 23305, 'uncertainty': 0.871},
#   {'identifier': 'P0A717',
#    'measurement': 7428,
#    'uncertainty': 0.42200000000000004},
#   {'identifier': 'P23908', 'measurement': 2145, 'uncertainty': 0.151},
#   {'identifier': 'P0AC38', 'measurement': 110, 'uncertainty': 0.00957},
#   {'identifier': 'P0A9D8', 'measurement': 10996, 'uncertainty': 0.545},
#   {'identifier': 'P60757', 'measurement': 4025, 'uncertainty': 0.223},
#   {'identifier': 'P15288',
#    'measurement': 2408,
#    'uncertainty': 0.21100000000000002},
#   {'identifier': 'P15034', 'measurement': 617, 'uncertainty': 0.051},
#   {'identifier': 'P00893', 'measurement': 441, 'uncertainty': 0.046},
#   {'identifier': 'P0AEU0', 'measurement': 10759, 'uncertainty': 0.508},
#   {'identifier': 'P0A6A3', 'measurement': 3062, 'uncertainty': 0.22},
#   {'identifier': 'P05042', 'measurement': 498, 'uncertainty': 0.0417},
#   {'identifier': 'P0ABA6', 'measurement': 2307, 'uncertainty': 0.121},
#   {'identifier': 'P32176', 'measurement': 13, 'uncertainty': 0.00244},
#   {'identifier': 'P76177', 'measurement': 2729, 'uncertainty': 0.153},
#   {'identifier': 'P45578', 'measurement': 6890, 'uncertainty': 0.222},
#   {'identifier': 'P0A8W8', 'measurement': 1232, 'uncertainty': 0.0399},
#   {'identifier': 'Q46857', 'measurement': 328, 'uncertainty': 0.0169},
#   {'identifier': 'P39342', 'measurement': 174, 'uncertainty': 0.0157},
#   {'identifier': 'P28635', 'measurement': 29884, 'uncertainty': 1.46},
#   {'identifier': 'P0AAB6', 'measurement': 4865, 'uncertainty': 0.265},
#   {'identifier': 'P0A749', 'measurement': 650, 'uncertainty': 0.0483},
#   {'identifier': 'P37759', 'measurement': 1009, 'uncertainty': 0.0679},
#   {'identifier': 'P0A7G6', 'measurement': 1514, 'uncertainty': 0.0954},
#   {'identifier': 'P15042', 'measurement': 290, 'uncertainty': 0.0355},
#   {'identifier': 'P21507', 'measurement': 301, 'uncertainty': 0.0249},
#   {'identifier': 'P07604', 'measurement': 132, 'uncertainty': 0.0127},
#   {'identifier': 'P0AE18', 'measurement': 1479, 'uncertainty': 0.0719},
#   {'identifier': 'P0A7W1', 'measurement': 18042, 'uncertainty': 0.527},
#   {'identifier': 'P02358',
#    'measurement': 17452,
#    'uncertainty': 0.45399999999999996},
#   {'identifier': 'P0AEI1', 'measurement': 967, 'uncertainty': 0.0861},
#   {'identifier': 'P0AA39', 'measurement': 152, 'uncertainty': 0.00909},
#   {'identifier': 'P0AGJ9', 'measurement': 2277, 'uncertainty': 0.18},
#   {'identifier': 'P0A6W9', 'measurement': 550, 'uncertainty': 0.0531},
#   {'identifier': 'P23893',
#    'measurement': 2909,
#    'uncertainty': 0.21899999999999997},
#   {'identifier': 'P0A887', 'measurement': 929, 'uncertainty': 0.0433},
#   {'identifier': 'P77488', 'measurement': 298, 'uncertainty': 0.0335},
#   {'identifier': 'P15877',
#    'measurement': 43,
#    'uncertainty': 0.006229999999999999},
#   {'identifier': 'P09424', 'measurement': 725, 'uncertainty': 0.0495},
#   {'identifier': 'P33570', 'measurement': 754, 'uncertainty': 0.0913},
#   {'identifier': 'P13482', 'measurement': 66, 'uncertainty': 0.00695},
#   {'identifier': 'P09323', 'measurement': 266, 'uncertainty': 0.0302},
#   {'identifier': 'P15640', 'measurement': 2115, 'uncertainty': 0.161},
#   {'identifier': 'P0A7E1', 'measurement': 1545, 'uncertainty': 0.0942},
#   {'identifier': 'P00963', 'measurement': 1766, 'uncertainty': 0.107},
#   {'identifier': 'P04036', 'measurement': 3082, 'uncertainty': 0.147},
#   {'identifier': 'P04968', 'measurement': 140, 'uncertainty': 0.013},
#   {'identifier': 'P04693', 'measurement': 1770, 'uncertainty': 0.128},
#   {'identifier': 'P0AEQ3', 'measurement': 6759, 'uncertainty': 0.305},
#   {'identifier': 'P07001',
#    'measurement': 1938,
#    'uncertainty': 0.17600000000000002},
#   {'identifier': 'P0AB67',
#    'measurement': 2977,
#    'uncertainty': 0.24100000000000002},
#   {'identifier': 'P37666', 'measurement': 1788, 'uncertainty': 0.105},
#   {'identifier': 'P76658', 'measurement': 802, 'uncertainty': 0.0679},
#   {'identifier': 'P31224', 'measurement': 282, 'uncertainty': 0.0532},
#   {'identifier': 'P0A855', 'measurement': 1690, 'uncertainty': 0.129},
#   {'identifier': 'P0ACJ8', 'measurement': 2048, 'uncertainty': 0.0803},
#   {'identifier': 'P29217', 'measurement': 858, 'uncertainty': 0.0344},
#   {'identifier': 'P30871', 'measurement': 287, 'uncertainty': 0.0231},
#   {'identifier': 'P63389',
#    'measurement': 56,
#    'uncertainty': 0.006670000000000001},
#   {'identifier': 'P04335', 'measurement': 248, 'uncertainty': 0.0193},
#   {'identifier': 'P37329', 'measurement': 757, 'uncertainty': 0.0343},
#   {'identifier': 'P0AE08', 'measurement': 58487, 'uncertainty': 2.01},
#   {'identifier': 'P0AE52', 'measurement': 7595, 'uncertainty': 0.222},
#   {'identifier': 'P0A6Z1', 'measurement': 587, 'uncertainty': 0.0639},
#   {'identifier': 'P0ACA3', 'measurement': 4718, 'uncertainty': 0.19},
#   {'identifier': 'P0A9P4', 'measurement': 4439, 'uncertainty': 0.255},
#   {'identifier': 'P39099', 'measurement': 846, 'uncertainty': 0.0662},
#   {'identifier': 'P0AEB2', 'measurement': 1349, 'uncertainty': 0.0994},
#   {'identifier': 'P0AGC3', 'measurement': 80, 'uncertainty': 0.00974},
#   {'identifier': 'P0A9P6', 'measurement': 560, 'uncertainty': 0.0655},
#   {'identifier': 'P06993', 'measurement': 21, 'uncertainty': 0.00361},
#   {'identifier': 'P0AFG0', 'measurement': 3934, 'uncertainty': 0.134},
#   {'identifier': 'P00579', 'measurement': 648, 'uncertainty': 0.0755},
#   {'identifier': 'P07012', 'measurement': 1682, 'uncertainty': 0.115},
#   {'identifier': 'P0ABU2', 'measurement': 2762, 'uncertainty': 0.182},
#   {'identifier': 'P0A6R0',
#    'measurement': 2120,
#    'uncertainty': 0.11800000000000001},
#   {'identifier': 'P77718', 'measurement': 198, 'uncertainty': 0.018},
#   {'identifier': 'P0A9C3', 'measurement': 1240, 'uncertainty': 0.0786},
#   {'identifier': 'P62707',
#    'measurement': 12056,
#    'uncertainty': 0.5710000000000001},
#   {'identifier': 'P0AF96',
#    'measurement': 15854,
#    'uncertainty': 0.44299999999999995},
#   {'identifier': 'P0A6L0', 'measurement': 1162, 'uncertainty': 0.0535},
#   {'identifier': 'P0A7D7',
#    'measurement': 8188,
#    'uncertainty': 0.36700000000000005},
#   {'identifier': 'P25524', 'measurement': 3065, 'uncertainty': 0.242},
#   {'identifier': 'P00888', 'measurement': 2076, 'uncertainty': 0.134},
#   {'identifier': 'P27248', 'measurement': 662, 'uncertainty': 0.0441},
#   {'identifier': 'P0A877', 'measurement': 4387, 'uncertainty': 0.209},
#   {'identifier': 'P0A6F1', 'measurement': 9256, 'uncertainty': 0.636},
#   {'identifier': 'P04816',
#    'measurement': 2647,
#    'uncertainty': 0.17300000000000001},
#   {'identifier': 'P0ADF6', 'measurement': 81, 'uncertainty': 0.00873},
#   {'identifier': 'P0ABH0', 'measurement': 572, 'uncertainty': 0.043},
#   {'identifier': 'P0A9C0', 'measurement': 14, 'uncertainty': 0.00139},
#   {'identifier': 'P08957', 'measurement': 346, 'uncertainty': 0.034},
#   {'identifier': 'P10121',
#    'measurement': 1149,
#    'uncertainty': 0.10400000000000001},
#   {'identifier': 'P11557', 'measurement': 911, 'uncertainty': 0.0698},
#   {'identifier': 'P0A8M6', 'measurement': 20277, 'uncertainty': 0.429},
#   {'identifier': 'P23839', 'measurement': 710, 'uncertainty': 0.0391},
#   {'identifier': 'P0A9U3', 'measurement': 343, 'uncertainty': 0.034},
#   {'identifier': 'P0A8E1', 'measurement': 793, 'uncertainty': 0.0279},
#   {'identifier': 'P0A6P5', 'measurement': 267, 'uncertainty': 0.0244},
#   {'identifier': 'P0ADV7', 'measurement': 1567, 'uncertainty': 0.0623},
#   {'identifier': 'P00448', 'measurement': 21660, 'uncertainty': 0.83},
#   {'identifier': 'P08622', 'measurement': 688, 'uncertainty': 0.0469},
#   {'identifier': 'P0ABC3', 'measurement': 1290, 'uncertainty': 0.0806},
#   {'identifier': 'P76403', 'measurement': 265, 'uncertainty': 0.0225},
#   {'identifier': 'P09147', 'measurement': 621, 'uncertainty': 0.0384},
#   {'identifier': 'P37747', 'measurement': 836, 'uncertainty': 0.0596},
#   {'identifier': 'P77211',
#    'measurement': 1475,
#    'uncertainty': 0.12300000000000001},
#   {'identifier': 'P0A8F8', 'measurement': 134, 'uncertainty': 0.017},
#   {'identifier': 'P0ACQ4', 'measurement': 395, 'uncertainty': 0.0225},
#   {'identifier': 'P0ACP7', 'measurement': 826, 'uncertainty': 0.0523},
#   {'identifier': 'P0A8N5', 'measurement': 493, 'uncertainty': 0.0473},
#   {'identifier': 'P0AG55',
#    'measurement': 18104,
#    'uncertainty': 0.5670000000000001},
#   {'identifier': 'P0A847', 'measurement': 846, 'uncertainty': 0.0598},
#   {'identifier': 'P00954', 'measurement': 1818, 'uncertainty': 0.113},
#   {'identifier': 'P0AAI5',
#    'measurement': 1917,
#    'uncertainty': 0.13699999999999998},
#   {'identifier': 'P0AEK2', 'measurement': 4675, 'uncertainty': 0.198},
#   {'identifier': 'P0A6T5', 'measurement': 14176, 'uncertainty': 0.584},
#   {'identifier': 'P30011', 'measurement': 631, 'uncertainty': 0.0343},
#   {'identifier': 'P0A6T3', 'measurement': 369, 'uncertainty': 0.0254},
#   {'identifier': 'P0A6V8', 'measurement': 497, 'uncertainty': 0.0286},
#   {'identifier': 'P00946', 'measurement': 914, 'uncertainty': 0.065},
#   {'identifier': 'P06999', 'measurement': 939, 'uncertainty': 0.0505},
#   {'identifier': 'P76015', 'measurement': 754, 'uncertainty': 0.0478},
#   {'identifier': 'P0A993', 'measurement': 944, 'uncertainty': 0.0577},
#   {'identifier': 'P0AAG8', 'measurement': 25, 'uncertainty': 0.00237},
#   {'identifier': 'P0AG80', 'measurement': 113, 'uncertainty': 0.00908},
#   {'identifier': 'P0A6D3', 'measurement': 2056, 'uncertainty': 0.157},
#   {'identifier': 'P06986',
#    'measurement': 2203,
#    'uncertainty': 0.14400000000000002},
#   {'identifier': 'P06988', 'measurement': 3447, 'uncertainty': 0.264},
#   {'identifier': 'P0AFK9', 'measurement': 3341, 'uncertainty': 0.215},
#   {'identifier': 'P76108',
#    'measurement': 82,
#    'uncertainty': 0.0057799999999999995},
#   {'identifier': 'D9IX93', 'measurement': 316, 'uncertainty': 0.0296},
#   {'identifier': 'P0A9J8', 'measurement': 1584, 'uncertainty': 0.113},
#   {'identifier': 'P30859', 'measurement': 1927, 'uncertainty': 0.0861},
#   {'identifier': 'P00904', 'measurement': 1025, 'uncertainty': 0.0967},
#   {'identifier': 'P30125', 'measurement': 4588, 'uncertainty': 0.301},
#   {'identifier': 'Q46851', 'measurement': 167, 'uncertainty': 0.0108},
#   {'identifier': 'P77674', 'measurement': 313, 'uncertainty': 0.0264},
#   {'identifier': 'P26646', 'measurement': 1097, 'uncertainty': 0.0632},
#   {'identifier': 'P0AEE1', 'measurement': 2176, 'uncertainty': 0.0714},
#   {'identifier': 'P64451', 'measurement': 1470, 'uncertainty': 0.0595},
#   {'identifier': 'P63224',
#    'measurement': 3370,
#    'uncertainty': 0.11599999999999999},
#   {'identifier': 'P0ABQ0', 'measurement': 252, 'uncertainty': 0.0182},
#   {'identifier': 'P76372', 'measurement': 1637, 'uncertainty': 0.099},
#   {'identifier': 'P0AAC0', 'measurement': 1445, 'uncertainty': 0.0856},
#   {'identifier': 'P0AA16', 'measurement': 828, 'uncertainty': 0.0376},
#   {'identifier': 'P0A9K3', 'measurement': 734, 'uncertainty': 0.0475},
#   {'identifier': 'P0ADE6', 'measurement': 1857, 'uncertainty': 0.0494},
#   {'identifier': 'P0A8G6', 'measurement': 5306, 'uncertainty': 0.183},
#   {'identifier': 'P25522', 'measurement': 292, 'uncertainty': 0.0238},
#   {'identifier': 'P36979', 'measurement': 215, 'uncertainty': 0.0154},
#   {'identifier': 'P0A7B1', 'measurement': 60, 'uncertainty': 0.00806},
#   {'identifier': 'P16676', 'measurement': 705, 'uncertainty': 0.048},
#   {'identifier': 'P45523', 'measurement': 5679, 'uncertainty': 0.272},
#   {'identifier': 'P0A6Y5', 'measurement': 2363, 'uncertainty': 0.127},
#   {'identifier': 'P77689', 'measurement': 252, 'uncertainty': 0.0196},
#   {'identifier': 'P22188', 'measurement': 512, 'uncertainty': 0.0453},
#   {'identifier': 'P37692', 'measurement': 189, 'uncertainty': 0.0123},
#   {'identifier': 'P39180', 'measurement': 59, 'uncertainty': 0.0105},
#   {'identifier': 'P21888', 'measurement': 550, 'uncertainty': 0.0477},
#   {'identifier': 'P0A805', 'measurement': 5649, 'uncertainty': 0.193},
#   {'identifier': 'P0A707',
#    'measurement': 6930,
#    'uncertainty': 0.23600000000000002},
#   {'identifier': 'P0A7W7', 'measurement': 22152, 'uncertainty': 0.519},
#   {'identifier': 'P14081', 'measurement': 49, 'uncertainty': 0.00556},
#   {'identifier': 'P0AAI9', 'measurement': 3385, 'uncertainty': 0.182},
#   {'identifier': 'P09127', 'measurement': 587, 'uncertainty': 0.0418},
#   {'identifier': 'P31057', 'measurement': 2579, 'uncertainty': 0.121},
#   {'identifier': 'P31663', 'measurement': 1286, 'uncertainty': 0.0674},
#   {'identifier': 'P04425', 'measurement': 1279, 'uncertainty': 0.0754},
#   {'identifier': 'P69783', 'measurement': 33524, 'uncertainty': 1.01},
#   {'identifier': 'P0A6V1', 'measurement': 240, 'uncertainty': 0.0194},
#   {'identifier': 'P24215', 'measurement': 395, 'uncertainty': 0.0294},
#   {'identifier': 'P02924', 'measurement': 35, 'uncertainty': 0.00206},
#   {'identifier': 'P69811', 'measurement': 301, 'uncertainty': 0.0198},
#   {'identifier': 'P69831', 'measurement': 580, 'uncertainty': 0.0466},
#   {'identifier': 'P0AE12', 'measurement': 426, 'uncertainty': 0.0381},
#   {'identifier': 'P60560', 'measurement': 1145, 'uncertainty': 0.071},
#   {'identifier': 'P0AG16', 'measurement': 771, 'uncertainty': 0.0722},
#   {'identifier': 'P07024', 'measurement': 363, 'uncertainty': 0.0367},
#   {'identifier': 'P0A6C8',
#    'measurement': 6391,
#    'uncertainty': 0.28800000000000003},
#   {'identifier': 'P05194', 'measurement': 881, 'uncertainty': 0.0401},
#   {'identifier': 'P09053', 'measurement': 553, 'uncertainty': 0.0429},
#   {'identifier': 'P00935', 'measurement': 1916, 'uncertainty': 0.132},
#   {'identifier': 'P06721', 'measurement': 2128, 'uncertainty': 0.153},
#   {'identifier': 'P16456', 'measurement': 708, 'uncertainty': 0.0431},
#   {'identifier': 'P21156', 'measurement': 1300, 'uncertainty': 0.0759},
#   {'identifier': 'P17854', 'measurement': 1861, 'uncertainty': 0.0863},
#   {'identifier': 'P0A6C5', 'measurement': 333, 'uncertainty': 0.0271},
#   {'identifier': 'P06987', 'measurement': 2794, 'uncertainty': 0.187},
#   {'identifier': 'P07003', 'measurement': 258, 'uncertainty': 0.0265},
#   {'identifier': 'P09394', 'measurement': 164, 'uncertainty': 0.0111},
#   {'identifier': 'P0ABA4', 'measurement': 7700, 'uncertainty': 0.247},
#   {'identifier': 'P25437', 'measurement': 551, 'uncertainty': 0.0359},
#   {'identifier': 'P38489', 'measurement': 1503, 'uncertainty': 0.0596},
#   {'identifier': 'P37744', 'measurement': 635, 'uncertainty': 0.0344},
#   {'identifier': 'P0ABS1', 'measurement': 5844, 'uncertainty': 0.17},
#   {'identifier': 'P45577', 'measurement': 2318, 'uncertainty': 0.0995},
#   {'identifier': 'P0A9Q1', 'measurement': 3367, 'uncertainty': 0.152},
#   {'identifier': 'P0AG20', 'measurement': 64, 'uncertainty': 0.00895},
#   {'identifier': 'P37903', 'measurement': 1378, 'uncertainty': 0.0366},
#   {'identifier': 'P39177', 'measurement': 1174, 'uncertainty': 0.031},
#   {'identifier': 'P0ADW3', 'measurement': 5444, 'uncertainty': 0.135},
#   {'identifier': 'P0ADN2',
#    'measurement': 5671,
#    'uncertainty': 0.12300000000000001},
#   {'identifier': 'P77774', 'measurement': 962, 'uncertainty': 0.0669},
#   {'identifier': 'P76113', 'measurement': 663, 'uncertainty': 0.0413},
#   {'identifier': 'P25519', 'measurement': 239, 'uncertainty': 0.0192},
#   {'identifier': 'P0ACF8', 'measurement': 22541, 'uncertainty': 0.581},
#   {'identifier': 'P0ACG1', 'measurement': 6863, 'uncertainty': 0.175},
#   {'identifier': 'P39831', 'measurement': 1891, 'uncertainty': 0.0855},
#   {'identifier': 'P0AC02', 'measurement': 1372, 'uncertainty': 0.0633},
#   {'identifier': 'P39286', 'measurement': 374, 'uncertainty': 0.0243},
#   {'identifier': 'P77247', 'measurement': 519, 'uncertainty': 0.0209},
#   {'identifier': 'P76536', 'measurement': 489, 'uncertainty': 0.0268},
#   {'identifier': 'P22255', 'measurement': 917, 'uncertainty': 0.0413},
#   {'identifier': 'P0A9K7', 'measurement': 338, 'uncertainty': 0.0154},
#   {'identifier': 'P13024', 'measurement': 373, 'uncertainty': 0.0215},
#   {'identifier': 'P27249', 'measurement': 126, 'uncertainty': 0.0214},
#   {'identifier': 'P0AC59',
#    'measurement': 2666,
#    'uncertainty': 0.10800000000000001},
#   {'identifier': 'P0AFL3', 'measurement': 2576, 'uncertainty': 0.0873},
#   {'identifier': 'P0A862', 'measurement': 24694, 'uncertainty': 0.73},
#   {'identifier': 'Q46845', 'measurement': 769, 'uncertainty': 0.0413},
#   {'identifier': 'P0AG14', 'measurement': 413, 'uncertainty': 0.027},
#   {'identifier': 'P0A6J8', 'measurement': 140, 'uncertainty': 0.00916},
#   {'identifier': 'P37636', 'measurement': 13, 'uncertainty': 0.000884},
#   {'identifier': 'P36767', 'measurement': 561, 'uncertainty': 0.0316},
#   {'identifier': 'P0A6X7', 'measurement': 4676, 'uncertainty': 0.088},
#   {'identifier': 'P0A9F3', 'measurement': 523, 'uncertainty': 0.0314},
#   {'identifier': 'P76268', 'measurement': 546, 'uncertainty': 0.0272},
#   {'identifier': 'P0ACJ0', 'measurement': 6092, 'uncertainty': 0.191},
#   {'identifier': 'P0A7J7', 'measurement': 11140, 'uncertainty': 0.275},
#   {'identifier': 'P68919',
#    'measurement': 20176,
#    'uncertainty': 0.35700000000000004},
#   {'identifier': 'P0A7X3', 'measurement': 8821, 'uncertainty': 0.217},
#   {'identifier': 'P0A9Q5', 'measurement': 1660, 'uncertainty': 0.0918},
#   {'identifier': 'P10384', 'measurement': 472, 'uncertainty': 0.038},
#   {'identifier': 'P0A8K1', 'measurement': 1620, 'uncertainty': 0.0966},
#   {'identifier': 'P69451', 'measurement': 150, 'uncertainty': 0.0155},
#   {'identifier': 'P0AG84',
#    'measurement': 150,
#    'uncertainty': 0.007809999999999999},
#   {'identifier': 'P0AEZ9', 'measurement': 2560, 'uncertainty': 0.0792},
#   {'identifier': 'P0AAB4', 'measurement': 244, 'uncertainty': 0.0225},
#   {'identifier': 'P0A759', 'measurement': 550, 'uncertainty': 0.0272},
#   {'identifier': 'P0A8G3', 'measurement': 143, 'uncertainty': 0.0128},
#   {'identifier': 'P37349', 'measurement': 340, 'uncertainty': 0.0291},
#   {'identifier': 'P69805', 'measurement': 341, 'uncertainty': 0.0177},
#   {'identifier': 'P39325', 'measurement': 99, 'uncertainty': 0.00565},
#   {'identifier': 'P37051', 'measurement': 2304, 'uncertainty': 0.122},
#   {'identifier': 'P08331', 'measurement': 134, 'uncertainty': 0.0158},
#   {'identifier': 'P11446', 'measurement': 1718, 'uncertainty': 0.102},
#   {'identifier': 'P16703', 'measurement': 1533, 'uncertainty': 0.0831},
#   {'identifier': 'P29745', 'measurement': 262, 'uncertainty': 0.0195},
#   {'identifier': 'P0A821', 'measurement': 181, 'uncertainty': 0.0152},
#   {'identifier': 'P30177', 'measurement': 716, 'uncertainty': 0.0416},
#   {'identifier': 'P0A6L2',
#    'measurement': 3589,
#    'uncertainty': 0.18600000000000003},
#   {'identifier': 'P37313', 'measurement': 309, 'uncertainty': 0.0192},
#   {'identifier': 'P0AES0', 'measurement': 184, 'uncertainty': 0.0215},
#   {'identifier': 'P77444', 'measurement': 508, 'uncertainty': 0.0374},
#   {'identifier': 'P00909', 'measurement': 804, 'uncertainty': 0.0658},
#   {'identifier': 'P0AAG0', 'measurement': 367, 'uncertainty': 0.0218},
#   {'identifier': 'P0AFD1', 'measurement': 748, 'uncertainty': 0.0231},
#   {'identifier': 'P30178', 'measurement': 1634, 'uncertainty': 0.105},
#   {'identifier': 'P25906', 'measurement': 413, 'uncertainty': 0.0211},
#   {'identifier': 'P0ABA0', 'measurement': 8988, 'uncertainty': 0.257},
#   {'identifier': 'P24232', 'measurement': 149, 'uncertainty': 0.0108},
#   {'identifier': 'P28304', 'measurement': 871, 'uncertainty': 0.0508},
#   {'identifier': 'P25714', 'measurement': 842, 'uncertainty': 0.0859},
#   {'identifier': 'P0AED0',
#    'measurement': 37520,
#    'uncertainty': 0.9990000000000001},
#   {'identifier': 'P0AF28', 'measurement': 1239, 'uncertainty': 0.0492},
#   {'identifier': 'P0A8I3', 'measurement': 803, 'uncertainty': 0.0394},
#   {'identifier': 'P0A8E7', 'measurement': 10057, 'uncertainty': 0.306},
#   {'identifier': 'P0A8B5',
#    'measurement': 6880,
#    'uncertainty': 0.13699999999999998},
#   {'identifier': 'P76097', 'measurement': 43, 'uncertainty': 0.0036},
#   {'identifier': 'P43672', 'measurement': 156, 'uncertainty': 0.0186},
#   {'identifier': 'P33920', 'measurement': 833, 'uncertainty': 0.0522},
#   {'identifier': 'P0ADR8', 'measurement': 199, 'uncertainty': 0.0168},
#   {'identifier': 'P0A894', 'measurement': 231, 'uncertainty': 0.0125},
#   {'identifier': 'P46853', 'measurement': 424, 'uncertainty': 0.0273},
#   {'identifier': 'P31658', 'measurement': 628, 'uncertainty': 0.0325},
#   {'identifier': 'P0A9V1', 'measurement': 1635, 'uncertainty': 0.0727},
#   {'identifier': 'P33940', 'measurement': 146, 'uncertainty': 0.0146},
#   {'identifier': 'P67087', 'measurement': 383, 'uncertainty': 0.0199},
#   {'identifier': 'P21367', 'measurement': 1884, 'uncertainty': 0.0722},
#   {'identifier': 'P04846', 'measurement': 1867, 'uncertainty': 0.0911},
#   {'identifier': 'P31142', 'measurement': 821, 'uncertainty': 0.042},
#   {'identifier': 'P77318',
#    'measurement': 14,
#    'uncertainty': 0.0014199999999999998},
#   {'identifier': 'P0AG82', 'measurement': 305, 'uncertainty': 0.0187},
#   {'identifier': 'P07821', 'measurement': 154, 'uncertainty': 0.0074},
#   {'identifier': 'P06610', 'measurement': 1158, 'uncertainty': 0.0393},
#   {'identifier': 'P0AEG6', 'measurement': 1421, 'uncertainty': 0.0604},
#   {'identifier': 'P0AEG4', 'measurement': 4138, 'uncertainty': 0.159},
#   {'identifier': 'P77522', 'measurement': 266, 'uncertainty': 0.0242},
#   {'identifier': 'P77499', 'measurement': 628, 'uncertainty': 0.0287},
#   {'identifier': 'P0ACA7', 'measurement': 627, 'uncertainty': 0.0246},
#   {'identifier': 'P0A9D2', 'measurement': 685, 'uncertainty': 0.026},
#   {'identifier': 'P04949',
#    'measurement': 3,
#    'uncertainty': 0.00026000000000000003},
#   {'identifier': 'P69776', 'measurement': 48939, 'uncertainty': 0.675},
#   {'identifier': 'P02919', 'measurement': 91, 'uncertainty': 0.0134},
#   {'identifier': 'P17952', 'measurement': 435, 'uncertainty': 0.0387},
#   {'identifier': 'P11880', 'measurement': 530, 'uncertainty': 0.0418},
#   {'identifier': 'P0A912', 'measurement': 18234, 'uncertainty': 0.569},
#   {'identifier': 'P60390', 'measurement': 374, 'uncertainty': 0.0216},
#   {'identifier': 'P0ACB0', 'measurement': 207, 'uncertainty': 0.018},
#   {'identifier': 'P43329', 'measurement': 32, 'uncertainty': 0.00783},
#   {'identifier': 'P09030', 'measurement': 658, 'uncertainty': 0.0338},
#   {'identifier': 'P0AF20', 'measurement': 124, 'uncertainty': 0.00915},
#   {'identifier': 'P0A7C2', 'measurement': 560, 'uncertainty': 0.0208},
#   {'identifier': 'P0AFM6', 'measurement': 934, 'uncertainty': 0.0395},
#   {'identifier': 'P23882', 'measurement': 715, 'uncertainty': 0.0405},
#   {'identifier': 'P60723', 'measurement': 21084, 'uncertainty': 0.772},
#   {'identifier': 'P0ADY3', 'measurement': 7098, 'uncertainty': 0.159},
#   {'identifier': 'P0AG44',
#    'measurement': 18397,
#    'uncertainty': 0.43799999999999994},
#   {'identifier': 'P60624', 'measurement': 49826, 'uncertainty': 0.934},
#   {'identifier': 'P0A7R5', 'measurement': 39792, 'uncertainty': 0.774},
#   {'identifier': 'P0A7S9', 'measurement': 23450, 'uncertainty': 0.509},
#   {'identifier': 'P0AEI4', 'measurement': 326, 'uncertainty': 0.0268},
#   {'identifier': 'P21151', 'measurement': 425, 'uncertainty': 0.0288},
#   {'identifier': 'P0AET8', 'measurement': 197, 'uncertainty': 0.00875},
#   {'identifier': 'P76503',
#    'measurement': 23,
#    'uncertainty': 0.0017399999999999998},
#   {'identifier': 'P77399', 'measurement': 24, 'uncertainty': 0.00309},
#   {'identifier': 'P06983', 'measurement': 224, 'uncertainty': 0.0126},
#   {'identifier': 'P0ACB7', 'measurement': 144, 'uncertainty': 0.0108},
#   {'identifier': 'P11458', 'measurement': 368, 'uncertainty': 0.0233},
#   {'identifier': 'P24186', 'measurement': 1861, 'uncertainty': 0.0958},
#   {'identifier': 'P0AEJ2', 'measurement': 193, 'uncertainty': 0.0137},
#   {'identifier': 'P17993', 'measurement': 1335, 'uncertainty': 0.0588},
#   {'identifier': 'P75913', 'measurement': 1020, 'uncertainty': 0.0598},
#   {'identifier': 'P0A7Z0', 'measurement': 2758, 'uncertainty': 0.105},
#   {'identifier': 'P46130', 'measurement': 1377, 'uncertainty': 0.105},
#   {'identifier': 'P76143', 'measurement': 88, 'uncertainty': 0.00464},
#   {'identifier': 'P0ADG4', 'measurement': 1439, 'uncertainty': 0.0696},
#   {'identifier': 'P08178', 'measurement': 2544, 'uncertainty': 0.156},
#   {'identifier': 'P08244', 'measurement': 1507, 'uncertainty': 0.0658},
#   {'identifier': 'P00452-2', 'measurement': 28, 'uncertainty': 0.00386},
#   {'identifier': 'P12008', 'measurement': 798, 'uncertainty': 0.0518},
#   {'identifier': 'P0A6J5', 'measurement': 51, 'uncertainty': 0.004},
#   {'identifier': 'P00926', 'measurement': 67, 'uncertainty': 0.0053},
#   {'identifier': 'P30126', 'measurement': 5119, 'uncertainty': 0.191},
#   {'identifier': 'P31133', 'measurement': 3029, 'uncertainty': 0.205},
#   {'identifier': 'P00547', 'measurement': 594, 'uncertainty': 0.0331},
#   {'identifier': 'P0A6D7', 'measurement': 2112, 'uncertainty': 0.0684},
#   {'identifier': 'P0ADF8', 'measurement': 1075, 'uncertainty': 0.0198},
#   {'identifier': 'P75823', 'measurement': 316, 'uncertainty': 0.0191},
#   {'identifier': 'Q46863', 'measurement': 47, 'uncertainty': 0.00477},
#   {'identifier': 'P76027',
#    'measurement': 144,
#    'uncertainty': 0.008879999999999999},
#   {'identifier': 'P30860',
#    'measurement': 9359,
#    'uncertainty': 0.41600000000000004},
#   {'identifier': 'P0A7A9', 'measurement': 8350, 'uncertainty': 0.273},
#   {'identifier': 'P0ABJ9', 'measurement': 344, 'uncertainty': 0.0333},
#   {'identifier': 'P0ABI8',
#    'measurement': 957,
#    'uncertainty': 0.11800000000000001},
#   {'identifier': 'P42593', 'measurement': 43, 'uncertainty': 0.00515},
#   {'identifier': 'P0A8P3', 'measurement': 3446, 'uncertainty': 0.0625},
#   {'identifier': 'P76621', 'measurement': 56, 'uncertainty': 0.00346},
#   {'identifier': 'P0AAT9', 'measurement': 540, 'uncertainty': 0.0168},
#   {'identifier': 'P39401', 'measurement': 77, 'uncertainty': 0.011},
#   {'identifier': 'P37626', 'measurement': 179, 'uncertainty': 0.0115},
#   {'identifier': 'P77485', 'measurement': 217, 'uncertainty': 0.0194},
#   {'identifier': 'P69407', 'measurement': 2769, 'uncertainty': 0.109},
#   {'identifier': 'P0AAX8', 'measurement': 3469, 'uncertainty': 0.192},
#   {'identifier': 'P0A8X2', 'measurement': 2094, 'uncertainty': 0.0726},
#   {'identifier': 'P0A8H6', 'measurement': 1175, 'uncertainty': 0.0371},
#   {'identifier': 'P77649', 'measurement': 70, 'uncertainty': 0.0063},
#   {'identifier': 'P37691',
#    'measurement': 126,
#    'uncertainty': 0.007370000000000001},
#   {'identifier': 'P0AFH8',
#    'measurement': 10489,
#    'uncertainty': 0.36700000000000005},
#   {'identifier': 'P75874', 'measurement': 1847, 'uncertainty': 0.045},
#   {'identifier': 'P45470', 'measurement': 288, 'uncertainty': 0.009},
#   {'identifier': 'P0A8Y5', 'measurement': 511, 'uncertainty': 0.0252},
#   {'identifier': 'P0AGE6', 'measurement': 1687, 'uncertainty': 0.057},
#   {'identifier': 'Q47679', 'measurement': 219, 'uncertainty': 0.0105},
#   {'identifier': 'P75863', 'measurement': 212, 'uncertainty': 0.0143},
#   {'identifier': 'P0A9W9', 'measurement': 840, 'uncertainty': 0.0282},
#   {'identifier': 'P36649', 'measurement': 1034, 'uncertainty': 0.097},
# ...
#   {'identifier': 'P0A763', 'measurement': 29653, 'uncertainty': 0.76},
#   {'identifier': 'P0A7E9', 'measurement': 678, 'uncertainty': 0.0292},
#   {'identifier': 'P10371', 'measurement': 984, 'uncertainty': 0.0425},
#   {'identifier': 'P60595', 'measurement': 859, 'uncertainty': 0.0308},
#   {'identifier': 'P0A9L8', 'measurement': 402, 'uncertainty': 0.0188},
#   {'identifier': 'P30744', 'measurement': 25, 'uncertainty': 0.00205},
#   {'identifier': 'P21169', 'measurement': 46, 'uncertainty': 0.00605},
#   {'identifier': 'P08390', 'measurement': 287, 'uncertainty': 0.0173},
#   {'identifier': 'P0AB80', 'measurement': 1967, 'uncertainty': 0.111},
#   {'identifier': 'P76316', 'measurement': 670, 'uncertainty': 0.0391},
#   {'identifier': 'P76128', 'measurement': 98, 'uncertainty': 0.00942},
#   {'identifier': 'P63235', 'measurement': 14, 'uncertainty': 0.00131},
#   {'identifier': 'P60651', 'measurement': 797, 'uncertainty': 0.0444},
#   {'identifier': 'P07913', 'measurement': 390, 'uncertainty': 0.0241},
#   {'identifier': 'P0A729', 'measurement': 2273, 'uncertainty': 0.0817},
#   {'identifier': 'P0A9R4', 'measurement': 2066, 'uncertainty': 0.0422},
#   {'identifier': 'P0A9S5', 'measurement': 25, 'uncertainty': 0.00158},
#   {'identifier': 'P08201', 'measurement': 3, 'uncertainty': 0.000496},
#   {'identifier': 'P45579', 'measurement': 498, 'uncertainty': 0.0323},
#   {'identifier': 'P33219', 'measurement': 1621, 'uncertainty': 0.0348},
#   {'identifier': 'P31063', 'measurement': 1467, 'uncertainty': 0.0364},
#   {'identifier': 'P0ADT8', 'measurement': 266, 'uncertainty': 0.0102},
#   {'identifier': 'P0A7A2', 'measurement': 553, 'uncertainty': 0.0221},
#   {'identifier': 'P0A8S1', 'measurement': 445, 'uncertainty': 0.0247},
#   {'identifier': 'P68066', 'measurement': 1251, 'uncertainty': 0.0296},
#   {'identifier': 'P24202', 'measurement': 48, 'uncertainty': 0.00265},
#   {'identifier': 'P0AGA2', 'measurement': 557, 'uncertainty': 0.0448},
#   {'identifier': 'P0ABV2', 'measurement': 262, 'uncertainty': 0.00673},
#   {'identifier': 'P0AG86', 'measurement': 10181, 'uncertainty': 0.292},
#   {'identifier': 'P0AFB8', 'measurement': 50, 'uncertainty': 0.00436},
#   {'identifier': 'P69228',
#    'measurement': 152,
#    'uncertainty': 0.006959999999999999},
#   {'identifier': 'P0AE88', 'measurement': 1102, 'uncertainty': 0.0481},
#   {'identifier': 'P52108', 'measurement': 188, 'uncertainty': 0.00831},
#   {'identifier': 'P0AG24', 'measurement': 9, 'uncertainty': 0.00123},
#   {'identifier': 'P0ACZ8', 'measurement': 869, 'uncertainty': 0.0366},
#   {'identifier': 'P52076', 'measurement': 43, 'uncertainty': 0.00176},
#   {'identifier': 'P0AEH5', 'measurement': 6742, 'uncertainty': 0.126},
#   {'identifier': 'P0AFP6', 'measurement': 4756, 'uncertainty': 0.212},
#   {'identifier': 'P34209', 'measurement': 169, 'uncertainty': 0.0083},
#   {'identifier': 'P0A8A0', 'measurement': 545, 'uncertainty': 0.0239},
#   {'identifier': 'P0ADU2', 'measurement': 497, 'uncertainty': 0.00951},
#   {'identifier': 'P0ADV1', 'measurement': 996, 'uncertainty': 0.0332},
#   {'identifier': 'P27434', 'measurement': 1622, 'uncertainty': 0.0974},
#   {'identifier': 'Q57261', 'measurement': 147, 'uncertainty': 0.00951},
#   {'identifier': 'P67603', 'measurement': 784, 'uncertainty': 0.0155},
#   {'identifier': 'P76053',
#    'measurement': 47,
#    'uncertainty': 0.0016699999999999998},
#   {'identifier': 'P0AEY5', 'measurement': 528, 'uncertainty': 0.0192},
#   {'identifier': 'P0A9G8',
#    'measurement': 62,
#    'uncertainty': 0.0029100000000000003},
#   {'identifier': 'P77529',
#    'measurement': 1282,
#    'uncertainty': 0.10300000000000001},
#   {'identifier': 'P0AD05', 'measurement': 367, 'uncertainty': 0.0153},
#   {'identifier': 'P31064', 'measurement': 86, 'uncertainty': 0.00635},
#   {'identifier': 'P0ADP0', 'measurement': 210, 'uncertainty': 0.00943},
#   {'identifier': 'P30863', 'measurement': 79, 'uncertainty': 0.00385},
#   {'identifier': 'P0ADR6', 'measurement': 62, 'uncertainty': 0.0043},
#   {'identifier': 'P24203', 'measurement': 231, 'uncertainty': 0.0137},
#   {'identifier': 'P37634', 'measurement': 168, 'uncertainty': 0.00889},
#   {'identifier': 'P10378', 'measurement': 114, 'uncertainty': 0.0112},
#   {'identifier': 'P0ABI4', 'measurement': 215, 'uncertainty': 0.013},
#   {'identifier': 'P0ABB8', 'measurement': 82, 'uncertainty': 0.0135},
#   {'identifier': 'P30750', 'measurement': 766, 'uncertainty': 0.048},
#   {'identifier': 'P0AG27', 'measurement': 1288, 'uncertainty': 0.0333},
#   {'identifier': 'Q46871', 'measurement': 439, 'uncertainty': 0.021},
#   {'identifier': 'P0A6F9', 'measurement': 20291, 'uncertainty': 0.349},
#   {'identifier': 'P63020',
#    'measurement': 2964,
#    'uncertainty': 0.10300000000000001},
#   {'identifier': 'P05458', 'measurement': 23, 'uncertainty': 0.00405},
#   {'identifier': 'P0ADX1', 'measurement': 365, 'uncertainty': 0.00877},
#   {'identifier': 'P25894', 'measurement': 569, 'uncertainty': 0.0253},
#   {'identifier': 'P07862', 'measurement': 462, 'uncertainty': 0.0252},
#   {'identifier': 'P17115',
#    'measurement': 48,
#    'uncertainty': 0.0027199999999999998},
#   {'identifier': 'P61320', 'measurement': 295, 'uncertainty': 0.0115},
#   {'identifier': 'P0A908', 'measurement': 2604, 'uncertainty': 0.12},
#   {'identifier': 'P0AEU7', 'measurement': 6494, 'uncertainty': 0.19},
#   {'identifier': 'P0AD12', 'measurement': 152, 'uncertainty': 0.00747},
#   {'identifier': 'P51981', 'measurement': 92, 'uncertainty': 0.00528},
#   {'identifier': 'P0AFV4', 'measurement': 3549, 'uncertainty': 0.124},
#   {'identifier': 'P03004',
#    'measurement': 66,
#    'uncertainty': 0.0057399999999999994},
#   {'identifier': 'P0A988', 'measurement': 386, 'uncertainty': 0.026},
#   {'identifier': 'P0A6C1', 'measurement': 226, 'uncertainty': 0.0118},
#   {'identifier': 'P0AGE0', 'measurement': 3019, 'uncertainty': 0.095},
#   {'identifier': 'P0A6Y1', 'measurement': 3699, 'uncertainty': 0.0653},
#   {'identifier': 'P0AFI2', 'measurement': 89, 'uncertainty': 0.0124},
#   {'identifier': 'P0A8V6', 'measurement': 198, 'uncertainty': 0.00885},
#   {'identifier': 'P0ACI0', 'measurement': 65, 'uncertainty': 0.00358},
#   {'identifier': 'P0A8W2', 'measurement': 773, 'uncertainty': 0.021},
#   {'identifier': 'P0ACU7', 'measurement': 275, 'uncertainty': 0.00998},
#   {'identifier': 'P03024', 'measurement': 23, 'uncertainty': 0.00141},
#   {'identifier': 'P0AGK8', 'measurement': 3458, 'uncertainty': 0.0994},
#   {'identifier': 'P0ACR9', 'measurement': 913, 'uncertainty': 0.0311},
#   {'identifier': 'P0ACT6', 'measurement': 97, 'uncertainty': 0.00352},
#   {'identifier': 'P16384', 'measurement': 37, 'uncertainty': 0.00216},
#   {'identifier': 'P0A7G2', 'measurement': 1002, 'uncertainty': 0.0252},
#   {'identifier': 'P02413',
#    'measurement': 4945,
#    'uncertainty': 0.12300000000000001},
#   {'identifier': 'P61175', 'measurement': 32937, 'uncertainty': 0.667},
#   {'identifier': 'P0A7M9', 'measurement': 8071, 'uncertainty': 0.105},
#   {'identifier': 'P60340', 'measurement': 38, 'uncertainty': 0.0022},
#   {'identifier': 'P25745', 'measurement': 197, 'uncertainty': 0.0134},
#   {'identifier': 'P0A7X6', 'measurement': 479, 'uncertainty': 0.0164},
#   {'identifier': 'P63177', 'measurement': 194, 'uncertainty': 0.00855},
#   {'identifier': 'P33643', 'measurement': 176, 'uncertainty': 0.0108},
#   {'identifier': 'P0A951', 'measurement': 62, 'uncertainty': 0.00224},
#   {'identifier': 'P07649', 'measurement': 43, 'uncertainty': 0.00216},
#   {'identifier': 'P0AF93', 'measurement': 10935, 'uncertainty': 0.247},
#   {'identifier': 'P0A6Q3', 'measurement': 2261, 'uncertainty': 0.0711},
#   {'identifier': 'P0A6Q6', 'measurement': 3997, 'uncertainty': 0.113},
#   {'identifier': 'P41407', 'measurement': 807, 'uncertainty': 0.029},
#   {'identifier': 'P31808',
#    'measurement': 171,
#    'uncertainty': 0.007940000000000001},
#   {'identifier': 'P37769', 'measurement': 31, 'uncertainty': 0.00139},
#   {'identifier': 'P0A794', 'measurement': 1615, 'uncertainty': 0.0707},
#   {'identifier': 'P76290', 'measurement': 262, 'uncertainty': 0.0121},
#   {'identifier': 'P0A9J4', 'measurement': 22, 'uncertainty': 0.00122},
#   {'identifier': 'P0A7J0', 'measurement': 223, 'uncertainty': 0.00865},
#   {'identifier': 'P0A6U8', 'measurement': 323, 'uncertainty': 0.0283},
#   {'identifier': 'P08194', 'measurement': 63, 'uncertainty': 0.00528},
#   {'identifier': 'P31677', 'measurement': 128, 'uncertainty': 0.0114},
#   {'identifier': 'P76014', 'measurement': 33, 'uncertainty': 0.00126},
#   {'identifier': 'P20966', 'measurement': 139, 'uncertainty': 0.0133},
#   {'identifier': 'P37188', 'measurement': 25668, 'uncertainty': 0.435},
#   {'identifier': 'P69828', 'measurement': 13360, 'uncertainty': 0.374},
#   {'identifier': 'P37676', 'measurement': 9, 'uncertainty': 0.000538},
#   {'identifier': 'P0A6I0', 'measurement': 654, 'uncertainty': 0.0268},
#   {'identifier': 'P0A9M5', 'measurement': 2981, 'uncertainty': 0.0839},
#   {'identifier': 'P09029', 'measurement': 226, 'uncertainty': 0.0148},
#   {'identifier': 'P39377',
#    'measurement': 146,
#    'uncertainty': 0.009940000000000001},
#   {'identifier': 'P41409', 'measurement': 309, 'uncertainty': 0.0173},
#   {'identifier': 'P22564', 'measurement': 258, 'uncertainty': 0.0139},
#   {'identifier': 'P07639', 'measurement': 247, 'uncertainty': 0.0159},
#   {'identifier': 'P00887', 'measurement': 187, 'uncertainty': 0.012},
#   {'identifier': 'P0AED7', 'measurement': 69, 'uncertainty': 0.00474},
#   {'identifier': 'P60664', 'measurement': 556, 'uncertainty': 0.0263},
#   {'identifier': 'P00861', 'measurement': 724, 'uncertainty': 0.0554},
#   {'identifier': 'P40874', 'measurement': 483, 'uncertainty': 0.0328},
#   {'identifier': 'P09158', 'measurement': 490, 'uncertainty': 0.0263},
#   {'identifier': 'P0A6L4', 'measurement': 151, 'uncertainty': 0.00815},
#   {'identifier': 'P22731',
#    'measurement': 223,
#    'uncertainty': 0.009729999999999999},
#   {'identifier': 'P69874', 'measurement': 202, 'uncertainty': 0.0144},
#   {'identifier': 'Q5H777', 'measurement': 98, 'uncertainty': 0.00861},
#   {'identifier': 'P33360', 'measurement': 110, 'uncertainty': 0.0063},
#   {'identifier': 'P0ADQ2', 'measurement': 167, 'uncertainty': 0.0103},
#   {'identifier': 'P0A9R7', 'measurement': 309, 'uncertainty': 0.0125},
#   {'identifier': 'P46889', 'measurement': 23, 'uncertainty': 0.00566},
#   {'identifier': 'P0A734', 'measurement': 3041, 'uncertainty': 0.0516},
#   {'identifier': 'P60293',
#    'measurement': 37,
#    'uncertainty': 0.0031100000000000004},
#   {'identifier': 'P20605', 'measurement': 82, 'uncertainty': 0.00312},
#   {'identifier': 'P61949', 'measurement': 7806, 'uncertainty': 0.255},
#   {'identifier': 'P09148', 'measurement': 116, 'uncertainty': 0.00761},
#   {'identifier': 'P0A9S1', 'measurement': 133, 'uncertainty': 0.00897},
#   {'identifier': 'P0ACD8', 'measurement': 1, 'uncertainty': 6.28e-05},
#   {'identifier': 'P23883', 'measurement': 70, 'uncertainty': 0.00619},
#   {'identifier': 'P52643', 'measurement': 230, 'uncertainty': 0.0139},
#   {'identifier': 'P76594',
#    'measurement': 32,
#    'uncertainty': 0.005229999999999999},
#   {'identifier': 'P77212', 'measurement': 26, 'uncertainty': 0.00206},
#   {'identifier': 'P0A784', 'measurement': 498, 'uncertainty': 0.0172},
#   {'identifier': 'P07102', 'measurement': 6, 'uncertainty': 0.000493},
#   {'identifier': 'P0AD59', 'measurement': 1046, 'uncertainty': 0.0293},
#   {'identifier': 'P0ADX7', 'measurement': 102, 'uncertainty': 0.00282},
#   {'identifier': 'P0ADK0', 'measurement': 1235, 'uncertainty': 0.0526},
#   {'identifier': 'P65556', 'measurement': 870, 'uncertainty': 0.0294},
#   {'identifier': 'P62517', 'measurement': 82, 'uncertainty': 0.0132},
#   {'identifier': 'P27828',
#    'measurement': 52,
#    'uncertainty': 0.0036200000000000004},
#   {'identifier': 'P40120',
#    'measurement': 66,
#    'uncertainty': 0.0068200000000000005},
#   {'identifier': 'P0AF12', 'measurement': 2065, 'uncertainty': 0.0834},
#   {'identifier': 'P75957', 'measurement': 371, 'uncertainty': 0.0157},
#   {'identifier': 'P08956', 'measurement': 12, 'uncertainty': 0.0027},
#   {'identifier': 'P36879', 'measurement': 272, 'uncertainty': 0.0156},
#   {'identifier': 'P60752', 'measurement': 100, 'uncertainty': 0.0107},
#   {'identifier': 'P69428', 'measurement': 1441, 'uncertainty': 0.0231},
#   {'identifier': 'P0ABU7', 'measurement': 862, 'uncertainty': 0.0376},
#   {'identifier': 'P00803',
#    'measurement': 109,
#    'uncertainty': 0.006490000000000001},
#   {'identifier': 'P0AG93', 'measurement': 478, 'uncertainty': 0.0281},
#   {'identifier': 'P37177',
#    'measurement': 54,
#    'uncertainty': 0.007509999999999999},
#   {'identifier': 'P39838', 'measurement': 36, 'uncertainty': 0.00602},
#   {'identifier': 'P39396', 'measurement': 11, 'uncertainty': 0.00141},
#   {'identifier': 'P21866', 'measurement': 25, 'uncertainty': 0.00107},
#   {'identifier': 'P77213', 'measurement': 73, 'uncertainty': 0.00506},
#   {'identifier': 'P75838', 'measurement': 196, 'uncertainty': 0.0213},
#   {'identifier': 'P0AB43', 'measurement': 72, 'uncertainty': 0.00134},
#   {'identifier': 'P21362', 'measurement': 241, 'uncertainty': 0.00743},
#   {'identifier': 'P31130', 'measurement': 28, 'uncertainty': 0.000666},
#   {'identifier': 'P77148', 'measurement': 29, 'uncertainty': 0.00292},
#   {'identifier': 'P64483', 'measurement': 279, 'uncertainty': 0.00825},
#   {'identifier': 'P33218', 'measurement': 350, 'uncertainty': 0.0138},
#   {'identifier': 'P76402', 'measurement': 317, 'uncertainty': 0.00632},
#   {'identifier': 'P0ADS6', 'measurement': 932, 'uncertainty': 0.0411},
#   {'identifier': 'P0ADU5', 'measurement': 1688, 'uncertainty': 0.0392},
#   {'identifier': 'P0ADP9', 'measurement': 1246, 'uncertainty': 0.0212},
#   {'identifier': 'P77214', 'measurement': 28457, 'uncertainty': 0.578},
#   {'identifier': 'Q46920', 'measurement': 49, 'uncertainty': 0.00267},
#   {'identifier': 'P64530', 'measurement': 291, 'uncertainty': 0.00488},
#   {'identifier': 'P0A8A8', 'measurement': 355, 'uncertainty': 0.0098},
#   {'identifier': 'P0A8X0', 'measurement': 119, 'uncertainty': 0.00421},
#   {'identifier': 'Q46868', 'measurement': 1074, 'uncertainty': 0.0201},
#   {'identifier': 'P0AF36', 'measurement': 4364, 'uncertainty': 0.0696},
#   {'identifier': 'P66948', 'measurement': 231, 'uncertainty': 0.0207},
#   {'identifier': 'P23827', 'measurement': 200, 'uncertainty': 0.00602},
#   {'identifier': 'P0AFZ3',
#    'measurement': 233,
#    'uncertainty': 0.0070599999999999994},
#   {'identifier': 'P75736', 'measurement': 207, 'uncertainty': 0.00975},
#   {'identifier': 'P21829', 'measurement': 305, 'uncertainty': 0.0153},
#   {'identifier': 'P67095', 'measurement': 587, 'uncertainty': 0.0196},
#   {'identifier': 'P77775', 'measurement': 110, 'uncertainty': 0.00594},
#   {'identifier': 'P67080', 'measurement': 136, 'uncertainty': 0.00583},
#   {'identifier': 'P46852', 'measurement': 103, 'uncertainty': 0.00449},
#   {'identifier': 'P37648', 'measurement': 46, 'uncertainty': 0.00424},
#   {'identifier': 'P42641', 'measurement': 325, 'uncertainty': 0.0234},
#   {'identifier': 'Q5H776', 'measurement': 36, 'uncertainty': 0.00165},
#   {'identifier': 'P75876', 'measurement': 167, 'uncertainty': 0.0123},
#   {'identifier': 'Q46948', 'measurement': 362, 'uncertainty': 0.0125},
#   {'identifier': 'P64429',
#    'measurement': 96,
#    'uncertainty': 0.0050100000000000006},
#   {'identifier': 'P64596', 'measurement': 553, 'uncertainty': 0.0184},
#   {'identifier': 'P42624',
#    'measurement': 30,
#    'uncertainty': 0.0012699999999999999},
#   {'identifier': 'P27848', 'measurement': 628, 'uncertainty': 0.0309},
#   {'identifier': 'P75931', 'measurement': 28, 'uncertainty': 0.00155},
#   {'identifier': 'P0A6J1', 'measurement': 450, 'uncertainty': 0.0167},
#   {'identifier': 'P0AFJ7', 'measurement': 188, 'uncertainty': 0.0166},
#   {'identifier': 'P0AGD3',
#    'measurement': 5850,
#    'uncertainty': 0.20600000000000002},
#   {'identifier': 'P0AGD1', 'measurement': 194, 'uncertainty': 0.0057},
#   {'identifier': 'P0A9L3',
#    'measurement': 3216,
#    'uncertainty': 0.11800000000000001},
#   {'identifier': 'P0A9N4', 'measurement': 112, 'uncertainty': 0.00524},
#   {'identifier': 'P63284', 'measurement': 104, 'uncertainty': 0.0165},
#   ...]}

# %%
# Out:
# 2.3
